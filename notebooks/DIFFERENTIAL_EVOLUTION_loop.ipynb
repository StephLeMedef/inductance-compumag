# %% [markdown]
# # Control points optimization - differential evolution
#
# ## Loop

# %%
from shapeOptInductor import gen_meshN, Id
import ngsolve as ngs
from ngsolve.webgui import Draw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Geometry and meshing
#
# We define a geometry with an arbitrary number of control points on the airgap.

# %%
NControlPoints = 10
airgap = [1e-3,2e-3]*(NControlPoints//2)
lz = 1e-2  # thickness in the z-direction (m)
s = 4  # symmetry factor

maxh = 4e-3
mesh = gen_meshN(airgap, maxh)

XiAir = mesh.MaterialCF({"air": 1})
XiCore = mesh.MaterialCF({"core": 1})
XiCoil = mesh.MaterialCF({"coil": 1})

materialFunction = 1 * XiAir + 2 * XiCoil + 3 * XiCore
Draw(materialFunction, mesh, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ## 2 - State problem
#
# ### a) Parameters definition

# %%
f = 5e4  # working frequency (Hz)
omega = 2 * np.pi * f  # rad/s
mu0 = 4e-7 * np.pi  # void permeability (H/m)
mur = 1000  # relative permeability of iron (no unit)
mu_iron = mur * mu0  # permeability of iron (H/m)
delta = 0.1  # loss angle associated with the coil (rad)
mu_coil = np.exp(-1j * delta) * mu0  # complex permeability
nb_turn = 200  # number of turn in the coil (no unit)
Is = 2  # source current intensity (A)
js = nb_turn / 2 * Is / (ngs.Integrate(XiCoil, mesh)) * XiCoil  # source current density (A/m²)

# %% [markdown]
# ### b) Definition of the magnetic problem

# %%
def magWeakFormComplex(a, a_):
    """Return the complex weak form of the magnetic problem, i.e, bilinear
    and linear forms (matrix and right-hand side after discretization, respectively)"""

    # bilinear form (transmission)
    bf = ngs.grad(a_) * 1 / mu_iron * ngs.grad(a) * ngs.dx("core")
    bf += ngs.grad(a_) * 1 / mu_coil * ngs.grad(a) * ngs.dx("coil")
    bf += ngs.grad(a_) * 1 / mu0 * ngs.grad(a) * ngs.dx("air")

    # linear form (source)
    lf = a_ * js * ngs.dx("coil")

    return bf, lf


def solveStateComplex(mesh):
    """Solve the complex magnetic state"""
    # definition of function space
    fes = ngs.H1(mesh, order=1, dirichlet="arc|segment2|domainVert", complex=True)
    a, a_ = fes.TnT()

    # definition of weak form
    bf, f = magWeakFormComplex(a, a_)
    K, F = ngs.BilinearForm(fes), ngs.LinearForm(fes)
    K += bf
    F += f

    # assembly
    K.Assemble()
    F.Assemble()

    # solving
    gf = ngs.GridFunction(fes)
    Kinv = K.mat.Inverse(freedofs=fes.FreeDofs(), inverse="pardiso")
    gf.vec.data = Kinv * F.vec

    return gf

# %% [markdown]
# ### c) Definition of the post-processed quantities
#
# We define the losses and inductance. We don't need derivatives here since we'll use a differential evolution algorithm, which is a gradient-free optimization algorithm.

# %%
def Inductance(a, mesh):
    rel = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return s * lz / (Is**2) * ngs.Integrate(rel.real * ngs.Norm(ngs.grad(a)) ** 2, mesh)


def Losses(a, mesh):
    rel = XiCoil / mu_coil
    return s * np.pi * f * lz * ngs.Integrate(rel.imag * ngs.Norm(ngs.grad(a)) ** 2, mesh)

# %% [markdown]
# ## 3 - Optimization
#
# ### a) Scipy wrapper
# We first define wrappers of the objective function to minimize (the losses) and the constraint (the inductance value). We have to set a tolerance for the equality constraint, that we chose to be $\pm5\%$.

# %%
# FEM evaluation counter (solve the FEM system)
FEMcounter = [0]
LossList = []
xList = []

def scipyObj(x, maxh = 4e-3):
    """ Scipy wrapper to the objective function to minimize """
    FEMcounter[0] += 1                      # Increment at each evaluation
    if FEMcounter[0] % 100 == 0:            # print every 100 function calls
        print(f"{FEMcounter[0]} function evaluations")
    mesh = gen_meshN(list(x), maxh)
    a = solveStateComplex(mesh)
    return Losses(a, mesh)

def scipyConst(x, maxh = 4e-3):
    """ Scipy wrapper to the constraint to respect """
    FEMcounter[0] += 1                      # Increment at each evaluation
    if FEMcounter[0] % 100 == 0:            # print every 100 function calls
        print(f"Evaluation {FEMcounter[0]}")
    mesh = gen_meshN(list(x), maxh)
    a = solveStateComplex(mesh)
    return Inductance(a, mesh) - 1e-3

def callback(intermediate_result):
    LossList.append(intermediate_result.fun)
    xList.append(intermediate_result.x)


from scipy.optimize import NonlinearConstraint, Bounds
nlc = NonlinearConstraint(scipyConst,-5e-5,5e-5)
bnds = Bounds(5e-4*np.ones(NControlPoints), 7.2e-3*np.ones(NControlPoints))

# %% [markdown]
# ### b) Optimization
#
# We use `differential_evolution` from `scipy.optimize` package.

# %%
from scipy.optimize import differential_evolution

NList = [4,6,8,10,12,14,16]

FEMcounterListAll = []
objCounterListAll = []
LossListAll = []
xListAll = []

for N in NList:
    FEMcounter = [0]
    LossList = []
    xList = []
    print("-------------------------------")
    print("Number of control points : ", N)
    result = differential_evolution(
    scipyObj,
    bounds=bnds,
    maxiter=100,
    popsize=15,
    tol = 0.1,
    atol= 0.1,
    seed=0, # for reproducibility
    disp=True,
    polish=False,
    constraints = nlc)
    c = FEMcounter[0]
    FEMcounterListAll.append(c)
    xListAll.append(xList.copy())
    LossListAll.append(LossList.copy())
    objCounterListAll.append(result.nfev)
# Out:
# Evaluation 100
# Evaluation 200
# Evaluation 300
# differential_evolution step 1: f(x)= 5.1543575142646
# Evaluation 400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 15
#      12 LossList = []
#      13 xList = []
# ---> 15 result = differential_evolution(
#      16 scipyObj,
#      17 bounds=bnds,
#      18 maxiter=100,
#      19 popsize=15,
#      20 tol = 0.1,
#      21 atol= 0.1,
#      22 seed=0, # for reproducibility
#      23 disp=True,
#      24 polish=False,
#      25 constraints = nlc)
#      26 c = FEMcounter[0]
#      27 FEMcounterListAll.append(c)
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:503, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     486 # using a context manager means that any created Pool objects are
#     487 # cleared up.
#     488 with DifferentialEvolutionSolver(func, bounds, args=args,
#     489                                  strategy=strategy,
#     490                                  maxiter=maxiter,
#    (...)
#     501                                  integrality=integrality,
#     502                                  vectorized=vectorized) as solver:
# --> 503     ret = solver.solve()
#     505 return ret
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:1168, in DifferentialEvolutionSolver.solve(self)
#    1165 for nit in range(1, self.maxiter + 1):
#    1166     # evolve the population by a generation
#    1167     try:
# -> 1168         next(self)
#    1169     except StopIteration:
#    1170         warning_flag = True
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:1571, in DifferentialEvolutionSolver.__next__(self)
#    1569 # determine the energy of the objective function
#    1570 if self._wrapped_constraints:
# -> 1571     cv = self._constraint_violation_fn(parameters)
#    1572     feasible = False
#    1573     energy = np.inf
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:1397, in DifferentialEvolutionSolver._constraint_violation_fn(self, x)
#    1390 offset = 0
#    1391 for con in self._wrapped_constraints:
#    1392     # the input/output of the (vectorized) constraint function is
#    1393     # {(N, S), (N,)} --> (M, S)
#    1394     # The input to _constraint_violation_fn is (S, N) or (N,), so
#    1395     # transpose to pass it to the constraint. The output is transposed
#    1396     # from (M, S) to (S, M) for further use.
# -> 1397     c = con.violation(x.T).T
#    1399     # The shape of c should be (M,), (1, M), or (S, M). Check for
#    1400     # those shapes, as an incorrect shape indicates that the
#    1401     # user constraint function didn't return the right thing, and
#    1402     # the reshape operation will fail. Intercept the wrong shape
#    1403     # to give a reasonable error message. I'm not sure what failure
#    1404     # modes an inventive user will come up with.
#    1405     if c.shape[-1] != con.num_constr or (S > 1 and c.shape[0] != S):
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:1934, in _ConstraintWrapper.violation(self, x)
#    1918 """How much the constraint is exceeded by.
#    1919
#    1920 Parameters
#    (...)
#    1931     Has shape (M, S) where M is the number of constraint components.
#    1932 """
#    1933 # expect ev to have shape (num_constr, S) or (num_constr,)
# -> 1934 ev = self.fun(np.asarray(x))
#    1936 try:
#    1937     excess_lb = np.maximum(self.bounds[0] - ev.T, 0)
#
# File c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_differentialevolution.py:1869, in _ConstraintWrapper.__init__.<locals>.fun(x)
#    1867 def fun(x):
#    1868     x = np.asarray(x)
# -> 1869     return np.atleast_1d(constraint.fun(x))
#
# Cell In[11], line 20, in scipyConst(x, maxh)
#      18 if FEMcounter[0] % 100 == 0:            # print every 100 function calls
#      19     print(f"Evaluation {FEMcounter[0]}")
# ---> 20 mesh = gen_meshN(list(x), maxh)
#      21 a = solveStateComplex(mesh)
#      22 return Inductance(a, mesh) - 1e-3
#
# File c:\Users\theodore\Documents\GitHub\inductance-compumag\notebooks\shapeOptInductor.py:447, in gen_meshN(airgap, maxh)
#     445 geo.SetMaterial(3, "coil")
#     446 geo.SetMaterial(4, "air")
# --> 447 ngmesh = geo.GenerateMesh(maxh=maxh)
#     449 return ngs.Mesh(ngmesh)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4) Results
#
# ### a) Design

# %%
meshOpt = gen_meshN(result.x)
Draw(materialFunction, meshOpt, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### b) Performance

# %%
InductanceListOptim = []
LossListOptim = []
for xlist in xListAll:
    meshOpt = gen_meshN(xlist[-1])
    a = solveStateComplex(meshOpt)
    InductanceListOptim.append(Inductance(a, meshOpt))
    LossListOptim.append(Losses(a, meshOpt))

ax1 = plt.plot(NList, LossListOptim, color="b")
plt.ylabel("Losses (W)", color="b")
plt.xlabel("Number of control points")
ax2 = plt.gca().twinx()
ax2.plot(NList, InductanceListOptim, color="r")
plt.ylabel("Inductance (H)", color="r")
plt.show()
# Out:
#  Losses =  5.097 W
#  Inductance =  0.960 mH
# Number of objective function evaluations =  462
# Number of FEM evaluations (objective + constraints) =  2925

# %%
plt.plot(NList, FEMcounterListAll)
plt.title("FEM counter")
plt.xlabel("Number of control points")

# %% [markdown]
# ## Saving the results

# %%
import pickle
results = dict("xListAll" : xListAll,"LossListAll" : LossListAll, "FEMcounterListAll" : FEMcounterListAll, "objCounterListAll" : objCounterListAll )
with open('results/differential_evolution.pkl', 'wb') as f:
    pickle.dump(results, f)
