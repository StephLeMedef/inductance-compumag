# %% [markdown]
# # III - Gradient-based design optimization with control points
#
# - **Parametric optimization** is not incompatible with gradient optimization.
# - The derivatives can be evaluated using **finite differences**, but this requires at least as many additional function evaluations as the number of parameters $N$. With many parameters (say $N>10$), using finite difference becomes **really costly**, especially when evaluating the function requires solving finite element problems.
# - Thanks to mathematical tools such as shape derivative and adjoint method, the derivatives can be evaluated efficiently with only $1$ additional resolution of a linear finite element problem per function to derivate (so-called adjoint).

# %%
from shapeOptInductor import gen_meshN, Id
import ngsolve as ngs
from ngsolve.webgui import Draw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, we set up the number of control points (with adjoint method, computation time is almost independant of the number of parameters).

# %%
##############################################
NControlPoints = 10 # can be changed
##############################################
print(f"{NControlPoints = }")
# Out:
# NControlPoints = 10

# %% [markdown]
# ___________________________
# ## 1 - Geometry and meshing
#
# Then, we define the inductor geometry and generate the mesh.

# %%
# Geometric parameters
lz = 1e-2               # z-thickness of the inductor  
s = 4                   # symmetry factor (model 1/4th of the total space)

# Mesh generation
airgap = 4.11e-3 * np.ones(NControlPoints)              # Array of y-coordinates of control points along the airgap
maxh = 2e-3                                             # Maximum size of mesh element
mesh, p1, p2 = gen_meshN(airgap, maxh)                  # Generate the mesh and return the coordinates of control points on the first and second leg
xAirgaps = [p[0] for p in p1] + [p[0] for p in p2]      # Extract the x-coordinates of the control points

# Define the characteristics functions
XiAir = mesh.MaterialCF({"air": 1})
XiCore = mesh.MaterialCF({"core": 1})
XiCoil = mesh.MaterialCF({"coil": 1})
materials_regions = 1 * XiAir + 2 * XiCoil + 3 * XiCore

# Draw the geometry and mesh
Draw(materials_regions, mesh, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 2 - State problem (time-harmonic magnetics)
#
# ### 2.a - Parameters definition
#
# We describe the magnetic permeabilities and the source currents.

# %%
# Electric current (assumed sinusoidal)
f = 5e4                                                         # Working frequency (Hz)
omega = 2 * np.pi * f                                           # rad/s
nb_turn = 200                                                   # Number of turn in the coil (no unit)
I = 2                                                           # Amplitude of the source current (A)
j = nb_turn / 2 * I / (ngs.Integrate(XiCoil, mesh)) * XiCoil    # Amplitude of the source current density  (A/m²)

# Magnetic permeabilities
mu0 = 4e-7 * np.pi                                              # Void permeability (H/m)
mur = 1000                                                      # Relative permeability of iron (no unit)
mu_iron = mur * mu0                                             # Iron permeability (H/m)
delta = 0.1                                                     # Loss angle associated with the coil (rad)
mu_coil = np.exp(-1j * delta) * mu0                             # Complex permeability of the coil

# %% [markdown]
# ### 2.b - Definition of the time-harmonic magnetics problem
#
# Then we can write the weak formulation and solve the following problem :
# $$\text{Find } \underline{a_h} \in H := \{\underline{a} \in H^1(\Omega) |\, \underline{a} = 0 \text{ on } \Gamma_D\} \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H, \int_\Omega \underline{\nu_h} (\nabla \underline{a_h}) \cdot (\nabla \underline{v})^* \,\mathrm{d}x = \int_{\Omega_{c, h}} j \underline{v}^* \, \mathrm{d}x. $$

# %%
def magWeakFormComplex(ah : ngs.FESpace.TrialFunction, 
                       v  : ngs.FESpace.TestFunction
                       ) -> tuple[ngs.BilinearForm, ngs.LinearForm]:
    """Return the sybolic weak form of the magnetic problem, 
    i.e, bilinear and linear forms (not assembled yet)."""

    # Bilinear form (transmission)
    bf =  1 / mu_iron * ngs.grad(ah) * ngs.grad(v) * ngs.dx("core")
    bf += 1 / mu_coil * ngs.grad(ah) * ngs.grad(v) * ngs.dx("coil")
    bf += 1 / mu0 * ngs.grad(ah) * ngs.grad(v) * ngs.dx("air")

    # Linear form (source)
    lf = j * v * ngs.dx("coil")

    return bf, lf


def solveStateComplex(mesh : ngs.Mesh
                      ) -> tuple[ngs.GridFunction, ngs.la.BaseMatrix]:
    """ Solve the time-harmonic magnetics problem """

    # Definition of function space
    fes = ngs.H1(mesh, order=1, dirichlet="arc|domainVert", complex=True)
    a, v = fes.TnT()

    # Definition of weak form
    bf, f = magWeakFormComplex(a, v)

    # Assembly
    K = ngs.BilinearForm(bf).Assemble()
    F = ngs.LinearForm(f).Assemble()

    # Solving
    gf = ngs.GridFunction(fes)
    Kinv = K.mat.Inverse(freedofs=fes.FreeDofs())
    gf.vec.data = Kinv * F.vec

    return gf, Kinv  # returning Kinv speed up adjoint calculation

# Example :
state, Kinv = solveStateComplex(mesh)
Draw(state.real, mesh, radius=0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 2.c - Definition of the post-processed quantities
#
# We define the losses and inductance
# $$
# \begin{array}{lcl}
# P(\underline{a}) &=& \displaystyle  s l_z  \pi f \int_{\Omega_c} \text{Im} \left( \frac{1}{\underline{\mu_c}} \right ) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# L(\underline{a}) &=& \displaystyle \frac{s l_z}{I^2} \int_\Omega \text{Re} \left( \underline{\nu} \right) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# \end{array}$$
#
# with their directional derivatives.

# %%
def L(state : ngs.GridFunction, 
      mesh : ngs.Mesh
      ) -> float:
    """ Compute inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return s * lz / (I**2) * ngs.Integrate(nu.real * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddL(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of the inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return 2 * s * lz / (I**2) * ngs.InnerProduct(nu.real * ngs.grad(state), ngs.grad(v)) * ngs.dx


def P(state : ngs.GridFunction,
      mesh : ngs.Mesh
      ) -> float:
    """ Compute AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return s * np.pi * f * lz * ngs.Integrate(nu.imag * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddP(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return 2 * s * np.pi * f * lz * ngs.InnerProduct(nu.imag * ngs.grad(state), ngs.grad(v)) * ngs.dx

# Example :
print(f"Inductance : {L(state, mesh) *1000:.3} mH")
print(f"Losses : {P(state, mesh):.3} W")
# Out:
# Inductance : 1.0 mH
# Losses : 13.2 W

# %% [markdown]
# ___________________________
# ## 3 - Adjoint problem
#
# The adjoint method is an efficient way to compute derivatives of PDE-constrained problem; it requires solving one linear auxiliary problem per function $f$ to derivate that reads
#
# $$ \text{Find } \underline{p}_f \in H \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H,  \quad \int_\Omega \nabla \underline{p}_f \cdot \underline{\nu}^* \nabla \underline{v} \; \mathrm{d}x = \int f'(\underline{a})(\underline{v})\; \mathrm{d}x, $$
#
# with $f'$ the directional derivative of $f$, such that $F(\underline{a}) = \int_\Omega f(\underline{a}) \; \mathrm{d}x$.

# %%
def solveAdjoint(state : ngs.GridFunction,      
                 df : ngs.comp.SumOfIntegrals,
                 Kinv : ngs.la.BaseMatrix
                 ) -> ngs.GridFunction:
    """Solve the adjoint equation for a given directional derivative (right-hand side)"""

    fes = state.space
    v = fes.TestFunction()

    # Assemble the right-hand side
    f = ngs.LinearForm(-1. * df(state, v)).Assemble()
    
    # Solve using the adjoint (transconjugate) of provided FEM matrix
    gf = ngs.GridFunction(fes)
    gf.vec.data = Kinv.H * f.vec

    return gf

# Example :
adjoint_P = solveAdjoint(state, ddP, Kinv)
Draw(adjoint_P.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})

adjoint_L = solveAdjoint(state, ddL, Kinv)
Draw(adjoint_L.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 4 - Continuous and discretized shape derivatives
#
# ### 4.a - Continuous expressions
#
# The shape derivative of the losses is a linear form obtained by Céa's method that reads
# $$\mathrm{d} P(\Omega)(\phi) = \text{Re}\left( s l_z \pi f \int_{\Omega_c} \text{Im}\left(\frac{1}{\underline{\mu_c}}\right) A_\phi \nabla \underline a \cdot (\nabla \underline a)^* \; \mathrm{d} x + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_P^* \mathrm{d} x - \int_{\Omega_c} j\, \text{div} \phi\, \underline p_P^*  \mathrm{d} x \right)  $$
#
# with $\phi\in W^{1, \infty}(\mathbb{R}^2,\mathbb{R}^2)$ and $A_\phi = \text{div} \phi \, I_2 - \nabla \phi - \nabla \phi^\top$.

# %%
def sdP(state : ngs.GridFunction,
        adjoint_P : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) of the AC losses inside the coil """

    # Finite element spaces
    mesh = state.space.mesh
    FESReal = ngs.VectorH1(mesh)
    FEScomplex = ngs.VectorH1(mesh, complex=True)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_losses = s * np.pi * f * lz * (1 / mu_coil).imag
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_losses * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx("coil")
    shape_derivative_cplx += -j * XiCoil * ngs.div(phi) * adjoint_P * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_P)) * ngs.dx
    shape_derivative_cplx.Assemble()

    # Take the real part
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# Similarly, computing the shape derivative of the inductance leads to
#
# $$
#  \mathrm{d}  L(\Omega)(\phi) =  \text{Re}\left( \frac{s l_z}{I^2} \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot (\nabla \underline a)^* \; \mathrm{d} x  + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_L^* \mathrm{d} x - \int_{\Omega_c} j\,\text{div} \phi\, \underline p_L^*  \mathrm{d} x \right)
# $$

# %%
def sdL(state : ngs.GridFunction,
        adjoint_L : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) for the inductance"""

    # Finite element spaces
    mesh = state.space.mesh
    FEScomplex = ngs.H1(mesh, complex = True)**2 #ngs.VectorH1(mesh, complex=True)
    FESReal = ngs.H1(mesh)**2 # ngs.VectorH1(mesh)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_induc = s * lz / (I**2) * nu.real
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative 
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_induc * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx
    shape_derivative_cplx += -j * ngs.div(phi) * adjoint_L * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_L)) * ngs.dx
    shape_derivative_cplx.Assemble()
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# ### 4.b - Discrete shape derivatives
# - The shape derivative is a **linear form**, from which we can extract a **descent direction**.
# - At the discrete level, one possibility is to extract directly the **nodal coefficients** from the assembled linear form, which is a vector.
#     - It represents the derivative of the losses with respect to the **coordinates of the mesh nodes**. In a sense, it represents the **shape gradient** of the discretized model.
#     - It takes the form of a nodal vector field, indicating in which direction one should move every node of the mesh to increase $f$ maximally.
# - We can therefore plot it, as below. It is almost 0 everywhere (should be exactly 0 up to the discretization errors), except on the **edges** of the geometry.
#     - Indeed, displacing a node at an interface modify the material distribution, which impacts the value of the scalar function, while moving a point from the inside doesn't change the geometry.
# - The **correctness** of the point-wise values of the discretized shape derivative can therefore be checked by **finite difference**, which is the purpose of the last section.

# %%
# Nodal identification of the shape derivative of the losses:
sdP_linear_form = sdP(state, adjoint_P)
discrete_shape_gradient_P = ngs.GridFunction(sdP_linear_form.space)
discrete_shape_gradient_P.vec.data = sdP_linear_form.vec
Draw(discrete_shape_gradient_P, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %%
# Nodal identification of the shape derivative of the inductance:
sdL_linear_form = sdL(state, adjoint_L)
discrete_shape_gradient_L = ngs.GridFunction(sdL_linear_form.space)
discrete_shape_gradient_L.vec.data = sdL_linear_form.vec
Draw(discrete_shape_gradient_L, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 4.c - Sensitivities with respect to the control points
#
# The sensitivities with respect to the $y$-coordinate of the control points (i.e., the first order derivatives of the quantity of interest) are simply obtained by taking the scalar product of the discretized shape derivative with a displacement field induced by the displacement of the control points.
#
# To obtain the true derivative, the displacement of the control point should be unitary. In the literature, this displacement can also be called a "velocity" because it can be used as a descent direction, transporting the geometry through a pseudo-time that are iterations of the algorithm. It is also possible (rather recommended) to use other descent direction using a regularization.

# %%
from shapeOptInductor import referenceVelocity

def sensitivities_y_control_points(state : ngs.GridFunction,
               adjoint : ngs.GridFunction,
               shape_derivative : callable,
               x_airgap : list[float]) -> list[float]:
    """ Compute the sensitivities of a function with respect to the y-value of the control points """

    velocityFields = referenceVelocity(state.space.mesh, x_airgap)
    sd_linearform = shape_derivative(state, adjoint)
    sd_discretized = ngs.GridFunction(ngs.VectorH1(state.space.mesh))
    sd_discretized.vec.FV().NumPy()[:] = np.real(sd_linearform.vec.FV().NumPy()[:])
    sensitivities = [ ngs.InnerProduct(sd_discretized.vec, refVelocity.vec) for refVelocity in velocityFields]
    return sensitivities

# Example:
sensitivities_P = sensitivities_y_control_points(state, adjoint_P, sdP, xAirgaps)
sensitivities_L = sensitivities_y_control_points(state, adjoint_L, sdL, xAirgaps)

print("dL/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_P) + " ]")
print("dP/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_L) + " ]")
# Out:
# dL/dy = [ 1.600e+02, 3.172e+02, 2.947e+02, -1.338e+01, -2.429e+03, -1.470e+03, -3.974e+02, -2.139e+02, -2.309e+02, -2.561e+02 ]
# dP/dy = [ -2.672e-02, -5.353e-02, -5.428e-02, -6.276e-02, -6.879e-02, -2.937e-02, -2.680e-02, -2.347e-02, -2.684e-02, -2.999e-02 ]

# %%
np.dot([1,2,3],[3,2,1.])
# Out:
# np.float64(10.0)

# %% [markdown]
# ________
# ## 5 - Gradient-based optimization
#
# ### 5.a - Optimization algorithm
# We use an augmented Lagrangian algorithm to solve the constrained optimization problem. That is to say, we maximize with respect to a Lagrange multiplier $\lambda$ a sequence of inner minimization problem with respect to the optimization variables $y_{airgap}$ :
#
# $$ \mathcal L(y_{airgap},\lambda) = P(y_{airgap}) + \lambda (L(y_{airgap}) - L_0) + \frac{\beta}{2} (L(y_{airgap}) - L_0)^2 $$

# %%
# Wrappers
regularize_symmetry_axis = True # flag to ensure dy/dx = 0 at the symmetry axis; otherwise problems happen...
L0 = 1e-3                       # target inductance
scale = 1/L0                    # constraint scaling factor

# container
current = {"x" : None, 
           "x_airgap" : None,
           "state" : None, 
           "mesh" : None, 
           "Kinv" : None, 
           "FEM_counter" : 0}

def update(x):
    current["x"] = x
    if regularize_symmetry_axis : y_airgap = [x[0]] + list(x)
    else : y_airgap = list(x)
    current["mesh"], p1, p2 = gen_meshN(y_airgap, maxh)    # Generate the mesh and return the coordinates of control points on the first and second leg
    current["x_airgap"] = [p[0] for p in p1] + [p[0] for p in p2]     # Extract the x-coordinates of the control points
    current["state"], current["Kinv"] = solveStateComplex(current["mesh"])
    current["FEM_counter"] += 1

def obj(x):
    if x is not current["x"]: update(x)
    return P(current["state"], current["mesh"])

def dObj(x):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddP, current["Kinv"])
    dobj = sensitivities_y_control_points(current["state"], adjoint, sdP, current["x_airgap"])
    if regularize_symmetry_axis : return np.array(dobj[1:])
    else : return np.array(dobj)


def cons(x, L0 = L0, scale = scale):
    if x is not current["x"]: update(x)
    return scale * (L(current["state"], current["mesh"]) - L0)

def dCons(x, scale = scale):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddL, current["Kinv"])
    dcons = sensitivities_y_control_points(current["state"], adjoint, sdL, current["x_airgap"])
    if regularize_symmetry_axis : return scale * np.array(dcons[1:])
    else : return scale * np.array(dcons)

# lagrangian

def lagrangian(x, lam, beta, fun, cons):
    objFunction = fun(x)
    constraint = cons(x)
    return objFunction + lam * constraint + beta / 2 * constraint **2

def dx_lagrangian(x, lam, beta, dfun, dcons, cons):
    dx_objFunction = dfun(x)
    dx_constraint = dcons(x)
    constraint = cons(x)
    return dx_objFunction + lam * dx_constraint + beta * constraint * dx_constraint

# %% [markdown]
# ### 5-b. Unconstrained optimization (gradient descent)

# %%
from shapeOptInductor import gradient_descent

# Example (unconstrained)
lam = 0
beta = 100
lbound = 0.5e-4
ubound = 1.395e-2
if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

lagr = lambda x: lagrangian(x, lam = lam,  beta = beta, fun = obj, cons = cons)
dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
res = gradient_descent(lagr, dlagr, x, step = 1e-3, iter_max = 50,
                       xlb = lbound, xub = ubound, precond = True, verbosity = 2)
# Out:
# ---- Start gradient descent
# it 0 | fun = 1.31714e+01 | step = 1.00e-03
# it 1 | fun = 1.16747e+01 | step = 1.20e-03 | crit = 1.88e+00 (accepted ✅)
# it 2 | fun = 1.02500e+01 | step = 1.44e-03 | crit = 1.80e+00 (accepted ✅)
# it 3 | fun = 8.71700e+00 | step = 1.73e-03 | crit = 1.85e+00 (accepted ✅)
# it 4 | fun = 7.15125e+00 | step = 2.07e-03 | crit = 1.93e+00 (accepted ✅)
# it 5 | fun = 6.08509e+00 | step = 2.49e-03 | crit = 1.80e+00 (accepted ✅)
# it 6 | fun = 5.63291e+01 | step = 1.24e-03 | crit = 1.80e+00 (rejected ❌)
# it 7 | fun = 7.80567e+00 | step = 6.22e-04 | crit = 1.80e+00 (rejected ❌)
# it 8 | fun = 5.88252e+00 | step = 7.46e-04 | crit = 9.38e-01 (accepted ✅)
# it 9 | fun = 6.11024e+00 | step = 3.73e-04 | crit = 9.38e-01 (rejected ❌)
# it 10 | fun = 5.80875e+00 | step = 4.48e-04 | crit = 7.44e-01 (accepted ✅)
# it 11 | fun = 5.77485e+00 | step = 2.24e-04 | crit = 7.44e-01 (rejected ❌)
# it 12 | fun = 5.71650e+00 | step = 2.69e-04 | crit = 4.71e-01 (accepted ✅)
# it 13 | fun = 5.58996e+00 | step = 3.22e-04 | crit = 5.15e-01 (accepted ✅)
# it 14 | fun = 5.55168e+00 | step = 3.87e-04 | crit = 5.80e-01 (accepted ✅)
# it 15 | fun = 5.47456e+00 | step = 4.64e-04 | crit = 7.86e-01 (accepted ✅)
# it 16 | fun = 5.53505e+00 | step = 2.32e-04 | crit = 7.86e-01 (rejected ❌)
# it 17 | fun = 5.39577e+00 | step = 2.79e-04 | crit = 4.65e-01 (accepted ✅)
# it 18 | fun = 5.37943e+00 | step = 1.39e-04 | crit = 4.65e-01 (rejected ❌)
# it 19 | fun = 5.35522e+00 | step = 1.67e-04 | crit = 3.90e-01 (accepted ✅)
# it 20 | fun = 5.31300e+00 | step = 2.01e-04 | crit = 3.58e-01 (accepted ✅)
# it 21 | fun = 5.29733e+00 | step = 1.00e-04 | crit = 3.58e-01 (rejected ❌)
# it 22 | fun = 5.28372e+00 | step = 1.20e-04 | crit = 3.13e-01 (accepted ✅)
# it 23 | fun = 5.25128e+00 | step = 1.44e-04 | crit = 3.07e-01 (accepted ✅)
# it 24 | fun = 5.22825e+00 | step = 1.73e-04 | crit = 3.65e-01 (accepted ✅)
# it 25 | fun = 5.18838e+00 | step = 2.08e-04 | crit = 3.59e-01 (accepted ✅)
# it 26 | fun = 5.18296e+00 | step = 1.04e-04 | crit = 3.59e-01 (rejected ❌)
# it 27 | fun = 5.16644e+00 | step = 1.25e-04 | crit = 2.97e-01 (accepted ✅)
# it 28 | fun = 5.13554e+00 | step = 1.50e-04 | crit = 3.03e-01 (accepted ✅)
# it 29 | fun = 5.11743e+00 | step = 1.80e-04 | crit = 3.49e-01 (accepted ✅)
# it 30 | fun = 5.09388e+00 | step = 2.16e-04 | crit = 3.56e-01 (accepted ✅)
# it 31 | fun = 5.08941e+00 | step = 1.08e-04 | crit = 3.56e-01 (rejected ❌)
# it 32 | fun = 5.06454e+00 | step = 1.29e-04 | crit = 2.98e-01 (accepted ✅)
# it 33 | fun = 5.03436e+00 | step = 1.55e-04 | crit = 3.25e-01 (accepted ✅)
# it 34 | fun = 5.01377e+00 | step = 1.86e-04 | crit = 3.57e-01 (accepted ✅)
# it 35 | fun = 5.00504e+00 | step = 9.32e-05 | crit = 3.57e-01 (rejected ❌)
# it 36 | fun = 4.98446e+00 | step = 1.12e-04 | crit = 2.47e-01 (accepted ✅)
# it 37 | fun = 4.95810e+00 | step = 1.34e-04 | crit = 2.84e-01 (accepted ✅)
# it 38 | fun = 4.94156e+00 | step = 1.61e-04 | crit = 2.91e-01 (accepted ✅)
# it 39 | fun = 4.92731e+00 | step = 1.93e-04 | crit = 3.56e-01 (accepted ✅)
# it 40 | fun = 4.91925e+00 | step = 9.66e-05 | crit = 3.56e-01 (rejected ❌)
# it 41 | fun = 4.90060e+00 | step = 1.16e-04 | crit = 2.52e-01 (accepted ✅)
# it 42 | fun = 4.86784e+00 | step = 1.39e-04 | crit = 2.80e-01 (accepted ✅)
# it 43 | fun = 4.85945e+00 | step = 1.67e-04 | crit = 2.86e-01 (accepted ✅)
# it 44 | fun = 4.84568e+00 | step = 2.00e-04 | crit = 3.65e-01 (accepted ✅)
# it 45 | fun = 4.84524e+00 | step = 1.00e-04 | crit = 3.65e-01 (rejected ❌)
# it 46 | fun = 4.82166e+00 | step = 1.20e-04 | crit = 2.54e-01 (accepted ✅)
# it 47 | fun = 4.79973e+00 | step = 1.44e-04 | crit = 2.89e-01 (accepted ✅)
# it 48 | fun = 4.78340e+00 | step = 1.73e-04 | crit = 2.99e-01 (accepted ✅)
# it 49 | fun = 4.78627e+00 | step = 8.65e-05 | crit = 2.99e-01 (rejected ❌)
# it 50 | fun = 4.76365e+00 | step = 1.04e-04 | crit = 2.43e-01 (accepted ✅)
# ---- Stopped after 50 because maximum number of iterations reached.

# %% [markdown]
# We plot the convergence and optimized design:

# %%
print(f"final airgap control point values : {res["x"][-1]}")
# Out:
# final airgap control point values : [0.00142553 0.00486552 0.01016025 0.01295467 0.01314711 0.01056713
#  0.00712461 0.00512479 0.00452388]

# %%
ax1 = plt.plot(res["fun"], color = 'b')   
plt.ylabel('Objective function', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.semilogy(res["stop_criterion"], color = 'r')
plt.ylabel("Stop criterion", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5-c. Constrained optimization with augmented Lagrangian

# %%
# Example (constrained optimization)

beta = 0.1
lam = 0
max_outer = 50
max_inner = 10
step = 1e-3

if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

lam = 0
x_list= [x]
P_list = [obj(x)]
L_list = [cons(x)/scale + L0]

for i in range(max_outer):
    print(f"it {i} : P = {P_list[-1]:.5f} W | L = {L_list[-1]*1000 :.3e} mH | lam = {lam:.3e}")
    lagr = lambda x: lagrangian(x, lam = lam, beta = beta, fun = obj, cons = cons)
    dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
    res = gradient_descent(lagr, dlagr, x, step = step, xlb = lbound, xub = ubound, 
                           iter_max = max_inner, precond = True, verbosity = 1)
    x = res["x"][-1]
    x_list.append(x)
    L_list.append(cons(x)/scale + L0)
    P_list.append(obj(x))
    lam += beta * cons(x)
    beta *= 1.1
    
print(f"Final design : P = {P_list[-1]:.5f} W | L = {L_list[-1]*1000 :.3f} mH")
x0 = res["x"][-1]
# Out:
# it 0 : P = 13.17140 W | L = 1.000e+00 mH | lam = 0.000e+00
# ---- Start gradient descent
# it 0 | fun = 1.31714e+01 | step = 1.00e-03
# it 1 | fun = 1.16254e+01 | step = 1.20e-03 | crit = 1.88e+00 (accepted ✅)
# it 2 | fun = 1.01870e+01 | step = 1.44e-03 | crit = 1.84e+00 (accepted ✅)
# it 3 | fun = 8.71755e+00 | step = 1.73e-03 | crit = 1.83e+00 (accepted ✅)
# it 4 | fun = 7.17142e+00 | step = 2.07e-03 | crit = 1.90e+00 (accepted ✅)
# it 5 | fun = 5.88560e+00 | step = 2.49e-03 | crit = 1.81e+00 (accepted ✅)
# it 6 | fun = 5.12422e+00 | step = 2.99e-03 | crit = 1.63e+00 (accepted ✅)
# it 8 | fun = 4.77440e+00 | step = 1.79e-03 | crit = 1.06e+00 (accepted ✅)
# it 10 | fun = 4.65976e+00 | step = 1.07e-03 | crit = 7.95e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 1 : P = 4.65844 W | L = 8.375e-01 mH | lam = -1.625e-02
# ---- Start gradient descent
# it 0 | fun = 4.66253e+00 | step = 1.00e-03
# it 1 | fun = 4.58887e+00 | step = 1.20e-03 | crit = 7.88e-01 (accepted ✅)
# it 2 | fun = 4.45267e+00 | step = 1.44e-03 | crit = 1.01e+00 (accepted ✅)
# it 4 | fun = 4.33194e+00 | step = 8.64e-04 | crit = 5.65e-01 (accepted ✅)
# it 6 | fun = 4.28840e+00 | step = 5.18e-04 | crit = 3.94e-01 (accepted ✅)
# it 7 | fun = 4.22735e+00 | step = 6.22e-04 | crit = 4.60e-01 (accepted ✅)
# it 8 | fun = 4.19601e+00 | step = 7.46e-04 | crit = 4.42e-01 (accepted ✅)
# it 10 | fun = 4.14464e+00 | step = 4.48e-04 | crit = 3.52e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 2 : P = 4.13929 W | L = 8.026e-01 mH | lam = -3.796e-02
# ---- Start gradient descent
# it 0 | fun = 4.14914e+00 | step = 1.00e-03
# it 1 | fun = 4.10038e+00 | step = 1.20e-03 | crit = 5.07e-01 (accepted ✅)
# it 3 | fun = 4.02915e+00 | step = 7.20e-04 | crit = 4.13e-01 (accepted ✅)
# it 4 | fun = 3.99735e+00 | step = 8.64e-04 | crit = 3.47e-01 (accepted ✅)
# it 6 | fun = 3.96913e+00 | step = 5.18e-04 | crit = 2.89e-01 (accepted ✅)
# it 8 | fun = 3.95818e+00 | step = 3.11e-04 | crit = 1.85e-01 (accepted ✅)
# it 9 | fun = 3.94343e+00 | step = 3.73e-04 | crit = 2.04e-01 (accepted ✅)
# it 10 | fun = 3.93473e+00 | step = 4.48e-04 | crit = 2.13e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 3 : P = 3.91666 W | L = 6.836e-01 mH | lam = -7.624e-02
# ---- Start gradient descent
# it 0 | fun = 3.94745e+00 | step = 1.00e-03
# it 2 | fun = 3.93821e+00 | step = 6.00e-04 | crit = 2.73e-01 (accepted ✅)
# it 3 | fun = 3.92722e+00 | step = 7.20e-04 | crit = 3.07e-01 (accepted ✅)
# it 5 | fun = 3.91001e+00 | step = 4.32e-04 | crit = 2.23e-01 (accepted ✅)
# it 7 | fun = 3.90492e+00 | step = 2.59e-04 | crit = 1.42e-01 (accepted ✅)
# it 8 | fun = 3.89423e+00 | step = 3.11e-04 | crit = 1.50e-01 (accepted ✅)
# it 9 | fun = 3.88749e+00 | step = 3.73e-04 | crit = 1.61e-01 (accepted ✅)
# it 10 | fun = 3.87888e+00 | step = 4.48e-04 | crit = 2.00e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 4 : P = 3.84641 W | L = 6.695e-01 mH | lam = -1.202e-01
# ---- Start gradient descent
# it 0 | fun = 3.89414e+00 | step = 1.00e-03
# it 3 | fun = 3.88985e+00 | step = 3.00e-04 | crit = 1.55e-01 (accepted ✅)
# it 4 | fun = 3.88035e+00 | step = 3.60e-04 | crit = 1.34e-01 (accepted ✅)
# it 5 | fun = 3.87054e+00 | step = 4.32e-04 | crit = 1.51e-01 (accepted ✅)
# it 7 | fun = 3.86890e+00 | step = 2.59e-04 | crit = 1.10e-01 (accepted ✅)
# it 8 | fun = 3.86227e+00 | step = 3.11e-04 | crit = 1.26e-01 (accepted ✅)
# it 10 | fun = 3.86109e+00 | step = 1.87e-04 | crit = 8.88e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 5 : P = 3.80412 W | L = 6.159e-01 mH | lam = -1.765e-01
# ---- Start gradient descent
# it 0 | fun = 3.88376e+00 | step = 1.00e-03
# it 2 | fun = 3.87692e+00 | step = 6.00e-04 | crit = 1.54e-01 (accepted ✅)
# it 4 | fun = 3.87488e+00 | step = 3.60e-04 | crit = 1.33e-01 (accepted ✅)
# it 5 | fun = 3.87334e+00 | step = 4.32e-04 | crit = 1.03e-01 (accepted ✅)
# it 7 | fun = 3.87144e+00 | step = 2.59e-04 | crit = 1.01e-01 (accepted ✅)
# it 8 | fun = 3.86982e+00 | step = 3.11e-04 | crit = 6.96e-02 (accepted ✅)
# it 9 | fun = 3.86817e+00 | step = 3.73e-04 | crit = 7.42e-02 (accepted ✅)
# it 10 | fun = 3.86637e+00 | step = 4.48e-04 | crit = 8.27e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 6 : P = 3.77868 W | L = 5.826e-01 mH | lam = -2.437e-01
# ---- Start gradient descent
# it 0 | fun = 3.89584e+00 | step = 1.00e-03
# it 5 | fun = 3.89521e+00 | step = 7.50e-05 | crit = 4.07e-02 (accepted ✅)
# it 8 | fun = 3.89510e+00 | step = 2.25e-05 | crit = 1.77e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 7 : P = 3.77637 W | L = 5.776e-01 mH | lam = -3.185e-01
# ---- Start gradient descent
# it 0 | fun = 3.92828e+00 | step = 1.00e-03
# it 10 | fun = 3.92823e+00 | step = 2.34e-06 | crit = 4.40e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 8 : P = 3.77627 W | L = 5.775e-01 mH | lam = -4.008e-01
# ---- Start gradient descent
# it 0 | fun = 3.96475e+00 | step = 1.00e-03
# it 5 | fun = 3.96451e+00 | step = 7.50e-05 | crit = 1.77e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 9 : P = 3.77681 W | L = 5.791e-01 mH | lam = -4.911e-01
# ---- Start gradient descent
# it 0 | fun = 4.00438e+00 | step = 1.00e-03
# it 4 | fun = 4.00326e+00 | step = 1.50e-04 | crit = 2.85e-02 (accepted ✅)
# it 9 | fun = 4.00314e+00 | step = 1.12e-05 | crit = 1.39e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 10 : P = 3.77979 W | L = 5.863e-01 mH | lam = -5.886e-01
# ---- Start gradient descent
# it 0 | fun = 4.04552e+00 | step = 1.00e-03
# it 10 | fun = 4.04550e+00 | step = 2.34e-06 | crit = 5.32e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 11 : P = 3.77970 W | L = 5.862e-01 mH | lam = -6.960e-01
# ---- Start gradient descent
# it 0 | fun = 4.09214e+00 | step = 1.00e-03
# it 1 | fun = 4.08354e+00 | step = 1.20e-03 | crit = 1.05e-01 (accepted ✅)
# it 9 | fun = 4.08342e+00 | step = 1.12e-05 | crit = 1.51e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 12 : P = 3.79152 W | L = 6.115e-01 mH | lam = -8.068e-01
# ---- Start gradient descent
# it 0 | fun = 4.12864e+00 | step = 1.00e-03
# it 1 | fun = 4.11925e+00 | step = 1.20e-03 | crit = 1.39e-01 (accepted ✅)
# it 4 | fun = 4.11539e+00 | step = 3.60e-04 | crit = 1.08e-01 (accepted ✅)
# it 6 | fun = 4.11383e+00 | step = 2.16e-04 | crit = 1.14e-01 (accepted ✅)
# it 7 | fun = 4.10942e+00 | step = 2.59e-04 | crit = 8.85e-02 (accepted ✅)
# it 9 | fun = 4.10800e+00 | step = 1.56e-04 | crit = 9.32e-02 (accepted ✅)
# it 10 | fun = 4.10499e+00 | step = 1.87e-04 | crit = 6.71e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 13 : P = 3.81419 W | L = 6.618e-01 mH | lam = -9.129e-01
# ---- Start gradient descent
# it 0 | fun = 4.14268e+00 | step = 1.00e-03
# it 1 | fun = 4.12323e+00 | step = 1.20e-03 | crit = 1.83e-01 (accepted ✅)
# it 4 | fun = 4.12011e+00 | step = 3.60e-04 | crit = 1.33e-01 (accepted ✅)
# it 5 | fun = 4.11297e+00 | step = 4.32e-04 | crit = 1.55e-01 (accepted ✅)
# it 8 | fun = 4.10710e+00 | step = 1.30e-04 | crit = 1.25e-01 (accepted ✅)
# it 9 | fun = 4.10444e+00 | step = 1.56e-04 | crit = 9.15e-02 (accepted ✅)
# it 10 | fun = 4.10005e+00 | step = 1.87e-04 | crit = 8.54e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 14 : P = 3.84305 W | L = 7.321e-01 mH | lam = -1.005e+00
# ---- Start gradient descent
# it 0 | fun = 4.12608e+00 | step = 1.00e-03
# it 1 | fun = 4.09202e+00 | step = 1.20e-03 | crit = 2.41e-01 (accepted ✅)
# it 5 | fun = 4.08470e+00 | step = 1.80e-04 | crit = 1.54e-01 (accepted ✅)
# it 6 | fun = 4.07692e+00 | step = 2.16e-04 | crit = 1.17e-01 (accepted ✅)
# it 7 | fun = 4.06778e+00 | step = 2.59e-04 | crit = 1.29e-01 (accepted ✅)
# it 8 | fun = 4.05961e+00 | step = 3.11e-04 | crit = 1.49e-01 (accepted ✅)
# it 9 | fun = 4.04413e+00 | step = 3.73e-04 | crit = 1.64e-01 (accepted ✅)
# it 10 | fun = 4.02044e+00 | step = 4.48e-04 | crit = 2.01e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 15 : P = 3.90687 W | L = 8.894e-01 mH | lam = -1.047e+00
# ---- Start gradient descent
# it 0 | fun = 4.02532e+00 | step = 1.00e-03
# it 3 | fun = 4.01740e+00 | step = 3.00e-04 | crit = 2.03e-01 (accepted ✅)
# it 4 | fun = 3.99849e+00 | step = 3.60e-04 | crit = 2.34e-01 (accepted ✅)
# it 6 | fun = 3.97814e+00 | step = 2.16e-04 | crit = 2.64e-01 (accepted ✅)
# it 7 | fun = 3.95868e+00 | step = 2.59e-04 | crit = 1.96e-01 (accepted ✅)
# it 8 | fun = 3.94106e+00 | step = 3.11e-04 | crit = 2.19e-01 (accepted ✅)
# it 9 | fun = 3.91719e+00 | step = 3.73e-04 | crit = 2.72e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 16 : P = 3.96838 W | L = 1.049e+00 mH | lam = -1.027e+00
# ---- Start gradient descent
# it 0 | fun = 3.91826e+00 | step = 1.00e-03
# it 3 | fun = 3.90206e+00 | step = 3.00e-04 | crit = 3.61e-01 (accepted ✅)
# it 4 | fun = 3.87348e+00 | step = 3.60e-04 | crit = 3.01e-01 (accepted ✅)
# it 6 | fun = 3.85039e+00 | step = 2.16e-04 | crit = 2.95e-01 (accepted ✅)
# it 7 | fun = 3.82029e+00 | step = 2.59e-04 | crit = 2.58e-01 (accepted ✅)
# it 8 | fun = 3.79790e+00 | step = 3.11e-04 | crit = 3.07e-01 (accepted ✅)
# it 9 | fun = 3.77831e+00 | step = 3.73e-04 | crit = 3.52e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 17 : P = 4.02199 W | L = 1.251e+00 mH | lam = -9.113e-01
# ---- Start gradient descent
# it 0 | fun = 3.80882e+00 | step = 1.00e-03
# it 3 | fun = 3.76427e+00 | step = 3.00e-04 | crit = 4.92e-01 (accepted ✅)
# it 4 | fun = 3.75017e+00 | step = 3.60e-04 | crit = 3.52e-01 (accepted ✅)
# it 6 | fun = 3.70095e+00 | step = 2.16e-04 | crit = 4.42e-01 (accepted ✅)
# it 7 | fun = 3.66786e+00 | step = 2.59e-04 | crit = 3.29e-01 (accepted ✅)
# it 9 | fun = 3.62488e+00 | step = 1.56e-04 | crit = 3.59e-01 (accepted ✅)
# it 10 | fun = 3.58033e+00 | step = 1.87e-04 | crit = 2.81e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 18 : P = 3.92898 W | L = 1.435e+00 mH | lam = -6.914e-01
# ---- Start gradient descent
# it 0 | fun = 3.68079e+00 | step = 1.00e-03
# it 4 | fun = 3.66062e+00 | step = 1.50e-04 | crit = 2.59e-01 (accepted ✅)
# it 5 | fun = 3.63650e+00 | step = 1.80e-04 | crit = 2.73e-01 (accepted ✅)
# it 7 | fun = 3.60542e+00 | step = 1.08e-04 | crit = 2.90e-01 (accepted ✅)
# it 8 | fun = 3.57344e+00 | step = 1.30e-04 | crit = 2.34e-01 (accepted ✅)
# it 9 | fun = 3.54127e+00 | step = 1.56e-04 | crit = 2.73e-01 (accepted ✅)
# it 10 | fun = 3.50331e+00 | step = 1.87e-04 | crit = 3.26e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 19 : P = 3.91628 W | L = 1.997e+00 mH | lam = -1.371e-01
# ---- Start gradient descent
# it 0 | fun = 4.08354e+00 | step = 1.00e-03
# it 4 | fun = 4.00278e+00 | step = 1.50e-04 | crit = 5.04e-01 (accepted ✅)
# it 5 | fun = 3.96654e+00 | step = 1.80e-04 | crit = 4.67e-01 (accepted ✅)
# it 7 | fun = 3.94431e+00 | step = 1.08e-04 | crit = 2.66e-01 (accepted ✅)
# it 8 | fun = 3.93262e+00 | step = 1.30e-04 | crit = 2.57e-01 (accepted ✅)
# it 10 | fun = 3.92290e+00 | step = 7.78e-05 | crit = 1.57e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 20 : P = 3.90271 W | L = 1.565e+00 mH | lam = 2.085e-01
# ---- Start gradient descent
# it 0 | fun = 4.12799e+00 | step = 1.00e-03
# it 1 | fun = 3.97525e+00 | step = 1.20e-03 | crit = 8.56e-01 (accepted ✅)
# it 5 | fun = 3.95016e+00 | step = 1.80e-04 | crit = 2.69e-01 (accepted ✅)
# it 6 | fun = 3.94297e+00 | step = 2.16e-04 | crit = 1.78e-01 (accepted ✅)
# it 8 | fun = 3.93302e+00 | step = 1.30e-04 | crit = 1.68e-01 (accepted ✅)
# it 9 | fun = 3.92646e+00 | step = 1.56e-04 | crit = 1.27e-01 (accepted ✅)
# it 10 | fun = 3.92034e+00 | step = 1.87e-04 | crit = 1.40e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 21 : P = 3.90288 W | L = 1.075e+00 mH | lam = 2.588e-01
# ---- Start gradient descent
# it 0 | fun = 3.92428e+00 | step = 1.00e-03
# it 4 | fun = 3.91973e+00 | step = 1.50e-04 | crit = 1.40e-01 (accepted ✅)
# it 5 | fun = 3.91198e+00 | step = 1.80e-04 | crit = 1.47e-01 (accepted ✅)
# it 7 | fun = 3.90854e+00 | step = 1.08e-04 | crit = 1.11e-01 (accepted ✅)
# it 8 | fun = 3.90364e+00 | step = 1.30e-04 | crit = 1.07e-01 (accepted ✅)
# it 9 | fun = 3.89796e+00 | step = 1.56e-04 | crit = 1.12e-01 (accepted ✅)
# it 10 | fun = 3.89191e+00 | step = 1.87e-04 | crit = 1.17e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 22 : P = 3.89656 W | L = 9.816e-01 mH | lam = 2.452e-01
# ---- Start gradient descent
# it 0 | fun = 3.89218e+00 | step = 1.00e-03
# it 4 | fun = 3.88766e+00 | step = 1.50e-04 | crit = 1.09e-01 (accepted ✅)
# it 5 | fun = 3.88316e+00 | step = 1.80e-04 | crit = 1.14e-01 (accepted ✅)
# it 7 | fun = 3.88019e+00 | step = 1.08e-04 | crit = 9.80e-02 (accepted ✅)
# it 8 | fun = 3.87634e+00 | step = 1.30e-04 | crit = 9.37e-02 (accepted ✅)
# it 9 | fun = 3.87536e+00 | step = 1.56e-04 | crit = 9.81e-02 (accepted ✅)
# it 10 | fun = 3.87078e+00 | step = 1.87e-04 | crit = 1.04e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 23 : P = 3.88972 W | L = 9.090e-01 mH | lam = 1.711e-01
# ---- Start gradient descent
# it 0 | fun = 3.87786e+00 | step = 1.00e-03
# it 2 | fun = 3.87055e+00 | step = 6.00e-04 | crit = 1.63e-01 (accepted ✅)
# it 5 | fun = 3.86518e+00 | step = 1.80e-04 | crit = 1.52e-01 (accepted ✅)
# it 6 | fun = 3.86212e+00 | step = 2.16e-04 | crit = 1.07e-01 (accepted ✅)
# it 8 | fun = 3.85653e+00 | step = 1.30e-04 | crit = 1.17e-01 (accepted ✅)
# it 9 | fun = 3.85427e+00 | step = 1.56e-04 | crit = 7.71e-02 (accepted ✅)
# it 10 | fun = 3.85129e+00 | step = 1.87e-04 | crit = 8.30e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 24 : P = 3.86752 W | L = 8.247e-01 mH | lam = 1.411e-02
# ---- Start gradient descent
# it 0 | fun = 3.88018e+00 | step = 1.00e-03
# it 4 | fun = 3.87924e+00 | step = 1.50e-04 | crit = 5.19e-02 (accepted ✅)
# it 7 | fun = 3.87903e+00 | step = 4.50e-05 | crit = 3.59e-02 (accepted ✅)
# it 8 | fun = 3.87887e+00 | step = 5.40e-05 | crit = 3.12e-02 (accepted ✅)
# it 10 | fun = 3.87863e+00 | step = 3.24e-05 | crit = 2.36e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 25 : P = 3.86410 W | L = 8.133e-01 mH | lam = -1.698e-01
# ---- Start gradient descent
# it 0 | fun = 3.91467e+00 | step = 1.00e-03
# it 5 | fun = 3.91361e+00 | step = 7.50e-05 | crit = 4.60e-02 (accepted ✅)
# it 9 | fun = 3.91344e+00 | step = 1.12e-05 | crit = 1.42e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 26 : P = 3.86576 W | L = 8.212e-01 mH | lam = -3.635e-01
# ---- Start gradient descent
# it 0 | fun = 3.94982e+00 | step = 1.00e-03
# it 5 | fun = 3.94759e+00 | step = 7.50e-05 | crit = 5.65e-02 (accepted ✅)
# it 6 | fun = 3.94654e+00 | step = 9.00e-05 | crit = 5.18e-02 (accepted ✅)
# it 8 | fun = 3.94575e+00 | step = 5.40e-05 | crit = 4.04e-02 (accepted ✅)
# it 9 | fun = 3.94403e+00 | step = 6.48e-05 | crit = 4.35e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 27 : P = 3.87125 W | L = 8.411e-01 mH | lam = -5.529e-01
# ---- Start gradient descent
# it 0 | fun = 3.97561e+00 | step = 1.00e-03
# it 3 | fun = 3.97294e+00 | step = 3.00e-04 | crit = 1.55e-01 (accepted ✅)
# it 5 | fun = 3.96601e+00 | step = 1.80e-04 | crit = 1.82e-01 (accepted ✅)
# it 6 | fun = 3.95511e+00 | step = 2.16e-04 | crit = 1.12e-01 (accepted ✅)
# it 7 | fun = 3.95274e+00 | step = 2.59e-04 | crit = 1.26e-01 (accepted ✅)
# it 8 | fun = 3.94489e+00 | step = 3.11e-04 | crit = 1.70e-01 (accepted ✅)
# it 10 | fun = 3.93299e+00 | step = 1.87e-04 | crit = 2.05e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 28 : P = 3.88824 W | L = 9.256e-01 mH | lam = -6.504e-01
# ---- Start gradient descent
# it 0 | fun = 3.94060e+00 | step = 1.00e-03
# it 3 | fun = 3.93430e+00 | step = 3.00e-04 | crit = 1.91e-01 (accepted ✅)
# it 5 | fun = 3.92021e+00 | step = 1.80e-04 | crit = 2.25e-01 (accepted ✅)
# it 6 | fun = 3.90837e+00 | step = 2.16e-04 | crit = 1.46e-01 (accepted ✅)
# it 7 | fun = 3.90169e+00 | step = 2.59e-04 | crit = 1.75e-01 (accepted ✅)
# it 9 | fun = 3.89153e+00 | step = 1.56e-04 | crit = 1.47e-01 (accepted ✅)
# it 10 | fun = 3.88493e+00 | step = 1.87e-04 | crit = 1.54e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 29 : P = 3.89867 W | L = 1.022e+00 mH | lam = -6.192e-01
# ---- Start gradient descent
# it 0 | fun = 3.88564e+00 | step = 1.00e-03
# it 4 | fun = 3.87671e+00 | step = 1.50e-04 | crit = 1.45e-01 (accepted ✅)
# it 5 | fun = 3.87266e+00 | step = 1.80e-04 | crit = 1.73e-01 (accepted ✅)
# it 6 | fun = 3.86835e+00 | step = 2.16e-04 | crit = 1.77e-01 (accepted ✅)
# it 8 | fun = 3.85765e+00 | step = 1.30e-04 | crit = 1.96e-01 (accepted ✅)
# it 9 | fun = 3.84987e+00 | step = 1.56e-04 | crit = 1.50e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 30 : P = 3.91693 W | L = 1.130e+00 mH | lam = -4.130e-01
# ---- Start gradient descent
# it 0 | fun = 3.87800e+00 | step = 1.00e-03
# it 4 | fun = 3.87048e+00 | step = 1.50e-04 | crit = 1.92e-01 (accepted ✅)
# it 6 | fun = 3.86792e+00 | step = 9.00e-05 | crit = 8.47e-02 (accepted ✅)
# it 9 | fun = 3.86691e+00 | step = 2.70e-05 | crit = 5.23e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 31 : P = 3.90305 W | L = 1.116e+00 mH | lam = -2.109e-01
# ---- Start gradient descent
# it 0 | fun = 3.89150e+00 | step = 1.00e-03
# it 6 | fun = 3.89023e+00 | step = 3.75e-05 | crit = 5.51e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 32 : P = 3.90180 W | L = 1.106e+00 mH | lam = -8.257e-03
# ---- Start gradient descent
# it 0 | fun = 3.91269e+00 | step = 1.00e-03
# it 5 | fun = 3.91034e+00 | step = 7.50e-05 | crit = 8.89e-02 (accepted ✅)
# it 6 | fun = 3.90780e+00 | step = 9.00e-05 | crit = 7.64e-02 (accepted ✅)
# it 7 | fun = 3.90652e+00 | step = 1.08e-04 | crit = 8.41e-02 (accepted ✅)
# it 8 | fun = 3.90443e+00 | step = 1.30e-04 | crit = 1.02e-01 (accepted ✅)
# it 10 | fun = 3.90272e+00 | step = 7.78e-05 | crit = 8.51e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 33 : P = 3.90074 W | L = 1.047e+00 mH | lam = 9.178e-02
# ---- Start gradient descent
# it 0 | fun = 3.90770e+00 | step = 1.00e-03
# it 2 | fun = 3.89977e+00 | step = 6.00e-04 | crit = 2.00e-01 (accepted ✅)
# it 5 | fun = 3.89468e+00 | step = 1.80e-04 | crit = 1.60e-01 (accepted ✅)
# it 7 | fun = 3.89246e+00 | step = 1.08e-04 | crit = 1.01e-01 (accepted ✅)
# it 8 | fun = 3.89163e+00 | step = 1.30e-04 | crit = 7.08e-02 (accepted ✅)
# it 10 | fun = 3.89092e+00 | step = 7.78e-05 | crit = 6.72e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 34 : P = 3.89274 W | L = 9.611e-01 mH | lam = 1.317e-03
# ---- Start gradient descent
# it 0 | fun = 3.89462e+00 | step = 1.00e-03
# it 5 | fun = 3.89372e+00 | step = 7.50e-05 | crit = 5.99e-02 (accepted ✅)
# it 7 | fun = 3.89343e+00 | step = 4.50e-05 | crit = 4.23e-02 (accepted ✅)
# it 8 | fun = 3.89332e+00 | step = 5.40e-05 | crit = 2.45e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 35 : P = 3.89182 W | L = 9.652e-01 mH | lam = -8.765e-02
# ---- Start gradient descent
# it 0 | fun = 3.89657e+00 | step = 1.00e-03
# it 5 | fun = 3.89631e+00 | step = 7.50e-05 | crit = 2.50e-02 (accepted ✅)
# it 7 | fun = 3.89609e+00 | step = 4.50e-05 | crit = 4.33e-02 (accepted ✅)
# it 9 | fun = 3.89601e+00 | step = 2.70e-05 | crit = 1.76e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 36 : P = 3.89308 W | L = 9.759e-01 mH | lam = -1.555e-01
# ---- Start gradient descent
# it 0 | fun = 3.89773e+00 | step = 1.00e-03
# it 2 | fun = 3.89419e+00 | step = 6.00e-04 | crit = 9.86e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 37 : P = 3.89759 W | L = 1.032e+00 mH | lam = -5.651e-02
# ---- Start gradient descent
# it 0 | fun = 3.89752e+00 | step = 1.00e-03
# it 6 | fun = 3.89729e+00 | step = 3.75e-05 | crit = 4.51e-02 (accepted ✅)
# it 7 | fun = 3.89691e+00 | step = 4.50e-05 | crit = 3.33e-02 (accepted ✅)
# it 8 | fun = 3.89636e+00 | step = 5.40e-05 | crit = 3.50e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 38 : P = 3.89683 W | L = 1.015e+00 mH | lam = -4.637e-03
# ---- Start gradient descent
# it 0 | fun = 3.89719e+00 | step = 1.00e-03
# it 6 | fun = 3.89662e+00 | step = 3.75e-05 | crit = 4.06e-02 (accepted ✅)
# it 7 | fun = 3.89639e+00 | step = 4.50e-05 | crit = 3.67e-02 (accepted ✅)
# it 8 | fun = 3.89590e+00 | step = 5.40e-05 | crit = 3.87e-02 (accepted ✅)
# it 9 | fun = 3.89566e+00 | step = 6.48e-05 | crit = 4.54e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 39 : P = 3.89567 W | L = 1.001e+00 mH | lam = 4.157e-04
# ---- Start gradient descent
# it 0 | fun = 3.89567e+00 | step = 1.00e-03
# it 6 | fun = 3.89506e+00 | step = 3.75e-05 | crit = 3.86e-02 (accepted ✅)
# it 7 | fun = 3.89490e+00 | step = 4.50e-05 | crit = 2.83e-02 (accepted ✅)
# it 9 | fun = 3.89481e+00 | step = 2.70e-05 | crit = 2.18e-02 (accepted ✅)
# it 10 | fun = 3.89447e+00 | step = 3.24e-05 | crit = 2.31e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 40 : P = 3.89418 W | L = 9.879e-01 mH | lam = -4.945e-02
# ---- Start gradient descent
# it 0 | fun = 3.89511e+00 | step = 1.00e-03
# it 6 | fun = 3.89504e+00 | step = 3.75e-05 | crit = 1.28e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 41 : P = 3.89412 W | L = 9.880e-01 mH | lam = -1.039e-01
# ---- Start gradient descent
# it 0 | fun = 3.89573e+00 | step = 1.00e-03
# it 6 | fun = 3.89555e+00 | step = 3.75e-05 | crit = 1.66e-02 (accepted ✅)
# it 8 | fun = 3.89538e+00 | step = 2.25e-05 | crit = 1.49e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 42 : P = 3.89470 W | L = 9.943e-01 mH | lam = -1.324e-01
# ---- Start gradient descent
# it 0 | fun = 3.89555e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 43 : P = 3.89470 W | L = 9.943e-01 mH | lam = -1.637e-01
# ---- Start gradient descent
# it 0 | fun = 3.89573e+00 | step = 1.00e-03
# it 4 | fun = 3.89544e+00 | step = 1.50e-04 | crit = 4.61e-02 (accepted ✅)
# it 7 | fun = 3.89526e+00 | step = 4.50e-05 | crit = 3.36e-02 (accepted ✅)
# it 9 | fun = 3.89492e+00 | step = 2.70e-05 | crit = 3.02e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 44 : P = 3.89563 W | L = 1.005e+00 mH | lam = -1.351e-01
# ---- Start gradient descent
# it 0 | fun = 3.89507e+00 | step = 1.00e-03
# it 10 | fun = 3.89505e+00 | step = 2.34e-06 | crit = 2.77e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 45 : P = 3.89553 W | L = 1.004e+00 mH | lam = -1.088e-01
# ---- Start gradient descent
# it 0 | fun = 3.89516e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 46 : P = 3.89553 W | L = 1.004e+00 mH | lam = -7.985e-02
# ---- Start gradient descent
# it 0 | fun = 3.89528e+00 | step = 1.00e-03
# it 9 | fun = 3.89525e+00 | step = 4.69e-06 | crit = 9.41e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 47 : P = 3.89546 W | L = 1.003e+00 mH | lam = -5.517e-02
# ---- Start gradient descent
# it 0 | fun = 3.89533e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 48 : P = 3.89546 W | L = 1.003e+00 mH | lam = -2.803e-02
# ---- Start gradient descent
# it 0 | fun = 3.89541e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 49 : P = 3.89546 W | L = 1.003e+00 mH | lam = 1.826e-03
# ---- Start gradient descent
# it 0 | fun = 3.89551e+00 | step = 1.00e-03
# it 8 | fun = 3.89542e+00 | step = 9.37e-06 | crit = 1.97e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# Final design : P = 3.89541 W | L = 1.001 mH

# %% [markdown]
# We plot the convergence and optimized design:

# %%
ax1 = plt.plot(P_list, color = 'b')   
plt.ylabel('AC losses (W)', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.plot(np.array(L_list)*1000, color = 'r')
plt.ylabel("Inductance (mH)", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5.d - Scipy version
#
# We probably get a local optima.

# %%
from scipy.optimize import minimize, NonlinearConstraint, Bounds

cons_scipy = NonlinearConstraint(cons, lb = -1e-3, ub = 1e-3, jac = dCons)
options = {"maxiter" : 100,
           "ftol" : 1e-3, 
           "disp" : True
          }

bounds = Bounds(lb = lbound, ub = ubound, keep_feasible=True)
results_scipy = minimize(obj, x0, jac=dObj,
                       bounds=bounds,
                       constraints=cons_scipy,
                       options = options, 
                       method="SLSQP")
x_scipy = results_scipy["x"]
# Out:
# c:\Users\SESA811965\AppData\Local\miniforge3\envs\ngenv\Lib\site-packages\scipy\optimize\_slsqp_py.py:435: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8952849380727064
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1

# %%
print(f"{results_scipy}")
print(f"Final design (Scipy) : P = {results_scipy["fun"]:.5f} W | L = {(cons(x_scipy)/scale + L0)*1000 :.3f} mH")
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 3.8952849380727064
#        x: [ 1.260e-03  1.395e-02  1.395e-02  1.395e-02  1.395e-02
#             1.395e-02  1.395e-02  1.395e-02  2.609e-03]
#      nit: 1
#      jac: [-1.904e+01 -1.766e+01 -2.674e+01 -8.016e+01 -1.005e+02
#            -3.387e+01 -8.047e+00 -6.601e+00 -1.940e+01]
#     nfev: 6
#     njev: 1
# Final design (Scipy) : P = 3.89528 W | L = 1.001 mH

# %%
if regularize_symmetry_axis :x_scipy_bis = [x_scipy[0]] + list(x_scipy)

Draw(materials_regions, gen_meshN(x_scipy_bis)[0] )
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene
