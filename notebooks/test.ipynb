# %% [markdown]
# # Ceci est un test

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 6, 200)
Y = np.cos(X   ** 2) ** 2

plt.plot(X,      Y, "--")

# %%
X = np.linspace(0, 0.5, 200)
Y = X**3 * np.sin(1/ X**3)

plt.plot(X, Y, "--")
# Out:
# /tmp/ipykernel_5640/2724053745.py:2: RuntimeWarning: divide by zero encountered in divide
#   Y = X**3 * np.sin(1/ X**3)
# /tmp/ipykernel_5640/2724053745.py:2: RuntimeWarning: invalid value encountered in sin
#   Y = X**3 * np.sin(1/ X**3)
