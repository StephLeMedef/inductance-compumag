# %% [markdown]
# # III - Gradient-based design optimization with control points
#
# - **Parametric optimization** is not incompatible with gradient optimization.
# - The derivatives can be evaluated using **finite differences**, but this requires at least as many additional function evaluations as the number of parameters $N$. With many parameters (say $N>10$), using finite difference becomes **really costly**, especially when evaluating the function requires solving finite element problems.
# - Thanks to mathematical tools such as shape derivative and adjoint method, the derivatives can be evaluated efficiently with only $1$ additional resolution of a linear finite element problem per function to derivate (so-called adjoint).

# %%
from shapeOptInductor import gen_meshN, Id
import ngsolve as ngs
from ngsolve.webgui import Draw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, we set up the number of control points (with adjoint method, computation time is almost independant of the number of parameters).

# %%
##############################################
NControlPoints = 30 # can be changed
##############################################
print(f"{NControlPoints = }")
# Out:
# NControlPoints = 30

# %% [markdown]
# ___________________________
# ## 1 - Geometry and meshing
#
# Then, we define the inductor geometry and generate the mesh.

# %%
# Geometric parameters
lz = 1e-2               # z-thickness of the inductor  
s = 4                   # symmetry factor (model 1/4th of the total space)

# Mesh generation
airgap = 4.11e-3 * np.ones(NControlPoints)              # Array of y-coordinates of control points along the airgap
maxh = 2e-3                                             # Maximum size of mesh element
mesh, p1, p2 = gen_meshN(airgap, maxh)                  # Generate the mesh and return the coordinates of control points on the first and second leg
xAirgaps = [p[0] for p in p1] + [p[0] for p in p2]      # Extract the x-coordinates of the control points

# Define the characteristics functions
XiAir = mesh.MaterialCF({"air": 1})
XiCore = mesh.MaterialCF({"core": 1})
XiCoil = mesh.MaterialCF({"coil": 1})
materials_regions = 1 * XiAir + 2 * XiCoil + 3 * XiCore

# Draw the geometry and mesh
Draw(materials_regions, mesh, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 2 - State problem (time-harmonic magnetics)
#
# ### 2.a - Parameters definition
#
# We describe the magnetic permeabilities and the source currents.

# %%
# Electric current (assumed sinusoidal)
f = 5e4                                                         # Working frequency (Hz)
omega = 2 * np.pi * f                                           # rad/s
nb_turn = 200                                                   # Number of turn in the coil (no unit)
I = 2                                                           # Amplitude of the source current (A)
j = nb_turn / 2 * I / (ngs.Integrate(XiCoil, mesh)) * XiCoil    # Amplitude of the source current density  (A/m²)

# Magnetic permeabilities
mu0 = 4e-7 * np.pi                                              # Void permeability (H/m)
mur = 1000                                                      # Relative permeability of iron (no unit)
mu_iron = mur * mu0                                             # Iron permeability (H/m)
delta = 0.1                                                     # Loss angle associated with the coil (rad)
mu_coil = np.exp(-1j * delta) * mu0                             # Complex permeability of the coil

# %% [markdown]
# ### 2.b - Definition of the time-harmonic magnetics problem
#
# Then we can write the weak formulation and solve the following problem :
# $$\text{Find } \underline{a_h} \in H := \{\underline{a} \in H^1(\Omega) |\, \underline{a} = 0 \text{ on } \Gamma_D\} \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H, \int_\Omega \underline{\nu_h} (\nabla \underline{a_h}) \cdot (\nabla \underline{v})^* \,\mathrm{d}x = \int_{\Omega_{c, h}} j \underline{v}^* \, \mathrm{d}x. $$

# %%
def magWeakFormComplex(ah : ngs.FESpace.TrialFunction, 
                       v  : ngs.FESpace.TestFunction
                       ) -> tuple[ngs.BilinearForm, ngs.LinearForm]:
    """Return the sybolic weak form of the magnetic problem, 
    i.e, bilinear and linear forms (not assembled yet)."""

    # Bilinear form (transmission)
    bf =  1 / mu_iron * ngs.grad(ah) * ngs.grad(v) * ngs.dx("core")
    bf += 1 / mu_coil * ngs.grad(ah) * ngs.grad(v) * ngs.dx("coil")
    bf += 1 / mu0 * ngs.grad(ah) * ngs.grad(v) * ngs.dx("air")

    # Linear form (source)
    lf = j * v * ngs.dx("coil")

    return bf, lf


def solveStateComplex(mesh : ngs.Mesh
                      ) -> tuple[ngs.GridFunction, ngs.la.BaseMatrix]:
    """ Solve the time-harmonic magnetics problem """

    # Definition of function space
    fes = ngs.H1(mesh, order=1, dirichlet="arc|domainVert", complex=True)
    a, v = fes.TnT()

    # Definition of weak form
    bf, f = magWeakFormComplex(a, v)

    # Assembly
    K = ngs.BilinearForm(bf).Assemble()
    F = ngs.LinearForm(f).Assemble()

    # Solving
    gf = ngs.GridFunction(fes)
    Kinv = K.mat.Inverse(freedofs=fes.FreeDofs())
    gf.vec.data = Kinv * F.vec

    return gf, Kinv  # returning Kinv speed up adjoint calculation

# Example :
state, Kinv = solveStateComplex(mesh)
Draw(state.real, mesh, radius=0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 2.c - Definition of the post-processed quantities
#
# We define the losses and inductance
# $$
# \begin{array}{lcl}
# P(\underline{a}) &=& \displaystyle  s l_z  \pi f \int_{\Omega_c} \text{Im} \left( \frac{1}{\underline{\mu_c}} \right ) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# L(\underline{a}) &=& \displaystyle \frac{s l_z}{I^2} \int_\Omega \text{Re} \left( \underline{\nu} \right) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# \end{array}$$
#
# with their directional derivatives.

# %%
def L(state : ngs.GridFunction, 
      mesh : ngs.Mesh
      ) -> float:
    """ Compute inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return s * lz / (I**2) * ngs.Integrate(nu.real * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddL(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of the inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return 2 * s * lz / (I**2) * ngs.InnerProduct(nu.real * ngs.grad(state), ngs.grad(v)) * ngs.dx


def P(state : ngs.GridFunction,
      mesh : ngs.Mesh
      ) -> float:
    """ Compute AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return s * np.pi * f * lz * ngs.Integrate(nu.imag * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddP(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return 2 * s * np.pi * f * lz * ngs.InnerProduct(nu.imag * ngs.grad(state), ngs.grad(v)) * ngs.dx

# Example :
print(f"Inductance : {L(state, mesh) *1000:.3} mH")
print(f"Losses : {P(state, mesh):.3} W")
# Out:
# Inductance : 1.0 mH
# Losses : 13.2 W

# %% [markdown]
# ___________________________
# ## 3 - Adjoint problem
#
# The adjoint method is an efficient way to compute derivatives of PDE-constrained problem; it requires solving one linear auxiliary problem per function $f$ to derivate that reads
#
# $$ \text{Find } \underline{p}_f \in H \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H,  \quad \int_\Omega \nabla \underline{p}_f \cdot \underline{\nu}^* \nabla \underline{v} \; \mathrm{d}x = \int f'(\underline{a})(\underline{v})\; \mathrm{d}x, $$
#
# with $f'$ the directional derivative of $f$, such that $F(\underline{a}) = \int_\Omega f(\underline{a}) \; \mathrm{d}x$.

# %%
def solveAdjoint(state : ngs.GridFunction,      
                 df : ngs.comp.SumOfIntegrals,
                 Kinv : ngs.la.BaseMatrix
                 ) -> ngs.GridFunction:
    """Solve the adjoint equation for a given directional derivative (right-hand side)"""

    fes = state.space
    v = fes.TestFunction()

    # Assemble the right-hand side
    f = ngs.LinearForm(-1. * df(state, v)).Assemble()
    
    # Solve using the adjoint (transconjugate) of provided FEM matrix
    gf = ngs.GridFunction(fes)
    gf.vec.data = Kinv.H * f.vec

    return gf

# Example :
adjoint_P = solveAdjoint(state, ddP, Kinv)
Draw(adjoint_P.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})

adjoint_L = solveAdjoint(state, ddL, Kinv)
Draw(adjoint_L.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 4 - Continuous and discretized shape derivatives
#
# ### 4.a - Continuous expressions
#
# The shape derivative of the losses is a linear form obtained by Céa's method that reads
# $$\mathrm{d} P(\Omega)(\phi) = \text{Re}\left( s l_z \pi f \int_{\Omega_c} \text{Im}\left(\frac{1}{\underline{\mu_c}}\right) A_\phi \nabla \underline a \cdot (\nabla \underline a)^* \; \mathrm{d} x + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_P^* \mathrm{d} x - \int_{\Omega_c} j\, \text{div} \phi\, \underline p_P^*  \mathrm{d} x \right)  $$
#
# with $\phi\in W^{1, \infty}(\mathbb{R}^2, \mathbb{R}^2)$ and $A_\phi = \text{div} \phi \, I_2 - \nabla \phi - \nabla \phi^\top$.

# %%
def sdP(state : ngs.GridFunction,
        adjoint_P : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) of the AC losses inside the coil """

    # Finite element spaces
    mesh = state.space.mesh
    FESReal = ngs.VectorH1(mesh)
    FEScomplex = ngs.VectorH1(mesh, complex=True)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_losses = s * np.pi * f * lz * (1 / mu_coil).imag
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_losses * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx("coil")
    shape_derivative_cplx += -j * XiCoil * ngs.div(phi) * adjoint_P * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_P)) * ngs.dx
    shape_derivative_cplx.Assemble()

    # Take the real part
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# Similarly, computing the shape derivative of the inductance leads to
#
# $$
#  \mathrm{d}  L(\Omega)(\phi) =  \text{Re}\left( \frac{s l_z}{I^2} \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot (\nabla \underline a)^* \; \mathrm{d} x  + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_L^* \mathrm{d} x - \int_{\Omega_c} j\,\text{div} \phi\, \underline p_L^*  \mathrm{d} x \right)
# $$

# %%
def sdL(state : ngs.GridFunction,
        adjoint_L : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) for the inductance"""

    # Finite element spaces
    mesh = state.space.mesh
    FEScomplex = ngs.H1(mesh, complex = True)**2 #ngs.VectorH1(mesh, complex=True)
    FESReal = ngs.H1(mesh)**2 # ngs.VectorH1(mesh)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_induc = s * lz / (I**2) * nu.real
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative 
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_induc * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx
    shape_derivative_cplx += -j * ngs.div(phi) * adjoint_L * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_L)) * ngs.dx
    shape_derivative_cplx.Assemble()
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# ### 4.b - Discrete shape derivatives
# - The shape derivative is a **linear form**, from which we can extract a **descent direction**.
# - At the discrete level, one possibility is to extract directly the **nodal coefficients** from the assembled linear form, which is a vector.
#     - It represents the derivative of the losses with respect to the **coordinates of the mesh nodes**. In a sense, it represents the **shape gradient** of the discretized model.
#     - It takes the form of a nodal vector field, indicating in which direction one should move every node of the mesh to increase $f$ maximally.
# - We can therefore plot it, as below. It is almost 0 everywhere (should be exactly 0 up to the discretization errors), except on the **edges** of the geometry.
#     - Indeed, displacing a node at an interface modify the material distribution, which impacts the value of the scalar function, while moving a point from the inside doesn't change the geometry.
# - The **correctness** of the point-wise values of the discretized shape derivative can therefore be checked by **finite difference**, which is the purpose of the last section.

# %%
# Nodal identification of the shape derivative of the losses:
sdP_linear_form = sdP(state, adjoint_P)
discrete_shape_gradient_P = ngs.GridFunction(sdP_linear_form.space)
discrete_shape_gradient_P.vec.data = sdP_linear_form.vec
Draw(discrete_shape_gradient_P, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %%
# Nodal identification of the shape derivative of the inductance:
sdL_linear_form = sdL(state, adjoint_L)
discrete_shape_gradient_L = ngs.GridFunction(sdL_linear_form.space)
discrete_shape_gradient_L.vec.data = sdL_linear_form.vec
Draw(discrete_shape_gradient_L, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 4.c - Sensitivities with respect to the control points
#
# The sensitivities with respect to the $y$-coordinate of the control points (i.e., the first order derivatives of the quantity of interest) are simply obtained by taking the scalar product of the discretized shape derivative with a displacement field induced by the displacement of the control points.
#
# To obtain the true derivative, the displacement of the control point should be unitary. In the literature, this displacement can also be called a "velocity" because it can be used as a descent direction, transporting the geometry through a pseudo-time that are iterations of the algorithm. It is also possible (rather recommended) to use other descent direction using a regularization.

# %%
from shapeOptInductor import referenceVelocity

def sensitivities_y_control_points(state : ngs.GridFunction,
               adjoint : ngs.GridFunction,
               shape_derivative : callable,
               x_airgap : list[float]) -> list[float]:
    """ Compute the sensitivities of a function with respect to the y-value of the control points """

    velocityFields = referenceVelocity(state.space.mesh, x_airgap)
    sd_linearform = shape_derivative(state, adjoint)
    sd_discretized = ngs.GridFunction(ngs.VectorH1(state.space.mesh))
    sd_discretized.vec.FV().NumPy()[:] = np.real(sd_linearform.vec.FV().NumPy()[:])
    sensitivities = [ ngs.InnerProduct(sd_discretized.vec, refVelocity.vec) for refVelocity in velocityFields]
    return sensitivities

# Example:
sensitivities_P = sensitivities_y_control_points(state, adjoint_P, sdP, xAirgaps)
sensitivities_L = sensitivities_y_control_points(state, adjoint_L, sdL, xAirgaps)

print("dL/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_P) + " ]")
print("dP/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_L) + " ]")
# Out:
# dL/dy = [ 4.567e+01, 9.130e+01, 9.118e+01, 9.094e+01, 9.050e+01, 8.973e+01, 8.836e+01, 8.593e+01, 8.172e+01, 7.409e+01, 5.935e+01, 2.956e+01, -4.271e+01, -4.737e+02, -2.064e+03, -1.100e+03, -3.866e+02, -1.384e+02, -9.390e+01, -7.557e+01, -6.662e+01, -6.190e+01, -5.950e+01, -5.850e+01, -5.858e+01, -5.983e+01, -6.300e+01, -7.074e+01, -1.059e+02, -1.439e+02 ]
# dP/dy = [ -7.634e-03, -1.527e-02, -1.527e-02, -1.528e-02, -1.530e-02, -1.532e-02, -1.537e-02, -1.545e-02, -1.559e-02, -1.585e-02, -1.632e-02, -1.725e-02, -1.936e-02, -2.887e-02, -3.783e-02, -1.596e-02, -1.240e-02, -8.249e-03, -7.341e-03, -6.951e-03, -6.763e-03, -6.673e-03, -6.648e-03, -6.675e-03, -6.767e-03, -6.961e-03, -7.359e-03, -8.281e-03, -1.241e-02, -1.689e-02 ]

# %%
np.dot([1,2,3],[3,2,1.])
# Out:
# np.float64(10.0)

# %% [markdown]
# ________
# ## 5 - Gradient-based optimization
#
# ### 5.a - Optimization algorithm
# We use an augmented Lagrangian algorithm to solve the constrained optimization problem. That is to say, we maximize with respect to a Lagrange multiplier $\lambda$ a sequence of inner minimization problem with respect to the optimization variables $y_{airgap}$ :
#
# $$ \mathcal L(y_{airgap},\lambda) = P(y_{airgap}) + \lambda (L(y_{airgap}) - L_0) + \frac{\beta}{2} (L(y_{airgap}) - L_0)^2 $$

# %%
# Wrappers
regularize_symmetry_axis = True # flag to ensure dy/dx = 0 at the symmetry axis; otherwise problems happen...
L0 = 1e-3                       # target inductance

# container
current = {"x" : None, 
           "x_airgap" : None,
           "state" : None, 
           "mesh" : None, 
           "Kinv" : None, 
           "FEM_counter" : 0}

def update(x):
    current["x"] = x
    if regularize_symmetry_axis : y_airgap = [x[0]] + list(x)
    else : y_airgap = list(x)
    current["mesh"], p1, p2 = gen_meshN(y_airgap, maxh)    # Generate the mesh and return the coordinates of control points on the first and second leg
    current["x_airgap"] = [p[0] for p in p1] + [p[0] for p in p2]     # Extract the x-coordinates of the control points
    current["state"], current["Kinv"] = solveStateComplex(current["mesh"])
    current["FEM_counter"] += 1

def obj(x):
    if x is not current["x"]: update(x)
    return P(current["state"], current["mesh"])

def dObj(x):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddP, current["Kinv"])
    dobj = sensitivities_y_control_points(current["state"], adjoint, sdP, current["x_airgap"])
    if regularize_symmetry_axis : return np.array(dobj[1:])
    else : return np.array(dobj)


def cons(x, L0 = L0):
    if x is not current["x"]: update(x)
    return L(current["state"], current["mesh"])/L0 - 1

def dCons(x,  L0 = L0):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddL, current["Kinv"])
    dcons = sensitivities_y_control_points(current["state"], adjoint, sdL, current["x_airgap"])
    if regularize_symmetry_axis : return  np.array(dcons[1:])/L0
    else : return np.array(dcons)/L0

# lagrangian

def lagrangian(x, lam, beta, fun, cons):
    objFunction = fun(x)
    constraint = cons(x)
    return objFunction + lam * constraint + beta / 2 * constraint **2

def dx_lagrangian(x, lam, beta, dfun, dcons, cons):
    dx_objFunction = dfun(x)
    dx_constraint = dcons(x)
    constraint = cons(x)
    return dx_objFunction + lam * dx_constraint + beta * constraint * dx_constraint

# %% [markdown]
# ### 5-b. Unconstrained optimization (gradient descent)

# %%
from shapeOptInductor import gradient_descent

# Example (unconstrained)
lam = 0
beta = 1
lbound = 0.1e-4 * np.ones(NControlPoints)
ubound = np.array( [1.7e-2]* (NControlPoints//2-1) + [1.499e-2]*2 + (NControlPoints//2-1)*[1.7e-2])
if regularize_symmetry_axis : 
    x = airgap[1:]
    ubound = ubound[1:]
    lbound = lbound[1:]
else : x = airgap

lagr = lambda x: lagrangian(x, lam = lam,  beta = beta, fun = obj, cons = cons)
dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
res = gradient_descent(lagr, dlagr, x, step = 1e-3, iter_max = 50,
                       xlb = lbound, xub = ubound, precond = True, verbosity = 2)
# Out:
# ---- Start gradient descent
# it 0 | fun = 1.31676e+01 | step = 1.00e-03
# it 1 | fun = 1.20319e+01 | step = 1.20e-03 | crit = 1.71e+00 (accepted ✅)
# it 2 | fun = 1.06734e+01 | step = 1.44e-03 | crit = 1.82e+00 (accepted ✅)
# it 3 | fun = 9.23025e+00 | step = 1.73e-03 | crit = 1.86e+00 (accepted ✅)
# it 4 | fun = 7.72686e+00 | step = 2.07e-03 | crit = 1.91e+00 (accepted ✅)
# it 5 | fun = 6.26417e+00 | step = 2.49e-03 | crit = 1.92e+00 (accepted ✅)
# it 6 | fun = 5.30032e+00 | step = 2.99e-03 | crit = 1.66e+00 (accepted ✅)
# it 7 | fun = 5.20733e+00 | step = 1.49e-03 | crit = 1.66e+00 (rejected ❌)
# it 8 | fun = 5.08961e+00 | step = 1.79e-03 | crit = 1.15e+00 (accepted ✅)
# it 9 | fun = 5.15676e+00 | step = 8.96e-04 | crit = 1.15e+00 (rejected ❌)
# it 10 | fun = 4.80570e+00 | step = 1.07e-03 | crit = 8.58e-01 (accepted ✅)
# it 11 | fun = 4.57375e+00 | step = 1.29e-03 | crit = 7.48e-01 (accepted ✅)
# it 12 | fun = 4.92191e+00 | step = 6.45e-04 | crit = 7.48e-01 (rejected ❌)
# it 13 | fun = 4.48393e+00 | step = 7.74e-04 | crit = 5.95e-01 (accepted ✅)
# it 14 | fun = 4.42049e+00 | step = 9.29e-04 | crit = 6.27e-01 (accepted ✅)
# it 15 | fun = 4.44010e+00 | step = 4.64e-04 | crit = 6.27e-01 (rejected ❌)
# it 16 | fun = 4.35600e+00 | step = 5.57e-04 | crit = 4.35e-01 (accepted ✅)
# it 17 | fun = 4.31057e+00 | step = 6.69e-04 | crit = 4.71e-01 (accepted ✅)
# it 18 | fun = 4.26103e+00 | step = 8.02e-04 | crit = 4.88e-01 (accepted ✅)
# it 19 | fun = 4.24754e+00 | step = 4.01e-04 | crit = 4.88e-01 (rejected ❌)
# it 20 | fun = 4.22340e+00 | step = 4.81e-04 | crit = 3.85e-01 (accepted ✅)
# it 21 | fun = 4.18065e+00 | step = 5.78e-04 | crit = 4.05e-01 (accepted ✅)
# it 22 | fun = 4.15246e+00 | step = 6.93e-04 | crit = 4.61e-01 (accepted ✅)
# it 23 | fun = 4.16156e+00 | step = 3.47e-04 | crit = 4.61e-01 (rejected ❌)
# it 24 | fun = 4.12599e+00 | step = 4.16e-04 | crit = 3.04e-01 (accepted ✅)
# it 25 | fun = 4.09358e+00 | step = 4.99e-04 | crit = 3.47e-01 (accepted ✅)
# it 26 | fun = 4.06813e+00 | step = 5.99e-04 | crit = 3.41e-01 (accepted ✅)
# it 27 | fun = 4.06991e+00 | step = 3.00e-04 | crit = 3.41e-01 (rejected ❌)
# it 28 | fun = 4.05381e+00 | step = 3.59e-04 | crit = 2.63e-01 (accepted ✅)
# it 29 | fun = 4.04255e+00 | step = 4.31e-04 | crit = 2.62e-01 (accepted ✅)
# it 30 | fun = 4.02724e+00 | step = 5.18e-04 | crit = 3.21e-01 (accepted ✅)
# it 31 | fun = 4.02871e+00 | step = 2.59e-04 | crit = 3.21e-01 (rejected ❌)
# it 32 | fun = 4.01134e+00 | step = 3.11e-04 | crit = 2.18e-01 (accepted ✅)
# it 33 | fun = 3.99077e+00 | step = 3.73e-04 | crit = 2.71e-01 (accepted ✅)
# it 34 | fun = 3.97579e+00 | step = 4.47e-04 | crit = 2.52e-01 (accepted ✅)
# it 35 | fun = 3.97772e+00 | step = 2.24e-04 | crit = 2.52e-01 (rejected ❌)
# it 36 | fun = 3.96738e+00 | step = 2.68e-04 | crit = 1.89e-01 (accepted ✅)
# it 37 | fun = 3.96051e+00 | step = 3.22e-04 | crit = 1.90e-01 (accepted ✅)
# it 38 | fun = 3.95475e+00 | step = 3.86e-04 | crit = 2.27e-01 (accepted ✅)
# it 39 | fun = 3.95051e+00 | step = 1.93e-04 | crit = 2.27e-01 (rejected ❌)
# it 40 | fun = 3.94530e+00 | step = 2.32e-04 | crit = 1.65e-01 (accepted ✅)
# it 41 | fun = 3.92615e+00 | step = 2.78e-04 | crit = 1.98e-01 (accepted ✅)
# it 42 | fun = 3.92121e+00 | step = 3.34e-04 | crit = 1.89e-01 (accepted ✅)
# it 43 | fun = 3.90792e+00 | step = 4.01e-04 | crit = 2.50e-01 (accepted ✅)
# it 44 | fun = 3.91946e+00 | step = 2.00e-04 | crit = 2.50e-01 (rejected ❌)
# it 45 | fun = 3.90494e+00 | step = 2.40e-04 | crit = 1.48e-01 (accepted ✅)
# it 46 | fun = 3.90281e+00 | step = 1.20e-04 | crit = 1.48e-01 (rejected ❌)
# it 47 | fun = 3.90011e+00 | step = 1.44e-04 | crit = 1.21e-01 (accepted ✅)
# it 48 | fun = 3.89683e+00 | step = 1.73e-04 | crit = 1.23e-01 (accepted ✅)
# it 49 | fun = 3.89358e+00 | step = 2.08e-04 | crit = 1.40e-01 (accepted ✅)
# it 50 | fun = 3.88845e+00 | step = 2.49e-04 | crit = 1.45e-01 (accepted ✅)
# ---- Stopped after 50 because maximum number of iterations reached.

# %% [markdown]
# We plot the convergence and optimized design:

# %%
print(f"final airgap control point values : {res["x"][-1]}")
# Out:
# final airgap control point values : [0.00112836 0.0017947  0.00319924 0.00493694 0.00677723 0.00846997
#  0.00996919 0.01128906 0.01241328 0.01335593 0.01413246 0.01472882
#  0.01519124 0.01499    0.01499    0.01530726 0.01493619 0.01444565
#  0.01380624 0.0130618  0.01223601 0.01135599 0.01045123 0.00955318
#  0.00869337 0.0078998  0.00719258 0.00658845 0.00595503]

# %%
ax1 = plt.plot(res["fun"], color = 'b')   
plt.ylabel('Objective function', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.semilogy(res["stop_criterion"], color = 'r')
plt.ylabel("Stop criterion", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5-c. Constrained optimization with augmented Lagrangian

# %%
# Example (constrained optimization)

beta = 1
beta_max = 100
lam = 0
max_outer = 50
max_inner = 10
step = 1e-3

if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

lam = 0
x_list= [x]
P_list = [obj(x)]
L_list = [(cons(x)+1)*L0]

for i in range(max_outer):
    print(f"it {i} : P = {P_list[-1]:.5f} W | L = {L_list[-1]*1000 :.3e} mH | lam = {lam:.3e}")
    lagr = lambda x: lagrangian(x, lam = lam, beta = beta, fun = obj, cons = cons)
    dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
    res = gradient_descent(lagr, dlagr, x, step = step, xlb = lbound, xub = ubound, 
                           iter_max = max_inner, precond = True, verbosity = 1)
    x = res["x"][-1]
    x_list.append(x)
    L_list.append((cons(x)+1)*L0)
    P_list.append(obj(x))
    lam += beta * cons(x)
    beta = min(1.1*beta,beta_max)
    
print(f"Final design : P = {P_list[-1]:.5f} W | L = {L_list[-1]*1000 :.3f} mH")
# Out:
# it 0 : P = 13.16763 W | L = 1.000e+00 mH | lam = 0.000e+00
# ---- Start gradient descent
# it 0 | fun = 1.31676e+01 | step = 1.00e-03
# it 1 | fun = 1.20319e+01 | step = 1.20e-03 | crit = 1.71e+00 (accepted ✅)
# it 2 | fun = 1.06734e+01 | step = 1.44e-03 | crit = 1.82e+00 (accepted ✅)
# it 3 | fun = 9.23025e+00 | step = 1.73e-03 | crit = 1.86e+00 (accepted ✅)
# it 4 | fun = 7.72686e+00 | step = 2.07e-03 | crit = 1.91e+00 (accepted ✅)
# it 5 | fun = 6.26417e+00 | step = 2.49e-03 | crit = 1.92e+00 (accepted ✅)
# it 6 | fun = 5.30032e+00 | step = 2.99e-03 | crit = 1.66e+00 (accepted ✅)
# it 8 | fun = 5.08961e+00 | step = 1.79e-03 | crit = 1.15e+00 (accepted ✅)
# it 10 | fun = 4.80570e+00 | step = 1.07e-03 | crit = 8.58e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 1 : P = 4.80310 W | L = 9.278e-01 mH | lam = -7.216e-02
# ---- Start gradient descent
# it 0 | fun = 4.81117e+00 | step = 1.00e-03
# it 1 | fun = 4.58613e+00 | step = 1.20e-03 | crit = 7.15e-01 (accepted ✅)
# it 3 | fun = 4.48859e+00 | step = 7.20e-04 | crit = 5.62e-01 (accepted ✅)
# it 4 | fun = 4.43800e+00 | step = 8.64e-04 | crit = 5.57e-01 (accepted ✅)
# it 6 | fun = 4.37594e+00 | step = 5.18e-04 | crit = 4.18e-01 (accepted ✅)
# it 7 | fun = 4.31828e+00 | step = 6.22e-04 | crit = 4.66e-01 (accepted ✅)
# it 8 | fun = 4.27704e+00 | step = 7.46e-04 | crit = 4.62e-01 (accepted ✅)
# it 10 | fun = 4.24366e+00 | step = 4.48e-04 | crit = 3.75e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 2 : P = 4.22089 W | L = 8.518e-01 mH | lam = -2.352e-01
# ---- Start gradient descent
# it 0 | fun = 4.26903e+00 | step = 1.00e-03
# it 2 | fun = 4.25242e+00 | step = 6.00e-04 | crit = 3.74e-01 (accepted ✅)
# it 3 | fun = 4.22243e+00 | step = 7.20e-04 | crit = 5.14e-01 (accepted ✅)
# it 5 | fun = 4.19214e+00 | step = 4.32e-04 | crit = 3.19e-01 (accepted ✅)
# it 7 | fun = 4.17170e+00 | step = 2.59e-04 | crit = 2.48e-01 (accepted ✅)
# it 8 | fun = 4.15751e+00 | step = 3.11e-04 | crit = 2.44e-01 (accepted ✅)
# it 9 | fun = 4.14328e+00 | step = 3.73e-04 | crit = 2.91e-01 (accepted ✅)
# it 10 | fun = 4.12420e+00 | step = 4.48e-04 | crit = 2.96e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 3 : P = 4.09052 W | L = 8.887e-01 mH | lam = -3.699e-01
# ---- Start gradient descent
# it 0 | fun = 4.13995e+00 | step = 1.00e-03
# it 3 | fun = 4.12898e+00 | step = 3.00e-04 | crit = 2.59e-01 (accepted ✅)
# it 4 | fun = 4.11337e+00 | step = 3.60e-04 | crit = 2.54e-01 (accepted ✅)
# it 6 | fun = 4.10371e+00 | step = 2.16e-04 | crit = 2.02e-01 (accepted ✅)
# it 7 | fun = 4.09288e+00 | step = 2.59e-04 | crit = 1.94e-01 (accepted ✅)
# it 8 | fun = 4.08665e+00 | step = 3.11e-04 | crit = 2.34e-01 (accepted ✅)
# it 9 | fun = 4.07384e+00 | step = 3.73e-04 | crit = 2.51e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 4 : P = 4.04205 W | L = 9.244e-01 mH | lam = -4.706e-01
# ---- Start gradient descent
# it 0 | fun = 4.08184e+00 | step = 1.00e-03
# it 4 | fun = 4.07303e+00 | step = 1.50e-04 | crit = 1.68e-01 (accepted ✅)
# it 5 | fun = 4.06284e+00 | step = 1.80e-04 | crit = 1.55e-01 (accepted ✅)
# it 6 | fun = 4.05361e+00 | step = 2.16e-04 | crit = 1.58e-01 (accepted ✅)
# it 7 | fun = 4.04431e+00 | step = 2.59e-04 | crit = 1.97e-01 (accepted ✅)
# it 9 | fun = 4.03390e+00 | step = 1.56e-04 | crit = 1.93e-01 (accepted ✅)
# it 10 | fun = 4.02335e+00 | step = 1.87e-04 | crit = 1.46e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 5 : P = 4.00905 W | L = 9.709e-01 mH | lam = -5.131e-01
# ---- Start gradient descent
# it 0 | fun = 4.02465e+00 | step = 1.00e-03
# it 2 | fun = 4.00712e+00 | step = 6.00e-04 | crit = 2.51e-01 (accepted ✅)
# it 5 | fun = 3.99247e+00 | step = 1.80e-04 | crit = 1.90e-01 (accepted ✅)
# it 6 | fun = 3.98126e+00 | step = 2.16e-04 | crit = 1.49e-01 (accepted ✅)
# it 7 | fun = 3.96793e+00 | step = 2.59e-04 | crit = 1.62e-01 (accepted ✅)
# it 8 | fun = 3.94985e+00 | step = 3.11e-04 | crit = 1.79e-01 (accepted ✅)
# it 9 | fun = 3.93160e+00 | step = 3.73e-04 | crit = 2.00e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 6 : P = 3.98323 W | L = 1.125e+00 mH | lam = -3.114e-01
# ---- Start gradient descent
# it 0 | fun = 3.95812e+00 | step = 1.00e-03
# it 4 | fun = 3.95450e+00 | step = 1.50e-04 | crit = 1.87e-01 (accepted ✅)
# it 6 | fun = 3.95056e+00 | step = 9.00e-05 | crit = 1.15e-01 (accepted ✅)
# it 8 | fun = 3.94854e+00 | step = 5.40e-05 | crit = 7.87e-02 (accepted ✅)
# it 9 | fun = 3.94770e+00 | step = 6.48e-05 | crit = 8.03e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 7 : P = 3.97249 W | L = 1.122e+00 mH | lam = -9.571e-02
# ---- Start gradient descent
# it 0 | fun = 3.97528e+00 | step = 1.00e-03
# it 5 | fun = 3.97039e+00 | step = 7.50e-05 | crit = 1.18e-01 (accepted ✅)
# it 6 | fun = 3.96539e+00 | step = 9.00e-05 | crit = 1.04e-01 (accepted ✅)
# it 8 | fun = 3.96376e+00 | step = 5.40e-05 | crit = 7.98e-02 (accepted ✅)
# it 9 | fun = 3.96230e+00 | step = 6.48e-05 | crit = 8.58e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 8 : P = 3.96278 W | L = 1.093e+00 mH | lam = 8.552e-02
# ---- Start gradient descent
# it 0 | fun = 3.98000e+00 | step = 1.00e-03
# it 4 | fun = 3.97730e+00 | step = 1.50e-04 | crit = 1.59e-01 (accepted ✅)
# it 6 | fun = 3.97151e+00 | step = 9.00e-05 | crit = 1.31e-01 (accepted ✅)
# it 7 | fun = 3.96929e+00 | step = 1.08e-04 | crit = 1.18e-01 (accepted ✅)
# it 9 | fun = 3.96555e+00 | step = 6.48e-05 | crit = 1.04e-01 (accepted ✅)
# it 10 | fun = 3.96162e+00 | step = 7.78e-05 | crit = 8.73e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 9 : P = 3.95616 W | L = 1.042e+00 mH | lam = 1.752e-01
# ---- Start gradient descent
# it 0 | fun = 3.96556e+00 | step = 1.00e-03
# it 2 | fun = 3.95815e+00 | step = 6.00e-04 | crit = 2.65e-01 (accepted ✅)
# it 4 | fun = 3.94219e+00 | step = 3.60e-04 | crit = 3.05e-01 (accepted ✅)
# it 6 | fun = 3.93439e+00 | step = 2.16e-04 | crit = 2.06e-01 (accepted ✅)
# it 8 | fun = 3.93064e+00 | step = 1.30e-04 | crit = 1.30e-01 (accepted ✅)
# it 9 | fun = 3.92525e+00 | step = 1.56e-04 | crit = 1.31e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 10 : P = 3.93112 W | L = 9.490e-01 mH | lam = 5.486e-02
# ---- Start gradient descent
# it 0 | fun = 3.93170e+00 | step = 1.00e-03
# it 4 | fun = 3.92558e+00 | step = 1.50e-04 | crit = 1.46e-01 (accepted ✅)
# it 6 | fun = 3.92400e+00 | step = 9.00e-05 | crit = 9.70e-02 (accepted ✅)
# it 7 | fun = 3.92134e+00 | step = 1.08e-04 | crit = 1.04e-01 (accepted ✅)
# it 9 | fun = 3.91940e+00 | step = 6.48e-05 | crit = 7.98e-02 (accepted ✅)
# it 10 | fun = 3.91783e+00 | step = 7.78e-05 | crit = 8.76e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 11 : P = 3.91837 W | L = 9.737e-01 mH | lam = -1.339e-02
# ---- Start gradient descent
# it 0 | fun = 3.91971e+00 | step = 1.00e-03
# it 5 | fun = 3.91779e+00 | step = 7.50e-05 | crit = 8.71e-02 (accepted ✅)
# it 6 | fun = 3.91574e+00 | step = 9.00e-05 | crit = 8.77e-02 (accepted ✅)
# it 10 | fun = 3.91529e+00 | step = 1.35e-05 | crit = 3.64e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 12 : P = 3.91392 W | L = 9.734e-01 mH | lam = -8.926e-02
# ---- Start gradient descent
# it 0 | fun = 3.91741e+00 | step = 1.00e-03
# it 2 | fun = 3.91001e+00 | step = 6.00e-04 | crit = 2.59e-01 (accepted ✅)
# it 5 | fun = 3.89063e+00 | step = 1.80e-04 | crit = 2.14e-01 (accepted ✅)
# it 8 | fun = 3.88939e+00 | step = 5.40e-05 | crit = 6.84e-02 (accepted ✅)
# it 9 | fun = 3.88854e+00 | step = 6.48e-05 | crit = 7.90e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 13 : P = 3.88876 W | L = 1.003e+00 mH | lam = -8.116e-02
# ---- Start gradient descent
# it 0 | fun = 3.88856e+00 | step = 1.00e-03
# it 6 | fun = 3.88718e+00 | step = 3.75e-05 | crit = 5.34e-02 (accepted ✅)
# it 7 | fun = 3.88611e+00 | step = 4.50e-05 | crit = 7.29e-02 (accepted ✅)
# it 8 | fun = 3.88481e+00 | step = 5.40e-05 | crit = 6.88e-02 (accepted ✅)
# it 9 | fun = 3.88143e+00 | step = 6.48e-05 | crit = 7.88e-02 (accepted ✅)
# it 10 | fun = 3.87949e+00 | step = 7.78e-05 | crit = 9.11e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 14 : P = 3.88029 W | L = 1.014e+00 mH | lam = -3.247e-02
# ---- Start gradient descent
# it 0 | fun = 3.88021e+00 | step = 1.00e-03
# it 5 | fun = 3.87883e+00 | step = 7.50e-05 | crit = 8.06e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 15 : P = 3.87868 W | L = 9.962e-01 mH | lam = -4.700e-02
# ---- Start gradient descent
# it 0 | fun = 3.87889e+00 | step = 1.00e-03
# it 9 | fun = 3.87838e+00 | step = 4.69e-06 | crit = 2.16e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 16 : P = 3.87824 W | L = 9.973e-01 mH | lam = -5.824e-02
# ---- Start gradient descent
# it 0 | fun = 3.87841e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 17 : P = 3.87824 W | L = 9.973e-01 mH | lam = -7.061e-02
# ---- Start gradient descent
# it 0 | fun = 3.87845e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 18 : P = 3.87824 W | L = 9.973e-01 mH | lam = -8.421e-02
# ---- Start gradient descent
# it 0 | fun = 3.87848e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 19 : P = 3.87824 W | L = 9.973e-01 mH | lam = -9.917e-02
# ---- Start gradient descent
# it 0 | fun = 3.87853e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 20 : P = 3.87824 W | L = 9.973e-01 mH | lam = -1.156e-01
# ---- Start gradient descent
# it 0 | fun = 3.87857e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 21 : P = 3.87824 W | L = 9.973e-01 mH | lam = -1.337e-01
# ---- Start gradient descent
# it 0 | fun = 3.87862e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 22 : P = 3.87824 W | L = 9.973e-01 mH | lam = -1.536e-01
# ---- Start gradient descent
# it 0 | fun = 3.87868e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 23 : P = 3.87824 W | L = 9.973e-01 mH | lam = -1.755e-01
# ---- Start gradient descent
# it 0 | fun = 3.87874e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 24 : P = 3.87824 W | L = 9.973e-01 mH | lam = -1.996e-01
# ---- Start gradient descent
# it 0 | fun = 3.87881e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 25 : P = 3.87824 W | L = 9.973e-01 mH | lam = -2.261e-01
# ---- Start gradient descent
# it 0 | fun = 3.87889e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 26 : P = 3.87824 W | L = 9.973e-01 mH | lam = -2.553e-01
# ---- Start gradient descent
# it 0 | fun = 3.87897e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 27 : P = 3.87824 W | L = 9.973e-01 mH | lam = -2.874e-01
# ---- Start gradient descent
# it 0 | fun = 3.87906e+00 | step = 1.00e-03
# it 5 | fun = 3.87780e+00 | step = 7.50e-05 | crit = 1.11e-01 (accepted ✅)
# it 8 | fun = 3.87719e+00 | step = 2.25e-05 | crit = 4.83e-02 (accepted ✅)
# it 9 | fun = 3.87655e+00 | step = 2.70e-05 | crit = 4.51e-02 (accepted ✅)
# it 10 | fun = 3.87602e+00 | step = 3.24e-05 | crit = 5.37e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 28 : P = 3.87811 W | L = 1.009e+00 mH | lam = -1.670e-01
# ---- Start gradient descent
# it 0 | fun = 3.87719e+00 | step = 1.00e-03
# it 6 | fun = 3.87651e+00 | step = 3.75e-05 | crit = 6.00e-02 (accepted ✅)
# it 7 | fun = 3.87592e+00 | step = 4.50e-05 | crit = 6.86e-02 (accepted ✅)
# it 9 | fun = 3.87508e+00 | step = 2.70e-05 | crit = 4.48e-02 (accepted ✅)
# it 10 | fun = 3.87473e+00 | step = 3.24e-05 | crit = 5.21e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 29 : P = 3.87525 W | L = 1.004e+00 mH | lam = -1.141e-01
# ---- Start gradient descent
# it 0 | fun = 3.87494e+00 | step = 1.00e-03
# it 7 | fun = 3.87431e+00 | step = 1.87e-05 | crit = 3.75e-02 (accepted ✅)
# it 8 | fun = 3.87320e+00 | step = 2.25e-05 | crit = 5.13e-02 (accepted ✅)
# it 9 | fun = 3.87259e+00 | step = 2.70e-05 | crit = 4.67e-02 (accepted ✅)
# it 10 | fun = 3.87208e+00 | step = 3.24e-05 | crit = 5.11e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 30 : P = 3.87230 W | L = 1.002e+00 mH | lam = -7.664e-02
# ---- Start gradient descent
# it 0 | fun = 3.87217e+00 | step = 1.00e-03
# it 6 | fun = 3.87169e+00 | step = 3.75e-05 | crit = 5.28e-02 (accepted ✅)
# it 7 | fun = 3.87100e+00 | step = 4.50e-05 | crit = 6.74e-02 (accepted ✅)
# it 9 | fun = 3.87032e+00 | step = 2.70e-05 | crit = 4.59e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 31 : P = 3.87047 W | L = 1.006e+00 mH | lam = 2.479e-02
# ---- Start gradient descent
# it 0 | fun = 3.87094e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 32 : P = 3.87047 W | L = 1.006e+00 mH | lam = 1.364e-01
# ---- Start gradient descent
# it 0 | fun = 3.87162e+00 | step = 1.00e-03
# it 6 | fun = 3.87076e+00 | step = 3.75e-05 | crit = 6.82e-02 (accepted ✅)
# it 8 | fun = 3.87001e+00 | step = 2.25e-05 | crit = 4.80e-02 (accepted ✅)
# it 9 | fun = 3.86948e+00 | step = 2.70e-05 | crit = 4.91e-02 (accepted ✅)
# it 10 | fun = 3.86870e+00 | step = 3.24e-05 | crit = 5.03e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 33 : P = 3.86869 W | L = 1.000e+00 mH | lam = 1.371e-01
# ---- Start gradient descent
# it 0 | fun = 3.86870e+00 | step = 1.00e-03
# it 6 | fun = 3.86836e+00 | step = 3.75e-05 | crit = 5.75e-02 (accepted ✅)
# it 7 | fun = 3.86794e+00 | step = 4.50e-05 | crit = 6.24e-02 (accepted ✅)
# it 9 | fun = 3.86733e+00 | step = 2.70e-05 | crit = 5.18e-02 (accepted ✅)
# it 10 | fun = 3.86688e+00 | step = 3.24e-05 | crit = 5.15e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 34 : P = 3.86695 W | L = 9.995e-01 mH | lam = 1.249e-01
# ---- Start gradient descent
# it 0 | fun = 3.86689e+00 | step = 1.00e-03
# it 6 | fun = 3.86630e+00 | step = 3.75e-05 | crit = 6.09e-02 (accepted ✅)
# it 8 | fun = 3.86581e+00 | step = 2.25e-05 | crit = 4.13e-02 (accepted ✅)
# it 9 | fun = 3.86539e+00 | step = 2.70e-05 | crit = 4.95e-02 (accepted ✅)
# it 10 | fun = 3.86493e+00 | step = 3.24e-05 | crit = 5.41e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 35 : P = 3.86521 W | L = 9.964e-01 mH | lam = 3.189e-02
# ---- Start gradient descent
# it 0 | fun = 3.86528e+00 | step = 1.00e-03
# it 3 | fun = 3.85888e+00 | step = 3.00e-04 | crit = 1.79e-01 (accepted ✅)
# it 6 | fun = 3.85023e+00 | step = 9.00e-05 | crit = 1.80e-01 (accepted ✅)
# it 9 | fun = 3.84972e+00 | step = 2.70e-05 | crit = 4.94e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 36 : P = 3.84966 W | L = 1.001e+00 mH | lam = 6.588e-02
# ---- Start gradient descent
# it 0 | fun = 3.84977e+00 | step = 1.00e-03
# it 8 | fun = 3.84938e+00 | step = 9.37e-06 | crit = 2.71e-02 (accepted ✅)
# it 9 | fun = 3.84859e+00 | step = 1.12e-05 | crit = 3.51e-02 (accepted ✅)
# it 10 | fun = 3.84815e+00 | step = 1.35e-05 | crit = 3.78e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 37 : P = 3.84822 W | L = 9.977e-01 mH | lam = -6.296e-03
# ---- Start gradient descent
# it 0 | fun = 3.84833e+00 | step = 1.00e-03
# it 7 | fun = 3.84817e+00 | step = 1.87e-05 | crit = 3.52e-02 (accepted ✅)
# it 8 | fun = 3.84796e+00 | step = 2.25e-05 | crit = 4.39e-02 (accepted ✅)
# it 10 | fun = 3.84751e+00 | step = 1.35e-05 | crit = 3.11e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 38 : P = 3.84751 W | L = 1.000e+00 mH | lam = 5.469e-03
# ---- Start gradient descent
# it 0 | fun = 3.84752e+00 | step = 1.00e-03
# it 8 | fun = 3.84730e+00 | step = 9.37e-06 | crit = 2.65e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 39 : P = 3.84716 W | L = 9.971e-01 mH | lam = -1.028e-01
# ---- Start gradient descent
# it 0 | fun = 3.84763e+00 | step = 1.00e-03
# it 7 | fun = 3.84717e+00 | step = 1.87e-05 | crit = 4.14e-02 (accepted ✅)
# it 9 | fun = 3.84694e+00 | step = 1.12e-05 | crit = 2.82e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 40 : P = 3.84681 W | L = 9.990e-01 mH | lam = -1.451e-01
# ---- Start gradient descent
# it 0 | fun = 3.84698e+00 | step = 1.00e-03
# it 8 | fun = 3.84662e+00 | step = 9.37e-06 | crit = 2.69e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 41 : P = 3.84681 W | L = 1.002e+00 mH | lam = -6.129e-02
# ---- Start gradient descent
# it 0 | fun = 3.84678e+00 | step = 1.00e-03
# it 9 | fun = 3.84656e+00 | step = 4.69e-06 | crit = 1.83e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 42 : P = 3.84660 W | L = 1.001e+00 mH | lam = -3.693e-03
# ---- Start gradient descent
# it 0 | fun = 3.84663e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 43 : P = 3.84660 W | L = 1.001e+00 mH | lam = 5.966e-02
# ---- Start gradient descent
# it 0 | fun = 3.84671e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 44 : P = 3.84660 W | L = 1.001e+00 mH | lam = 1.294e-01
# ---- Start gradient descent
# it 0 | fun = 3.84679e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# it 45 : P = 3.84660 W | L = 1.001e+00 mH | lam = 2.060e-01
# ---- Start gradient descent
# it 0 | fun = 3.84688e+00 | step = 1.00e-03
# it 8 | fun = 3.84666e+00 | step = 9.37e-06 | crit = 3.62e-02 (accepted ✅)
# it 9 | fun = 3.84615e+00 | step = 1.12e-05 | crit = 3.61e-02 (accepted ✅)
# it 10 | fun = 3.84600e+00 | step = 1.35e-05 | crit = 3.71e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 46 : P = 3.84627 W | L = 9.978e-01 mH | lam = 4.831e-02
# ---- Start gradient descent
# it 0 | fun = 3.84636e+00 | step = 1.00e-03
# it 8 | fun = 3.84611e+00 | step = 9.37e-06 | crit = 2.49e-02 (accepted ✅)
# it 9 | fun = 3.84593e+00 | step = 1.12e-05 | crit = 2.98e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 47 : P = 3.84576 W | L = 9.973e-01 mH | lam = -1.693e-01
# ---- Start gradient descent
# it 0 | fun = 3.84655e+00 | step = 1.00e-03
# it 7 | fun = 3.84578e+00 | step = 1.87e-05 | crit = 5.33e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 48 : P = 3.84592 W | L = 1.003e+00 mH | lam = 6.332e-02
# ---- Start gradient descent
# it 0 | fun = 3.84642e+00 | step = 1.00e-03
# it 8 | fun = 3.84582e+00 | step = 9.37e-06 | crit = 3.93e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 49 : P = 3.84583 W | L = 9.999e-01 mH | lam = 5.062e-02
# ---- Start gradient descent
# it 0 | fun = 3.84582e+00 | step = 1.00e-03
# ---- Stopped after 10 because maximum number of iterations reached.
# Final design : P = 3.84583 W | L = 1.000 mH

# %% [markdown]
# We plot the convergence and optimized design:

# %%
ax1 = plt.plot(P_list, color = 'b')   
plt.ylabel('AC losses (W)', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.plot(np.array(L_list)*1000, color = 'r')
plt.ylabel("Inductance (mH)", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5.d - Scipy version
#
# We probably get a local optima.

# %%
from scipy.optimize import minimize, NonlinearConstraint, Bounds

if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

cons_scipy = NonlinearConstraint(cons, lb = 0, ub = 0, jac = dCons)
options = {"maxiter" : 100,
           'iprint' : 2
          }
bounds = Bounds(lb = lbound, ub = ubound, keep_feasible=True)
results_scipy = minimize(obj, x, jac=dObj,
                       bounds=bounds,
                       constraints=cons_scipy,
                       options = options)
x_scipy = results_scipy["x"]
# Out:
# c:\Users\theodore\miniconda3\envs\ngsolve-env\Lib\site-packages\scipy\optimize\_slsqp_py.py:434: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)

# %%
print(f"Final design (Scipy) : P = {results_scipy["fun"]:.5f} W | L = {(cons(x_scipy)+1)*L0*1000 :.3f} mH")
# Out:
# Final design (Scipy) : P = 3.81459 W | L = 1.010 mH

# %%
if regularize_symmetry_axis :x_scipy = [x_scipy[0]] + list(x_scipy)
Draw(materials_regions, gen_meshN(x_scipy)[0] )
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene
