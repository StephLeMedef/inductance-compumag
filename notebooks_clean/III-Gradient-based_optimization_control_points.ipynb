# %% [markdown]
# # III - Gradient-based design optimization with control points
#
# - **Parametric optimization** is not incompatible with gradient optimization.
# - The derivatives can be evaluated using **finite differences**, but this requires at least as many additional function evaluations as the number of parameters $N$. With many parameters (say $N>10$), using finite difference becomes **really costly**, especially when evaluating the function requires solving finite element problems.
# - Thanks to mathematical tools such as shape derivative and adjoint method, the derivatives can be evaluated efficiently with only $1$ additional resolution of a linear finite element problem per function to derivate (so-called adjoint).

# %%
from shapeOptInductor import gen_meshN, Id
import ngsolve as ngs
from ngsolve.webgui import Draw, WebGLScene
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, we set up the number of control points (with adjoint method, computation time is almost independant of the number of parameters).

# %%
##############################################
NControlPoints = 10 # can be changed
##############################################
print(f"{NControlPoints = }")
# Out:
# NControlPoints = 10

# %% [markdown]
# ___________________________
# ## 1 - Geometry and meshing
#
# Then, we define the inductor geometry and generate the mesh.

# %%
# Geometric parameters
lz = 1e-2               # z-thickness of the inductor  
s = 4                   # symmetry factor (model 1/4th of the total space)

# Mesh generation
airgap = 4.11e-3 * np.ones(NControlPoints)              # Array of y-coordinates of control points along the airgap
maxh = 2e-3                                             # Maximum size of mesh element
mesh, p1, p2 = gen_meshN(airgap, maxh)                  # Generate the mesh and return the coordinates of control points on the first and second leg
xAirgaps = [p[0] for p in p1] + [p[0] for p in p2]      # Extract the x-coordinates of the control points

# Define the characteristics functions
XiAir = mesh.MaterialCF({"air": 1})
XiCore = mesh.MaterialCF({"core": 1})
XiCoil = mesh.MaterialCF({"coil": 1})
materials_regions = 1 * XiAir + 2 * XiCoil + 3 * XiCore

# Draw the geometry and mesh
Draw(materials_regions, mesh, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 2 - State problem (time-harmonic magnetics)
#
# ### 2.a - Parameters definition
#
# We describe the magnetic permeabilities and the source currents.

# %%
# Electric current (assumed sinusoidal)
f = 5e4                                                         # Working frequency (Hz)
omega = 2 * np.pi * f                                           # rad/s
nb_turn = 200                                                   # Number of turn in the coil (no unit)
I = 2                                                           # Amplitude of the source current (A)
j = nb_turn / 2 * I / (ngs.Integrate(XiCoil, mesh)) * XiCoil    # Amplitude of the source current density  (A/m²)

# Magnetic permeabilities
mu0 = 4e-7 * np.pi                                              # Void permeability (H/m)
mur = 1000                                                      # Relative permeability of iron (no unit)
mu_iron = mur * mu0                                             # Iron permeability (H/m)
delta = 0.1                                                     # Loss angle associated with the coil (rad)
mu_coil = np.exp(-1j * delta) * mu0                             # Complex permeability of the coil

# %% [markdown]
# ### 2.b - Definition of the time-harmonic magnetics problem
#
# Then we can write the weak formulation and solve the following problem :
# $$\text{Find } \underline{a_h} \in H := \{\underline{a} \in H^1(\Omega) |\, \underline{a} = 0 \text{ on } \Gamma_D\} \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H, \int_\Omega \underline{\nu_h} (\nabla \underline{a_h}) \cdot (\nabla \underline{v})^* \,\mathrm{d}x = \int_{\Omega_{c, h}} j \underline{v}^* \, \mathrm{d}x. $$

# %%
def magWeakFormComplex(ah : ngs.FESpace.TrialFunction, 
                       v  : ngs.FESpace.TestFunction
                       ) -> tuple[ngs.BilinearForm, ngs.LinearForm]:
    """Return the sybolic weak form of the magnetic problem, 
    i.e, bilinear and linear forms (not assembled yet)."""

    # Bilinear form (transmission)
    bf =  1 / mu_iron * ngs.grad(ah) * ngs.grad(v) * ngs.dx("core")
    bf += 1 / mu_coil * ngs.grad(ah) * ngs.grad(v) * ngs.dx("coil")
    bf += 1 / mu0 * ngs.grad(ah) * ngs.grad(v) * ngs.dx("air")

    # Linear form (source)
    lf = j * v * ngs.dx("coil")

    return bf, lf


def solveStateComplex(mesh : ngs.Mesh
                      ) -> tuple[ngs.GridFunction, ngs.la.BaseMatrix]:
    """ Solve the time-harmonic magnetics problem """

    # Definition of function space
    fes = ngs.H1(mesh, order=1, dirichlet="arc|domainVert", complex=True)
    a, v = fes.TnT()

    # Definition of weak form
    bf, f = magWeakFormComplex(a, v)

    # Assembly
    K = ngs.BilinearForm(bf).Assemble()
    F = ngs.LinearForm(f).Assemble()

    # Solving
    gf = ngs.GridFunction(fes)
    Kinv = K.mat.Inverse(freedofs=fes.FreeDofs())
    gf.vec.data = Kinv * F.vec

    return gf, Kinv  # returning Kinv speed up adjoint calculation

# Example :
state, Kinv = solveStateComplex(mesh)
Draw(state.real, mesh, radius=0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 2.c - Definition of the post-processed quantities
#
# We define the losses and inductance
# $$
# \begin{array}{lcl}
# P(\underline{a}) &=& \displaystyle  s l_z  \pi f \int_{\Omega_c} \text{Im} \left( \frac{1}{\underline{\mu_c}} \right ) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# L(\underline{a}) &=& \displaystyle \frac{s l_z}{I^2} \int_\Omega \text{Re} \left( \underline{\nu} \right) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# \end{array}$$
#
# with their directional derivatives.

# %%
def L(state : ngs.GridFunction, 
      mesh : ngs.Mesh
      ) -> float:
    """ Compute inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return s * lz / (I**2) * ngs.Integrate(nu.real * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddL(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of the inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return 2 * s * lz / (I**2) * ngs.InnerProduct(nu.real * ngs.grad(state), ngs.grad(v)) * ngs.dx


def P(state : ngs.GridFunction,
      mesh : ngs.Mesh
      ) -> float:
    """ Compute AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return s * np.pi * f * lz * ngs.Integrate(nu.imag * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddP(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return 2 * s * np.pi * f * lz * ngs.InnerProduct(nu.imag * ngs.grad(state), ngs.grad(v)) * ngs.dx

# Example :
print(f"Inductance : {L(state, mesh) *1000:.3} mH")
print(f"Losses : {P(state, mesh):.3} W")
# Out:
# Inductance : 1.0 mH
# Losses : 13.2 W

# %% [markdown]
# ___________________________
# ## 3 - Adjoint problem
#
# The adjoint method is an efficient way to compute derivatives of PDE-constrained problem; it requires solving one linear auxiliary problem per function $f$ to derivate that reads
#
# $$ \text{Find } \underline{p}_f \in H \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H,  \quad \int_\Omega \nabla \underline{p}_f \cdot \left( \frac{\chi_c}{\underline{\mu_f}} + \frac{\chi_f}{\underline{\mu_f}} +\frac{\chi_a}{\underline{\mu_0}}\right)^* \nabla \underline{v} \; \mathrm{d}x = f'(\underline{a})(\underline{v}), $$
#
# with $f'$ the directional derivative of $f$, such that $F(\underline{a}) = \int_\Omega f(\underline{a}) \; \mathrm{d}x$.

# %%
def solveAdjoint(state : ngs.GridFunction,      
                 df : ngs.comp.SumOfIntegrals,
                 Kinv : ngs.la.BaseMatrix
                 ) -> ngs.GridFunction:
    """Solve the adjoint equation for a given directional derivative (right-hand side)"""

    fes = state.space
    v = fes.TestFunction()

    # Assemble the right-hand side
    f = ngs.LinearForm(-1. * df(state, v)).Assemble()
    
    # Solve using the adjoint (transconjugate) of provided FEM matrix
    gf = ngs.GridFunction(fes)
    gf.vec.data = Kinv.H * f.vec

    return gf

# Example :
adjoint_P = solveAdjoint(state, ddP, Kinv)
Draw(adjoint_P.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})

adjoint_L = solveAdjoint(state, ddL, Kinv)
Draw(adjoint_L.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 4 - Continuous and discretized shape derivatives
#
# ### 4.a - Continuous expressions
#
# The shape derivative of the losses is a linear form obtained by Céa's method that reads
# $$\mathrm{d} P(\Omega)(\phi) = \text{Re}\left( s l_z \pi f \int_{\Omega_c} \text{Im}\left(\frac{1}{\underline{\mu_c}}\right) A_\phi \nabla \underline a \cdot (\nabla \underline a)^* \; \mathrm{d} x + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_P^* \mathrm{d} x - \int_{\Omega_c} j\, \text{div} \phi\, \underline p_P^*  \mathrm{d} x \right)  $$
#
# with $\phi\in H^1(\Omega)^2$ and $A_\phi = \text{div} \phi \, I_2 - \nabla \phi - \nabla \phi^\top$.

# %%
def sdP(state : ngs.GridFunction,
        adjoint_P : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) of the AC losses inside the coil """

    # Finite element spaces
    mesh = state.space.mesh
    FESReal = ngs.VectorH1(mesh)
    FEScomplex = ngs.VectorH1(mesh, complex=True)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_losses = s * np.pi * f * lz * (1 / mu_coil).imag
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_losses * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx("coil")
    shape_derivative_cplx += -j * XiCoil * ngs.div(phi) * adjoint_P * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_P)) * ngs.dx
    shape_derivative_cplx.Assemble()

    # Take the real part
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# Similarly, computing the shape derivative of the inductance leads to
#
# $$
#  \mathrm{d}  L(\Omega)(\phi) =  \text{Re}\left( \frac{s l_z}{I^2} \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot (\nabla \underline a)^* \; \mathrm{d} x  + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_L^* \mathrm{d} x - \int_{\Omega_c} j\,\text{div} \phi\, \underline p_L^*  \mathrm{d} x \right)
# $$

# %%
def sdL(state : ngs.GridFunction,
        adjoint_L : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) for the inductance"""

    # Finite element spaces
    mesh = state.space.mesh
    FEScomplex = ngs.H1(mesh, complex = True)**2 #ngs.VectorH1(mesh, complex=True)
    FESReal = ngs.H1(mesh)**2 # ngs.VectorH1(mesh)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_induc = s * lz / (I**2) * nu.real
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative 
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_induc * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx
    shape_derivative_cplx += -j * ngs.div(phi) * adjoint_L * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_L)) * ngs.dx
    shape_derivative_cplx.Assemble()
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# ### 4.b - Discrete shape derivatives
# - The shape derivative is a **linear form**, from which we can extract a **descent direction**.
# - At the discrete level, one possibility is to extract directly the **nodal coefficients** from the assembled linear form, which is a vector.
#     - It represents the derivative of the losses with respect to the **coordinates of the mesh nodes**. In a sense, it represents the **shape gradient** of the discretized model.
#     - It takes the form of a nodal vector field, indicating in which direction one should move every node of the mesh to increase $f$ maximally.
# - We can therefore plot it, as below. It is almost 0 everywhere (should be exactly 0 up to the discretization errors), except on the **edges** of the geometry.
#     - Indeed, displacing a node at an interface modify the material distribution, which impacts the value of the scalar function, while moving a point from the inside doesn't change the geometry.
# - The **correctness** of the point-wise values of the discretized shape derivative can therefore be checked by **finite difference**, which is the purpose of the last section.

# %%
# Nodal identification of the shape derivative of the losses:
sdP_linear_form = sdP(state, adjoint_P)
discrete_shape_gradient_P = ngs.GridFunction(sdP_linear_form.space)
discrete_shape_gradient_P.vec.data = sdP_linear_form.vec
Draw(discrete_shape_gradient_P, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %%
# Nodal identification of the shape derivative of the inductance:
sdL_linear_form = sdL(state, adjoint_L)
discrete_shape_gradient_L = ngs.GridFunction(sdL_linear_form.space)
discrete_shape_gradient_L.vec.data = sdL_linear_form.vec
Draw(discrete_shape_gradient_L, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 4.c - Sensitivities with respect to the control points
#
# The sensitivities with respect to the $y$-coordinate of the control points (i.e., the first order derivatives of the quantity of interest) are simply obtained by taking the scalar product of the discretized shape derivative with a displacement field induced by the displacement of the control points.
#
# To obtain the true derivative, the displacement of the control point should be unitary. In the literature, this displacement can also be called a "velocity" because it can be used as a descent direction, transporting the geometry through a pseudo-time that are iterations of the algorithm. It is also possible (rather recommended) to use other descent direction using a regularization.

# %%
from shapeOptInductor import referenceVelocity

def sensitivities_y_control_points(state : ngs.GridFunction,
               adjoint : ngs.GridFunction,
               shape_derivative : callable,
               x_airgap : list[float]) -> list[float]:
    """ Compute the sensitivities of a function with respect to the y-value of the control points """

    velocityFields = referenceVelocity(state.space.mesh, x_airgap)
    sd_linearform = shape_derivative(state, adjoint)
    sd_discretized = ngs.GridFunction(ngs.VectorH1(state.space.mesh))
    sd_discretized.vec.FV().NumPy()[:] = np.real(sd_linearform.vec.FV().NumPy()[:])
    sensitivities = [ ngs.InnerProduct(sd_discretized.vec, refVelocity.vec) for refVelocity in velocityFields]
    return sensitivities

# Example:
sensitivities_P = sensitivities_y_control_points(state, adjoint_P, sdP, xAirgaps)
sensitivities_L = sensitivities_y_control_points(state, adjoint_L, sdL, xAirgaps)

print("dL/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_P) + " ]")
print("dP/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_L) + " ]")
# Out:
# dL/dy = [ 1.598e+02, 3.170e+02, 2.944e+02, -1.501e+01, -2.433e+03, -1.474e+03, -3.964e+02, -2.137e+02, -2.307e+02, -2.558e+02 ]
# dP/dy = [ -2.672e-02, -5.353e-02, -5.429e-02, -6.278e-02, -6.880e-02, -2.943e-02, -2.680e-02, -2.347e-02, -2.684e-02, -2.998e-02 ]

# %%
np.dot([1,2,3],[3,2,1.])
# Out:
# np.float64(10.0)

# %% [markdown]
# ________
# ## 5 - Gradient-based optimization
#
# ### 5.a - Optimization algorithm
# We use an augmented Lagrangian algorithm to solve the constrained optimization problem. That is to say, we maximize with respect to a Lagrange multiplier $\lambda$ a sequence of inner minimization problem with respect to the optimization variables $y_{airgap}$ :
#
# $$ \mathcal L(y_{airgap},\lambda) = P(y_{airgap}) + \lambda (L(y_{airgap}) - L_0) + \frac{\beta}{2} (L(y_{airgap}) - L_0)^2 $$

# %%
# Wrappers

# container
current = {"x" : None, 
           "x_airgap" : None,
           "state" : None, 
           "mesh" : None, 
           "Kinv" : None, 
           "FEM_counter" : 0}

def update(x):
    current["x"] = x
    current["mesh"], p1, p2 = gen_meshN([x[0]] + list(x), maxh)    # Generate the mesh and return the coordinates of control points on the first and second leg
    current["x_airgap"] = [p[0] for p in p1] + [p[0] for p in p2]     # Extract the x-coordinates of the control points
    current["state"], current["Kinv"] = solveStateComplex(current["mesh"])
    current["FEM_counter"] += 1

def obj(x):
    if x is not current["x"]: update(x)
    return P(current["state"], current["mesh"])

def dObj(x):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddP, current["Kinv"])
    dobj = sensitivities_y_control_points(current["state"], adjoint, sdP, current["x_airgap"])
    return np.array(dobj[1:])

L0 = 1e-3
def cons(x, L0 = L0):
    if x is not current["x"]: update(x)
    return L(current["state"], current["mesh"]) - L0

def dCons(x):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddL, current["Kinv"])
    dcons = sensitivities_y_control_points(current["state"], adjoint, sdL, current["x_airgap"])
    return np.array(dcons[1:])

# lagrangian
scale = 1e3
def lagrangian(x, lam, beta, fun, cons, scale = scale):
    objFunction = fun(x)
    constraint = cons(x)  * scale
    return objFunction + lam * constraint + beta / 2 * constraint **2

def dx_lagrangian(x, lam, beta, dfun, dcons, cons, scale = scale):
    dx_objFunction = dfun(x)
    dx_constraint = dcons(x) * scale
    constraint = cons(x) * scale
    return dx_objFunction + lam * dx_constraint + beta * constraint * dx_constraint

# %% [markdown]
# ### 5-b. Unconstrained optimization (gradient descent)

# %%
from shapeOptInductor import gradient_descent

# Example (unconstrained)
lam = 0
beta = 100
lagr = lambda x: lagrangian(x, lam = lam,  beta = beta, fun = obj, cons = cons)
dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
res = gradient_descent(lagr, dlagr, airgap[1:], step = 1e-3, iter_max = 100,
                       xlb = 2e-4, xub = 1.395e-2, precond = True, verbosity = 2)
# Out:
# ---- Start gradient descent
# it 0 | fun = 1.31661e+01 | step = 1.00e-03
# it 1 | fun = 1.16720e+01 | step = 1.20e-03 | crit = 1.88e+00 (accepted ✅)
# it 2 | fun = 1.02384e+01 | step = 1.44e-03 | crit = 1.81e+00 (accepted ✅)
# it 3 | fun = 8.71190e+00 | step = 1.73e-03 | crit = 1.85e+00 (accepted ✅)
# it 4 | fun = 7.15125e+00 | step = 2.07e-03 | crit = 1.93e+00 (accepted ✅)
# it 5 | fun = 6.01752e+00 | step = 2.49e-03 | crit = 1.79e+00 (accepted ✅)
# it 6 | fun = 3.09467e+01 | step = 1.24e-03 | crit = 1.79e+00 (rejected ❌)
# it 7 | fun = 8.32360e+00 | step = 6.22e-04 | crit = 1.79e+00 (rejected ❌)
# it 8 | fun = 5.93098e+00 | step = 7.46e-04 | crit = 8.85e-01 (accepted ✅)
# it 9 | fun = 6.03078e+00 | step = 3.73e-04 | crit = 8.85e-01 (rejected ❌)
# it 10 | fun = 5.78478e+00 | step = 4.48e-04 | crit = 8.30e-01 (accepted ✅)
# it 11 | fun = 5.80717e+00 | step = 2.24e-04 | crit = 8.30e-01 (rejected ❌)
# it 12 | fun = 5.71551e+00 | step = 2.69e-04 | crit = 4.53e-01 (accepted ✅)
# it 13 | fun = 5.67784e+00 | step = 3.22e-04 | crit = 5.93e-01 (accepted ✅)
# it 14 | fun = 5.56544e+00 | step = 3.87e-04 | crit = 5.82e-01 (accepted ✅)
# it 15 | fun = 5.62384e+00 | step = 1.93e-04 | crit = 5.82e-01 (rejected ❌)
# it 16 | fun = 5.52847e+00 | step = 2.32e-04 | crit = 4.72e-01 (accepted ✅)
# it 17 | fun = 5.46925e+00 | step = 2.79e-04 | crit = 4.47e-01 (accepted ✅)
# it 18 | fun = 5.47040e+00 | step = 1.39e-04 | crit = 4.47e-01 (rejected ❌)
# it 19 | fun = 5.42808e+00 | step = 1.67e-04 | crit = 3.82e-01 (accepted ✅)
# it 20 | fun = 5.38847e+00 | step = 2.01e-04 | crit = 3.64e-01 (accepted ✅)
# it 21 | fun = 5.36397e+00 | step = 2.41e-04 | crit = 4.44e-01 (accepted ✅)
# it 22 | fun = 5.31168e+00 | step = 2.89e-04 | crit = 4.52e-01 (accepted ✅)
# it 23 | fun = 5.33252e+00 | step = 1.44e-04 | crit = 4.52e-01 (rejected ❌)
# it 24 | fun = 5.27849e+00 | step = 1.73e-04 | crit = 3.66e-01 (accepted ✅)
# it 25 | fun = 5.25009e+00 | step = 2.08e-04 | crit = 3.58e-01 (accepted ✅)
# it 26 | fun = 5.23400e+00 | step = 1.04e-04 | crit = 3.58e-01 (rejected ❌)
# it 27 | fun = 5.21802e+00 | step = 1.25e-04 | crit = 3.07e-01 (accepted ✅)
# it 28 | fun = 5.16866e+00 | step = 1.50e-04 | crit = 3.15e-01 (accepted ✅)
# it 29 | fun = 5.14180e+00 | step = 1.80e-04 | crit = 3.75e-01 (accepted ✅)
# it 30 | fun = 5.10516e+00 | step = 2.16e-04 | crit = 3.69e-01 (accepted ✅)
# it 31 | fun = 5.10961e+00 | step = 1.08e-04 | crit = 3.69e-01 (rejected ❌)
# it 32 | fun = 5.07971e+00 | step = 1.29e-04 | crit = 2.93e-01 (accepted ✅)
# it 33 | fun = 5.05981e+00 | step = 1.55e-04 | crit = 2.95e-01 (accepted ✅)
# it 34 | fun = 5.04378e+00 | step = 1.86e-04 | crit = 3.47e-01 (accepted ✅)
# it 35 | fun = 5.02108e+00 | step = 2.24e-04 | crit = 3.60e-01 (accepted ✅)
# it 36 | fun = 5.02452e+00 | step = 1.12e-04 | crit = 3.60e-01 (rejected ❌)
# it 37 | fun = 4.99312e+00 | step = 1.34e-04 | crit = 3.04e-01 (accepted ✅)
# it 38 | fun = 4.97227e+00 | step = 1.61e-04 | crit = 3.27e-01 (accepted ✅)
# it 39 | fun = 4.94625e+00 | step = 1.93e-04 | crit = 3.70e-01 (accepted ✅)
# it 40 | fun = 4.94348e+00 | step = 9.66e-05 | crit = 3.70e-01 (rejected ❌)
# it 41 | fun = 4.92383e+00 | step = 1.16e-04 | crit = 2.46e-01 (accepted ✅)
# it 42 | fun = 4.90431e+00 | step = 1.39e-04 | crit = 3.03e-01 (accepted ✅)
# it 43 | fun = 4.87918e+00 | step = 1.67e-04 | crit = 3.03e-01 (accepted ✅)
# it 44 | fun = 4.88061e+00 | step = 8.35e-05 | crit = 3.03e-01 (rejected ❌)
# it 45 | fun = 4.85899e+00 | step = 1.00e-04 | crit = 2.35e-01 (accepted ✅)
# it 46 | fun = 4.84810e+00 | step = 1.20e-04 | crit = 2.46e-01 (accepted ✅)
# it 47 | fun = 4.83501e+00 | step = 1.44e-04 | crit = 2.82e-01 (accepted ✅)
# it 48 | fun = 4.82022e+00 | step = 1.73e-04 | crit = 2.93e-01 (accepted ✅)
# it 49 | fun = 4.81843e+00 | step = 8.65e-05 | crit = 2.93e-01 (rejected ❌)
# it 50 | fun = 4.80206e+00 | step = 1.04e-04 | crit = 2.51e-01 (accepted ✅)
# it 51 | fun = 4.77707e+00 | step = 1.25e-04 | crit = 2.60e-01 (accepted ✅)
# it 52 | fun = 4.77106e+00 | step = 6.23e-05 | crit = 2.60e-01 (rejected ❌)
# it 53 | fun = 4.76164e+00 | step = 7.48e-05 | crit = 1.94e-01 (accepted ✅)
# it 54 | fun = 4.74765e+00 | step = 8.97e-05 | crit = 2.30e-01 (accepted ✅)
# it 55 | fun = 4.73342e+00 | step = 1.08e-04 | crit = 2.34e-01 (accepted ✅)
# it 56 | fun = 4.72280e+00 | step = 1.29e-04 | crit = 2.40e-01 (accepted ✅)
# it 57 | fun = 4.71384e+00 | step = 1.55e-04 | crit = 2.90e-01 (accepted ✅)
# it 58 | fun = 4.71124e+00 | step = 7.75e-05 | crit = 2.90e-01 (rejected ❌)
# it 59 | fun = 4.69994e+00 | step = 9.30e-05 | crit = 2.12e-01 (accepted ✅)
# it 60 | fun = 4.67786e+00 | step = 1.12e-04 | crit = 2.39e-01 (accepted ✅)
# it 61 | fun = 4.67009e+00 | step = 1.34e-04 | crit = 2.40e-01 (accepted ✅)
# it 62 | fun = 4.66066e+00 | step = 1.61e-04 | crit = 2.93e-01 (accepted ✅)
# it 63 | fun = 4.65822e+00 | step = 8.04e-05 | crit = 2.93e-01 (rejected ❌)
# it 64 | fun = 4.64314e+00 | step = 9.64e-05 | crit = 2.18e-01 (accepted ✅)
# it 65 | fun = 4.62087e+00 | step = 1.16e-04 | crit = 2.36e-01 (accepted ✅)
# it 66 | fun = 4.61962e+00 | step = 5.79e-05 | crit = 2.36e-01 (rejected ❌)
# it 67 | fun = 4.61073e+00 | step = 6.94e-05 | crit = 1.68e-01 (accepted ✅)
# it 68 | fun = 4.60209e+00 | step = 8.33e-05 | crit = 2.07e-01 (accepted ✅)
# it 69 | fun = 4.58758e+00 | step = 1.00e-04 | crit = 2.06e-01 (accepted ✅)
# it 70 | fun = 4.58471e+00 | step = 5.00e-05 | crit = 2.06e-01 (rejected ❌)
# it 71 | fun = 4.57918e+00 | step = 6.00e-05 | crit = 1.60e-01 (accepted ✅)
# it 72 | fun = 4.57000e+00 | step = 7.20e-05 | crit = 1.79e-01 (accepted ✅)
# it 73 | fun = 4.56278e+00 | step = 8.64e-05 | crit = 1.89e-01 (accepted ✅)
# it 74 | fun = 4.55718e+00 | step = 1.04e-04 | crit = 2.01e-01 (accepted ✅)
# it 75 | fun = 4.55104e+00 | step = 1.24e-04 | crit = 2.36e-01 (accepted ✅)
# it 76 | fun = 4.54737e+00 | step = 6.22e-05 | crit = 2.36e-01 (rejected ❌)
# it 77 | fun = 4.53824e+00 | step = 7.46e-05 | crit = 1.79e-01 (accepted ✅)
# it 78 | fun = 4.52004e+00 | step = 8.96e-05 | crit = 1.92e-01 (accepted ✅)
# it 79 | fun = 4.51396e+00 | step = 1.07e-04 | crit = 2.20e-01 (accepted ✅)
# it 80 | fun = 4.50278e+00 | step = 1.29e-04 | crit = 2.68e-01 (accepted ✅)
# it 81 | fun = 4.50592e+00 | step = 6.45e-05 | crit = 2.68e-01 (rejected ❌)
# it 82 | fun = 4.49426e+00 | step = 7.74e-05 | crit = 1.69e-01 (accepted ✅)
# it 83 | fun = 4.48765e+00 | step = 9.29e-05 | crit = 1.85e-01 (accepted ✅)
# it 84 | fun = 4.48032e+00 | step = 1.11e-04 | crit = 2.13e-01 (accepted ✅)
# it 85 | fun = 4.48215e+00 | step = 5.57e-05 | crit = 2.13e-01 (rejected ❌)
# it 86 | fun = 4.47416e+00 | step = 6.69e-05 | crit = 1.58e-01 (accepted ✅)
# it 87 | fun = 4.46661e+00 | step = 8.02e-05 | crit = 1.70e-01 (accepted ✅)
# it 88 | fun = 4.46285e+00 | step = 4.01e-05 | crit = 1.70e-01 (rejected ❌)
# it 89 | fun = 4.46162e+00 | step = 4.81e-05 | crit = 1.40e-01 (accepted ✅)
# it 90 | fun = 4.45023e+00 | step = 5.78e-05 | crit = 1.39e-01 (accepted ✅)
# it 91 | fun = 4.44497e+00 | step = 6.93e-05 | crit = 1.65e-01 (accepted ✅)
# it 92 | fun = 4.43776e+00 | step = 8.32e-05 | crit = 1.79e-01 (accepted ✅)
# it 93 | fun = 4.43641e+00 | step = 4.16e-05 | crit = 1.79e-01 (rejected ❌)
# it 94 | fun = 4.43239e+00 | step = 4.99e-05 | crit = 1.27e-01 (accepted ✅)
# it 95 | fun = 4.42765e+00 | step = 5.99e-05 | crit = 1.51e-01 (accepted ✅)
# it 96 | fun = 4.41918e+00 | step = 7.19e-05 | crit = 1.54e-01 (accepted ✅)
# it 97 | fun = 4.41729e+00 | step = 3.59e-05 | crit = 1.54e-01 (rejected ❌)
# it 98 | fun = 4.41439e+00 | step = 4.31e-05 | crit = 1.19e-01 (accepted ✅)
# it 99 | fun = 4.41137e+00 | step = 5.17e-05 | crit = 1.42e-01 (accepted ✅)
# it 100 | fun = 4.40563e+00 | step = 6.21e-05 | crit = 1.45e-01 (accepted ✅)
# ---- Stopped after 100 because maximum number of iterations reached.

# %%
print(f"final airgap control point values : {res["x"][-1]}")
# Out:
# array([0.00136934, 0.00627691, 0.01150878, 0.01390072, 0.01395   ,
#        0.01197514, 0.00831562, 0.00540063, 0.00389608])

# %%
ax1 = plt.plot(res["fun"], color = 'b')   
plt.ylabel('Objective function', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.semilogy(res["stop_criterion"], color = 'r')
plt.ylabel("Stop criterion", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5-c. Constrained optimization with augmented Lagrangian

# %%
# Example (constrained)
from copy import copy
lam = 0
beta = 0.1
max_iter = 50
step = 1e-6

x = airgap[1:]
lam = 0
x_list= []
P_list = []
L_list = []

for i in range(max_iter):
    print(f"it {i} : P = {obj(x):.5f} W | L = {(cons(x) + L0)*1000 :.3e} mH | lam = {lam:.3e}")
    lagr = lambda x: lagrangian(x, lam = lam, beta = beta, fun = obj, cons = cons)
    dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
    res = gradient_descent(lagr, dlagr, x, step = 1e-4, xlb = 2e-4, xub = 1.395e-2, tol =1e-10, 
                           iter_max=10, precond = True, verbosity = 1)
    x = res["x"][-1]
    x_list.append(x)
    L_list.append(cons(x) + L0)
    P_list.append(obj(x))
    lam += beta * scale*cons(x)
    beta *= 1.1
# Out:
# it 0 : P = 13.16612 W | L = 1.000e+00 mH | lam = 0.000e+00
# ---- Start gradient descent
# it 0 | fun = 1.31661e+01 | step = 1.00e-04
# it 1 | fun = 1.29907e+01 | step = 1.20e-04 | crit = 5.95e-01 (accepted ✅)
# it 2 | fun = 1.28019e+01 | step = 1.44e-04 | crit = 6.40e-01 (accepted ✅)
# it 3 | fun = 1.25385e+01 | step = 1.73e-04 | crit = 6.93e-01 (accepted ✅)
# it 4 | fun = 1.22731e+01 | step = 2.07e-04 | crit = 7.45e-01 (accepted ✅)
# it 5 | fun = 1.19779e+01 | step = 2.49e-04 | crit = 7.97e-01 (accepted ✅)
# it 6 | fun = 1.16149e+01 | step = 2.99e-04 | crit = 8.57e-01 (accepted ✅)
# it 7 | fun = 1.11977e+01 | step = 3.58e-04 | crit = 9.12e-01 (accepted ✅)
# it 8 | fun = 1.07578e+01 | step = 4.30e-04 | crit = 9.69e-01 (accepted ✅)
# it 9 | fun = 1.02399e+01 | step = 5.16e-04 | crit = 1.03e+00 (accepted ✅)
# it 10 | fun = 9.66408e+00 | step = 6.19e-04 | crit = 1.10e+00 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 1 : P = 9.66388 W | L = 9.377e-01 mH | lam = -6.225e-03
# ---- Start gradient descent
# it 0 | fun = 9.66448e+00 | step = 1.00e-04
# it 1 | fun = 9.54568e+00 | step = 1.20e-04 | crit = 4.69e-01 (accepted ✅)
# it 2 | fun = 9.42479e+00 | step = 1.44e-04 | crit = 5.11e-01 (accepted ✅)
# it 3 | fun = 9.27462e+00 | step = 1.73e-04 | crit = 5.57e-01 (accepted ✅)
# it 4 | fun = 9.08373e+00 | step = 2.07e-04 | crit = 6.07e-01 (accepted ✅)
# it 5 | fun = 8.86849e+00 | step = 2.49e-04 | crit = 6.60e-01 (accepted ✅)
# it 6 | fun = 8.61155e+00 | step = 2.99e-04 | crit = 7.16e-01 (accepted ✅)
# it 7 | fun = 8.30821e+00 | step = 3.58e-04 | crit = 7.79e-01 (accepted ✅)
# it 8 | fun = 7.96182e+00 | step = 4.30e-04 | crit = 8.41e-01 (accepted ✅)
# it 9 | fun = 7.55267e+00 | step = 5.16e-04 | crit = 9.08e-01 (accepted ✅)
# it 10 | fun = 7.11028e+00 | step = 6.19e-04 | crit = 9.52e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 2 : P = 7.10979 W | L = 9.465e-01 mH | lam = -1.211e-02
# ---- Start gradient descent
# it 0 | fun = 7.11061e+00 | step = 1.00e-04
# it 1 | fun = 7.03585e+00 | step = 1.20e-04 | crit = 3.93e-01 (accepted ✅)
# it 2 | fun = 6.94007e+00 | step = 1.44e-04 | crit = 4.24e-01 (accepted ✅)
# it 3 | fun = 6.83190e+00 | step = 1.73e-04 | crit = 4.57e-01 (accepted ✅)
# it 4 | fun = 6.71277e+00 | step = 2.07e-04 | crit = 4.93e-01 (accepted ✅)
# it 5 | fun = 6.56648e+00 | step = 2.49e-04 | crit = 5.29e-01 (accepted ✅)
# it 6 | fun = 6.40905e+00 | step = 2.99e-04 | crit = 5.64e-01 (accepted ✅)
# it 7 | fun = 6.23222e+00 | step = 3.58e-04 | crit = 6.00e-01 (accepted ✅)
# it 8 | fun = 6.03402e+00 | step = 4.30e-04 | crit = 6.35e-01 (accepted ✅)
# it 9 | fun = 5.81525e+00 | step = 5.16e-04 | crit = 6.72e-01 (accepted ✅)
# it 10 | fun = 5.57341e+00 | step = 6.19e-04 | crit = 7.14e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 3 : P = 5.57298 W | L = 9.694e-01 mH | lam = -1.582e-02
# ---- Start gradient descent
# it 0 | fun = 5.57353e+00 | step = 1.00e-04
# it 1 | fun = 5.52964e+00 | step = 1.20e-04 | crit = 3.05e-01 (accepted ✅)
# it 2 | fun = 5.47228e+00 | step = 1.44e-04 | crit = 3.32e-01 (accepted ✅)
# it 3 | fun = 5.41058e+00 | step = 1.73e-04 | crit = 3.61e-01 (accepted ✅)
# it 4 | fun = 5.33561e+00 | step = 2.07e-04 | crit = 3.92e-01 (accepted ✅)
# it 5 | fun = 5.24820e+00 | step = 2.49e-04 | crit = 4.25e-01 (accepted ✅)
# it 6 | fun = 5.14173e+00 | step = 2.99e-04 | crit = 4.59e-01 (accepted ✅)
# it 7 | fun = 5.02613e+00 | step = 3.58e-04 | crit = 4.89e-01 (accepted ✅)
# it 8 | fun = 4.90365e+00 | step = 4.30e-04 | crit = 5.19e-01 (accepted ✅)
# it 9 | fun = 4.75869e+00 | step = 5.16e-04 | crit = 5.49e-01 (accepted ✅)
# it 10 | fun = 4.60257e+00 | step = 6.19e-04 | crit = 5.77e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 4 : P = 4.60039 W | L = 9.021e-01 mH | lam = -2.885e-02
# ---- Start gradient descent
# it 0 | fun = 4.60391e+00 | step = 1.00e-04
# it 1 | fun = 4.57135e+00 | step = 1.20e-04 | crit = 2.41e-01 (accepted ✅)
# it 2 | fun = 4.53948e+00 | step = 1.44e-04 | crit = 2.61e-01 (accepted ✅)
# it 3 | fun = 4.49983e+00 | step = 1.73e-04 | crit = 2.82e-01 (accepted ✅)
# it 4 | fun = 4.45658e+00 | step = 2.07e-04 | crit = 3.05e-01 (accepted ✅)
# it 5 | fun = 4.39904e+00 | step = 2.49e-04 | crit = 3.28e-01 (accepted ✅)
# it 6 | fun = 4.35091e+00 | step = 2.99e-04 | crit = 3.31e-01 (accepted ✅)
# it 7 | fun = 4.30135e+00 | step = 3.58e-04 | crit = 3.31e-01 (accepted ✅)
# it 8 | fun = 4.23999e+00 | step = 4.30e-04 | crit = 3.40e-01 (accepted ✅)
# it 9 | fun = 4.18562e+00 | step = 5.16e-04 | crit = 3.53e-01 (accepted ✅)
# it 10 | fun = 4.12133e+00 | step = 6.19e-04 | crit = 3.64e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 5 : P = 4.11377 W | L = 8.201e-01 mH | lam = -5.519e-02
# ---- Start gradient descent
# it 0 | fun = 4.12630e+00 | step = 1.00e-04
# it 1 | fun = 4.11750e+00 | step = 1.20e-04 | crit = 1.47e-01 (accepted ✅)
# it 2 | fun = 4.10682e+00 | step = 1.44e-04 | crit = 1.59e-01 (accepted ✅)
# it 3 | fun = 4.09168e+00 | step = 1.73e-04 | crit = 1.72e-01 (accepted ✅)
# it 4 | fun = 4.07403e+00 | step = 2.07e-04 | crit = 1.85e-01 (accepted ✅)
# it 5 | fun = 4.05654e+00 | step = 2.49e-04 | crit = 1.97e-01 (accepted ✅)
# it 6 | fun = 4.03927e+00 | step = 2.99e-04 | crit = 2.11e-01 (accepted ✅)
# it 7 | fun = 4.01291e+00 | step = 3.58e-04 | crit = 2.22e-01 (accepted ✅)
# it 8 | fun = 3.98557e+00 | step = 4.30e-04 | crit = 2.24e-01 (accepted ✅)
# it 9 | fun = 3.96751e+00 | step = 5.16e-04 | crit = 2.24e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 6 : P = 3.94757 W | L = 7.385e-01 mH | lam = -9.729e-02
# ---- Start gradient descent
# it 0 | fun = 3.97907e+00 | step = 1.00e-04
# it 1 | fun = 3.97069e+00 | step = 1.20e-04 | crit = 1.27e-01 (accepted ✅)
# it 2 | fun = 3.96424e+00 | step = 1.44e-04 | crit = 1.10e-01 (accepted ✅)
# it 3 | fun = 3.95817e+00 | step = 1.73e-04 | crit = 1.17e-01 (accepted ✅)
# it 4 | fun = 3.95068e+00 | step = 2.07e-04 | crit = 1.27e-01 (accepted ✅)
# it 5 | fun = 3.94196e+00 | step = 2.49e-04 | crit = 1.37e-01 (accepted ✅)
# it 6 | fun = 3.93153e+00 | step = 2.99e-04 | crit = 1.49e-01 (accepted ✅)
# it 7 | fun = 3.92056e+00 | step = 3.58e-04 | crit = 1.59e-01 (accepted ✅)
# it 8 | fun = 3.90709e+00 | step = 4.30e-04 | crit = 1.78e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 7 : P = 3.87080 W | L = 7.058e-01 mH | lam = -1.494e-01
# ---- Start gradient descent
# it 0 | fun = 3.92319e+00 | step = 1.00e-04
# it 2 | fun = 3.92164e+00 | step = 6.00e-05 | crit = 6.20e-02 (accepted ✅)
# it 5 | fun = 3.92140e+00 | step = 1.80e-05 | crit = 3.41e-02 (accepted ✅)
# it 7 | fun = 3.92129e+00 | step = 1.08e-05 | crit = 2.56e-02 (accepted ✅)
# it 10 | fun = 3.92107e+00 | step = 3.24e-06 | crit = 1.39e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 8 : P = 3.86716 W | L = 6.984e-01 mH | lam = -2.082e-01
# ---- Start gradient descent
# it 0 | fun = 3.93968e+00 | step = 1.00e-04
# it 8 | fun = 3.93962e+00 | step = 9.38e-07 | crit = 6.86e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 9 : P = 3.86710 W | L = 6.985e-01 mH | lam = -2.728e-01
# ---- Start gradient descent
# it 0 | fun = 3.96008e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 10 : P = 3.86710 W | L = 6.985e-01 mH | lam = -3.439e-01
# ---- Start gradient descent
# it 0 | fun = 3.98259e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 11 : P = 3.86710 W | L = 6.985e-01 mH | lam = -4.221e-01
# ---- Start gradient descent
# it 0 | fun = 4.00736e+00 | step = 1.00e-04
# it 7 | fun = 4.00733e+00 | step = 1.88e-06 | crit = 9.90e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 12 : P = 3.86715 W | L = 6.986e-01 mH | lam = -5.081e-01
# ---- Start gradient descent
# it 0 | fun = 4.03453e+00 | step = 1.00e-04
# it 10 | fun = 4.03435e+00 | step = 2.34e-07 | crit = 3.67e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 13 : P = 3.86697 W | L = 6.986e-01 mH | lam = -6.027e-01
# ---- Start gradient descent
# it 0 | fun = 4.06428e+00 | step = 1.00e-04
# it 1 | fun = 4.06352e+00 | step = 1.20e-04 | crit = 8.32e-02 (accepted ✅)
# it 2 | fun = 4.05684e+00 | step = 1.44e-04 | crit = 7.63e-02 (accepted ✅)
# it 4 | fun = 4.05528e+00 | step = 8.64e-05 | crit = 5.92e-02 (accepted ✅)
# it 7 | fun = 4.05474e+00 | step = 2.59e-05 | crit = 3.21e-02 (accepted ✅)
# it 9 | fun = 4.05433e+00 | step = 1.56e-05 | crit = 2.48e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 14 : P = 3.86649 W | L = 7.121e-01 mH | lam = -7.021e-01
# ---- Start gradient descent
# it 0 | fun = 4.08438e+00 | step = 1.00e-04
# it 6 | fun = 4.08426e+00 | step = 3.75e-06 | crit = 1.41e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 15 : P = 3.86657 W | L = 7.123e-01 mH | lam = -8.113e-01
# ---- Start gradient descent
# it 0 | fun = 4.11725e+00 | step = 1.00e-04
# it 1 | fun = 4.11629e+00 | step = 1.20e-04 | crit = 8.62e-02 (accepted ✅)
# it 2 | fun = 4.11200e+00 | step = 1.44e-04 | crit = 8.24e-02 (accepted ✅)
# it 3 | fun = 4.10682e+00 | step = 1.73e-04 | crit = 9.21e-02 (accepted ✅)
# it 4 | fun = 4.09976e+00 | step = 2.07e-04 | crit = 9.76e-02 (accepted ✅)
# it 5 | fun = 4.09255e+00 | step = 2.49e-04 | crit = 1.12e-01 (accepted ✅)
# it 6 | fun = 4.08816e+00 | step = 2.99e-04 | crit = 1.24e-01 (accepted ✅)
# it 7 | fun = 4.08357e+00 | step = 3.58e-04 | crit = 1.51e-01 (accepted ✅)
# it 9 | fun = 4.07693e+00 | step = 2.15e-04 | crit = 1.70e-01 (accepted ✅)
# it 10 | fun = 4.06849e+00 | step = 2.58e-04 | crit = 1.16e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 16 : P = 3.88318 W | L = 7.837e-01 mH | lam = -9.017e-01
# ---- Start gradient descent
# it 0 | fun = 4.08902e+00 | step = 1.00e-04
# it 1 | fun = 4.08546e+00 | step = 1.20e-04 | crit = 8.20e-02 (accepted ✅)
# it 2 | fun = 4.08125e+00 | step = 1.44e-04 | crit = 9.05e-02 (accepted ✅)
# it 3 | fun = 4.07565e+00 | step = 1.73e-04 | crit = 1.01e-01 (accepted ✅)
# it 4 | fun = 4.06880e+00 | step = 2.07e-04 | crit = 1.12e-01 (accepted ✅)
# it 5 | fun = 4.06006e+00 | step = 2.49e-04 | crit = 1.25e-01 (accepted ✅)
# it 6 | fun = 4.04993e+00 | step = 2.99e-04 | crit = 1.40e-01 (accepted ✅)
# it 7 | fun = 4.03487e+00 | step = 3.58e-04 | crit = 1.58e-01 (accepted ✅)
# it 8 | fun = 4.01825e+00 | step = 4.30e-04 | crit = 1.79e-01 (accepted ✅)
# it 9 | fun = 3.99937e+00 | step = 5.16e-04 | crit = 2.26e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 17 : P = 3.94818 W | L = 9.440e-01 mH | lam = -9.274e-01
# ---- Start gradient descent
# it 0 | fun = 4.00089e+00 | step = 1.00e-04
# it 1 | fun = 3.98885e+00 | step = 1.20e-04 | crit = 1.83e-01 (accepted ✅)
# it 2 | fun = 3.98155e+00 | step = 1.44e-04 | crit = 1.22e-01 (accepted ✅)
# it 3 | fun = 3.97058e+00 | step = 1.73e-04 | crit = 1.36e-01 (accepted ✅)
# it 4 | fun = 3.95862e+00 | step = 2.07e-04 | crit = 1.51e-01 (accepted ✅)
# it 5 | fun = 3.94202e+00 | step = 2.49e-04 | crit = 1.69e-01 (accepted ✅)
# it 6 | fun = 3.92188e+00 | step = 2.99e-04 | crit = 1.93e-01 (accepted ✅)
# it 7 | fun = 3.89413e+00 | step = 3.58e-04 | crit = 2.23e-01 (accepted ✅)
# it 8 | fun = 3.86034e+00 | step = 4.30e-04 | crit = 2.57e-01 (accepted ✅)
# it 9 | fun = 3.82397e+00 | step = 5.16e-04 | crit = 3.26e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 18 : P = 4.00163 W | L = 1.203e+00 mH | lam = -8.250e-01
# ---- Start gradient descent
# it 0 | fun = 3.84579e+00 | step = 1.00e-04
# it 1 | fun = 3.81034e+00 | step = 1.20e-04 | crit = 2.77e-01 (accepted ✅)
# it 2 | fun = 3.79811e+00 | step = 1.44e-04 | crit = 1.81e-01 (accepted ✅)
# it 3 | fun = 3.77853e+00 | step = 1.73e-04 | crit = 1.88e-01 (accepted ✅)
# it 4 | fun = 3.75440e+00 | step = 2.07e-04 | crit = 2.14e-01 (accepted ✅)
# it 5 | fun = 3.71974e+00 | step = 2.49e-04 | crit = 2.48e-01 (accepted ✅)
# it 6 | fun = 3.68537e+00 | step = 2.99e-04 | crit = 2.93e-01 (accepted ✅)
# it 8 | fun = 3.65059e+00 | step = 1.79e-04 | crit = 2.76e-01 (accepted ✅)
# it 9 | fun = 3.62293e+00 | step = 2.15e-04 | crit = 3.40e-01 (accepted ✅)
# it 10 | fun = 3.59777e+00 | step = 2.58e-04 | crit = 3.57e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 19 : P = 4.00073 W | L = 1.617e+00 mH | lam = -4.821e-01
# ---- Start gradient descent
# it 0 | fun = 3.81971e+00 | step = 1.00e-04
# it 1 | fun = 3.74874e+00 | step = 1.20e-04 | crit = 4.06e-01 (accepted ✅)
# it 3 | fun = 3.74275e+00 | step = 7.20e-05 | crit = 1.54e-01 (accepted ✅)
# it 4 | fun = 3.73828e+00 | step = 8.64e-05 | crit = 1.32e-01 (accepted ✅)
# it 6 | fun = 3.73207e+00 | step = 5.18e-05 | crit = 1.50e-01 (accepted ✅)
# it 7 | fun = 3.72540e+00 | step = 6.22e-05 | crit = 1.10e-01 (accepted ✅)
# it 8 | fun = 3.72329e+00 | step = 7.46e-05 | crit = 1.40e-01 (accepted ✅)
# it 10 | fun = 3.71958e+00 | step = 4.48e-05 | crit = 9.58e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 20 : P = 3.90707 W | L = 1.697e+00 mH | lam = -5.577e-02
# ---- Start gradient descent
# it 0 | fun = 4.03167e+00 | step = 1.00e-04
# it 1 | fun = 4.01341e+00 | step = 1.20e-04 | crit = 2.63e-01 (accepted ✅)
# it 2 | fun = 3.99067e+00 | step = 1.44e-04 | crit = 2.91e-01 (accepted ✅)
# it 3 | fun = 3.98021e+00 | step = 1.73e-04 | crit = 2.47e-01 (accepted ✅)
# it 5 | fun = 3.96185e+00 | step = 1.04e-04 | crit = 2.34e-01 (accepted ✅)
# it 6 | fun = 3.95166e+00 | step = 1.24e-04 | crit = 1.49e-01 (accepted ✅)
# it 7 | fun = 3.94535e+00 | step = 1.49e-04 | crit = 1.47e-01 (accepted ✅)
# it 9 | fun = 3.94306e+00 | step = 8.96e-05 | crit = 1.17e-01 (accepted ✅)
# it 10 | fun = 3.94022e+00 | step = 1.07e-04 | crit = 1.38e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 21 : P = 3.91973 W | L = 1.343e+00 mH | lam = 1.752e-01
# ---- Start gradient descent
# it 0 | fun = 4.02346e+00 | step = 1.00e-04
# it 1 | fun = 4.00830e+00 | step = 1.20e-04 | crit = 1.96e-01 (accepted ✅)
# it 2 | fun = 3.99634e+00 | step = 1.44e-04 | crit = 1.73e-01 (accepted ✅)
# it 3 | fun = 3.98286e+00 | step = 1.73e-04 | crit = 1.77e-01 (accepted ✅)
# it 4 | fun = 3.97163e+00 | step = 2.07e-04 | crit = 1.84e-01 (accepted ✅)
# it 6 | fun = 3.96504e+00 | step = 1.24e-04 | crit = 1.45e-01 (accepted ✅)
# it 7 | fun = 3.95782e+00 | step = 1.49e-04 | crit = 1.52e-01 (accepted ✅)
# it 8 | fun = 3.95487e+00 | step = 1.79e-04 | crit = 1.63e-01 (accepted ✅)
# it 9 | fun = 3.94777e+00 | step = 2.15e-04 | crit = 2.20e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 22 : P = 3.91861 W | L = 1.130e+00 mH | lam = 2.717e-01
# ---- Start gradient descent
# it 0 | fun = 3.96100e+00 | step = 1.00e-04
# it 1 | fun = 3.94902e+00 | step = 1.20e-04 | crit = 1.65e-01 (accepted ✅)
# it 2 | fun = 3.94147e+00 | step = 1.44e-04 | crit = 1.30e-01 (accepted ✅)
# it 3 | fun = 3.93305e+00 | step = 1.73e-04 | crit = 1.35e-01 (accepted ✅)
# it 4 | fun = 3.92389e+00 | step = 2.07e-04 | crit = 1.48e-01 (accepted ✅)
# it 5 | fun = 3.91593e+00 | step = 2.49e-04 | crit = 1.59e-01 (accepted ✅)
# it 7 | fun = 3.91182e+00 | step = 1.49e-04 | crit = 1.31e-01 (accepted ✅)
# it 8 | fun = 3.90500e+00 | step = 1.79e-04 | crit = 1.40e-01 (accepted ✅)
# it 9 | fun = 3.90096e+00 | step = 2.15e-04 | crit = 1.52e-01 (accepted ✅)
# it 10 | fun = 3.89441e+00 | step = 2.58e-04 | crit = 1.98e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 23 : P = 3.90349 W | L = 9.647e-01 mH | lam = 2.430e-01
# ---- Start gradient descent
# it 0 | fun = 3.89547e+00 | step = 1.00e-04
# it 1 | fun = 3.89051e+00 | step = 1.20e-04 | crit = 1.19e-01 (accepted ✅)
# it 2 | fun = 3.88642e+00 | step = 1.44e-04 | crit = 9.44e-02 (accepted ✅)
# it 3 | fun = 3.88029e+00 | step = 1.73e-04 | crit = 1.01e-01 (accepted ✅)
# it 4 | fun = 3.87529e+00 | step = 2.07e-04 | crit = 1.11e-01 (accepted ✅)
# it 5 | fun = 3.86997e+00 | step = 2.49e-04 | crit = 1.21e-01 (accepted ✅)
# it 8 | fun = 3.86795e+00 | step = 7.46e-05 | crit = 7.44e-02 (accepted ✅)
# it 9 | fun = 3.86581e+00 | step = 8.96e-05 | crit = 6.71e-02 (accepted ✅)
# it 10 | fun = 3.86352e+00 | step = 1.07e-04 | crit = 7.29e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 24 : P = 3.88766 W | L = 8.691e-01 mH | lam = 1.258e-01
# ---- Start gradient descent
# it 0 | fun = 3.87963e+00 | step = 1.00e-04
# it 1 | fun = 3.87718e+00 | step = 1.20e-04 | crit = 7.11e-02 (accepted ✅)
# it 4 | fun = 3.87681e+00 | step = 3.60e-05 | crit = 4.22e-02 (accepted ✅)
# it 5 | fun = 3.87582e+00 | step = 4.32e-05 | crit = 3.82e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 25 : P = 3.88381 W | L = 8.625e-01 mH | lam = -9.629e-03
# ---- Start gradient descent
# it 0 | fun = 3.89538e+00 | step = 1.00e-04
# it 2 | fun = 3.89454e+00 | step = 6.00e-05 | crit = 5.01e-02 (accepted ✅)
# it 4 | fun = 3.89437e+00 | step = 3.60e-05 | crit = 3.07e-02 (accepted ✅)
# it 5 | fun = 3.89400e+00 | step = 4.32e-05 | crit = 2.89e-02 (accepted ✅)
# it 6 | fun = 3.89357e+00 | step = 5.18e-05 | crit = 3.17e-02 (accepted ✅)
# it 10 | fun = 3.89340e+00 | step = 7.78e-06 | crit = 1.22e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 26 : P = 3.88099 W | L = 8.573e-01 mH | lam = -1.642e-01
# ---- Start gradient descent
# it 0 | fun = 3.91656e+00 | step = 1.00e-04
# it 1 | fun = 3.91596e+00 | step = 1.20e-04 | crit = 5.99e-02 (accepted ✅)
# it 3 | fun = 3.91539e+00 | step = 7.20e-05 | crit = 6.36e-02 (accepted ✅)
# it 4 | fun = 3.91470e+00 | step = 8.64e-05 | crit = 3.60e-02 (accepted ✅)
# it 8 | fun = 3.91430e+00 | step = 1.30e-05 | crit = 1.84e-02 (accepted ✅)
# it 9 | fun = 3.91426e+00 | step = 1.56e-05 | crit = 1.62e-02 (accepted ✅)
# it 10 | fun = 3.91395e+00 | step = 1.87e-05 | crit = 1.71e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 27 : P = 3.88315 W | L = 8.720e-01 mH | lam = -3.168e-01
# ---- Start gradient descent
# it 0 | fun = 3.93446e+00 | step = 1.00e-04
# it 1 | fun = 3.93393e+00 | step = 1.20e-04 | crit = 7.26e-02 (accepted ✅)
# it 3 | fun = 3.93141e+00 | step = 7.20e-05 | crit = 7.28e-02 (accepted ✅)
# it 5 | fun = 3.93097e+00 | step = 4.32e-05 | crit = 3.92e-02 (accepted ✅)
# it 6 | fun = 3.92992e+00 | step = 5.18e-05 | crit = 3.98e-02 (accepted ✅)
# it 8 | fun = 3.92943e+00 | step = 3.11e-05 | crit = 3.13e-02 (accepted ✅)
# it 10 | fun = 3.92900e+00 | step = 1.87e-05 | crit = 2.36e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 28 : P = 3.88844 W | L = 8.948e-01 mH | lam = -4.547e-01
# ---- Start gradient descent
# it 0 | fun = 3.94423e+00 | step = 1.00e-04
# it 1 | fun = 3.94091e+00 | step = 1.20e-04 | crit = 9.26e-02 (accepted ✅)
# it 2 | fun = 3.93857e+00 | step = 1.44e-04 | crit = 1.05e-01 (accepted ✅)
# it 3 | fun = 3.93415e+00 | step = 1.73e-04 | crit = 1.15e-01 (accepted ✅)
# it 5 | fun = 3.93065e+00 | step = 1.04e-04 | crit = 1.23e-01 (accepted ✅)
# it 6 | fun = 3.92652e+00 | step = 1.24e-04 | crit = 9.27e-02 (accepted ✅)
# it 7 | fun = 3.92394e+00 | step = 1.49e-04 | crit = 1.05e-01 (accepted ✅)
# it 8 | fun = 3.91995e+00 | step = 1.79e-04 | crit = 1.22e-01 (accepted ✅)
# it 10 | fun = 3.91561e+00 | step = 1.07e-04 | crit = 1.32e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 29 : P = 3.90039 W | L = 9.681e-01 mH | lam = -5.006e-01
# ---- Start gradient descent
# it 0 | fun = 3.91715e+00 | step = 1.00e-04
# it 1 | fun = 3.91206e+00 | step = 1.20e-04 | crit = 1.05e-01 (accepted ✅)
# it 2 | fun = 3.90921e+00 | step = 1.44e-04 | crit = 1.20e-01 (accepted ✅)
# it 3 | fun = 3.90486e+00 | step = 1.73e-04 | crit = 1.31e-01 (accepted ✅)
# it 5 | fun = 3.89927e+00 | step = 1.04e-04 | crit = 1.41e-01 (accepted ✅)
# it 6 | fun = 3.89351e+00 | step = 1.24e-04 | crit = 1.06e-01 (accepted ✅)
# it 7 | fun = 3.89172e+00 | step = 1.49e-04 | crit = 1.24e-01 (accepted ✅)
# it 8 | fun = 3.88844e+00 | step = 1.79e-04 | crit = 1.37e-01 (accepted ✅)
# it 10 | fun = 3.88225e+00 | step = 1.07e-04 | crit = 1.54e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 30 : P = 3.90792 W | L = 1.056e+00 mH | lam = -4.114e-01
# ---- Start gradient descent
# it 0 | fun = 3.88753e+00 | step = 1.00e-04
# it 1 | fun = 3.88442e+00 | step = 1.20e-04 | crit = 7.59e-02 (accepted ✅)
# it 2 | fun = 3.88143e+00 | step = 1.44e-04 | crit = 8.70e-02 (accepted ✅)
# it 4 | fun = 3.87977e+00 | step = 8.64e-05 | crit = 7.80e-02 (accepted ✅)
# it 6 | fun = 3.87837e+00 | step = 5.18e-05 | crit = 7.52e-02 (accepted ✅)
# it 7 | fun = 3.87627e+00 | step = 6.22e-05 | crit = 6.18e-02 (accepted ✅)
# it 8 | fun = 3.87564e+00 | step = 7.46e-05 | crit = 7.45e-02 (accepted ✅)
# it 9 | fun = 3.87445e+00 | step = 8.96e-05 | crit = 7.67e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 31 : P = 3.91368 W | L = 1.133e+00 mH | lam = -1.798e-01
# ---- Start gradient descent
# it 0 | fun = 3.90672e+00 | step = 1.00e-04
# it 1 | fun = 3.90210e+00 | step = 1.20e-04 | crit = 1.41e-01 (accepted ✅)
# it 4 | fun = 3.90082e+00 | step = 3.60e-05 | crit = 5.00e-02 (accepted ✅)
# it 9 | fun = 3.90080e+00 | step = 2.70e-06 | crit = 9.75e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 32 : P = 3.90907 W | L = 1.106e+00 mH | lam = 2.461e-02
# ---- Start gradient descent
# it 0 | fun = 3.92366e+00 | step = 1.00e-04
# it 1 | fun = 3.92111e+00 | step = 1.20e-04 | crit = 1.18e-01 (accepted ✅)
# it 2 | fun = 3.91783e+00 | step = 1.44e-04 | crit = 1.29e-01 (accepted ✅)
# it 4 | fun = 3.91502e+00 | step = 8.64e-05 | crit = 9.53e-02 (accepted ✅)
# it 5 | fun = 3.91272e+00 | step = 1.04e-04 | crit = 8.13e-02 (accepted ✅)
# it 6 | fun = 3.91136e+00 | step = 1.24e-04 | crit = 9.73e-02 (accepted ✅)
# it 8 | fun = 3.90796e+00 | step = 7.46e-05 | crit = 9.65e-02 (accepted ✅)
# it 10 | fun = 3.90741e+00 | step = 4.48e-05 | crit = 5.38e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 33 : P = 3.90604 W | L = 1.026e+00 mH | lam = 7.992e-02
# ---- Start gradient descent
# it 0 | fun = 3.90893e+00 | step = 1.00e-04
# it 1 | fun = 3.90564e+00 | step = 1.20e-04 | crit = 7.85e-02 (accepted ✅)
# it 2 | fun = 3.90333e+00 | step = 1.44e-04 | crit = 8.40e-02 (accepted ✅)
# it 3 | fun = 3.90106e+00 | step = 1.73e-04 | crit = 9.12e-02 (accepted ✅)
# it 6 | fun = 3.89990e+00 | step = 5.18e-05 | crit = 6.16e-02 (accepted ✅)
# it 7 | fun = 3.89883e+00 | step = 6.22e-05 | crit = 5.19e-02 (accepted ✅)
# it 8 | fun = 3.89790e+00 | step = 7.46e-05 | crit = 5.22e-02 (accepted ✅)
# it 10 | fun = 3.89743e+00 | step = 4.48e-05 | crit = 4.26e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 34 : P = 3.89880 W | L = 9.683e-01 mH | lam = 6.266e-03
# ---- Start gradient descent
# it 0 | fun = 3.89989e+00 | step = 1.00e-04
# it 2 | fun = 3.89923e+00 | step = 6.00e-05 | crit = 5.31e-02 (accepted ✅)
# it 4 | fun = 3.89898e+00 | step = 3.60e-05 | crit = 3.80e-02 (accepted ✅)
# it 5 | fun = 3.89854e+00 | step = 4.32e-05 | crit = 2.80e-02 (accepted ✅)
# it 6 | fun = 3.89826e+00 | step = 5.18e-05 | crit = 3.00e-02 (accepted ✅)
# it 9 | fun = 3.89812e+00 | step = 1.56e-05 | crit = 1.81e-02 (accepted ✅)
# it 10 | fun = 3.89787e+00 | step = 1.87e-05 | crit = 1.74e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 35 : P = 3.89616 W | L = 9.608e-01 mH | lam = -9.382e-02
# ---- Start gradient descent
# it 0 | fun = 3.90199e+00 | step = 1.00e-04
# it 3 | fun = 3.90175e+00 | step = 3.00e-05 | crit = 2.84e-02 (accepted ✅)
# it 9 | fun = 3.90174e+00 | step = 1.13e-06 | crit = 4.48e-03 (accepted ✅)
# it 10 | fun = 3.90145e+00 | step = 1.35e-06 | crit = 4.77e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 36 : P = 3.89657 W | L = 9.657e-01 mH | lam = -1.902e-01
# ---- Start gradient descent
# it 0 | fun = 3.90492e+00 | step = 1.00e-04
# it 2 | fun = 3.90415e+00 | step = 6.00e-05 | crit = 4.66e-02 (accepted ✅)
# it 4 | fun = 3.90356e+00 | step = 3.60e-05 | crit = 4.65e-02 (accepted ✅)
# it 5 | fun = 3.90306e+00 | step = 4.32e-05 | crit = 3.51e-02 (accepted ✅)
# it 6 | fun = 3.90288e+00 | step = 5.18e-05 | crit = 3.88e-02 (accepted ✅)
# it 7 | fun = 3.90197e+00 | step = 6.22e-05 | crit = 4.41e-02 (accepted ✅)
# it 10 | fun = 3.90180e+00 | step = 1.87e-05 | crit = 3.35e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 37 : P = 3.89945 W | L = 9.887e-01 mH | lam = -2.252e-01
# ---- Start gradient descent
# it 0 | fun = 3.90222e+00 | step = 1.00e-04
# it 2 | fun = 3.90192e+00 | step = 6.00e-05 | crit = 4.22e-02 (accepted ✅)
# it 3 | fun = 3.90142e+00 | step = 7.20e-05 | crit = 5.09e-02 (accepted ✅)
# it 5 | fun = 3.90037e+00 | step = 4.32e-05 | crit = 5.41e-02 (accepted ✅)
# it 6 | fun = 3.89963e+00 | step = 5.18e-05 | crit = 3.54e-02 (accepted ✅)
# it 8 | fun = 3.89943e+00 | step = 3.11e-05 | crit = 2.94e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 38 : P = 3.90029 W | L = 1.004e+00 mH | lam = -2.119e-01
# ---- Start gradient descent
# it 0 | fun = 3.89949e+00 | step = 1.00e-04
# it 1 | fun = 3.89912e+00 | step = 1.20e-04 | crit = 4.95e-02 (accepted ✅)
# it 4 | fun = 3.89859e+00 | step = 3.60e-05 | crit = 4.73e-02 (accepted ✅)
# it 6 | fun = 3.89824e+00 | step = 2.16e-05 | crit = 1.85e-02 (accepted ✅)
# it 7 | fun = 3.89807e+00 | step = 2.59e-05 | crit = 2.17e-02 (accepted ✅)
# it 10 | fun = 3.89800e+00 | step = 7.78e-06 | crit = 1.45e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 39 : P = 3.90149 W | L = 1.020e+00 mH | lam = -1.372e-01
# ---- Start gradient descent
# it 0 | fun = 3.89957e+00 | step = 1.00e-04
# it 8 | fun = 3.89949e+00 | step = 9.38e-07 | crit = 5.68e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 40 : P = 3.90142 W | L = 1.020e+00 mH | lam = -5.434e-02
# ---- Start gradient descent
# it 0 | fun = 3.90125e+00 | step = 1.00e-04
# it 2 | fun = 3.90086e+00 | step = 6.00e-05 | crit = 5.85e-02 (accepted ✅)
# it 4 | fun = 3.90047e+00 | step = 3.60e-05 | crit = 3.81e-02 (accepted ✅)
# it 6 | fun = 3.90014e+00 | step = 2.16e-05 | crit = 2.66e-02 (accepted ✅)
# it 7 | fun = 3.90002e+00 | step = 2.59e-05 | crit = 2.42e-02 (accepted ✅)
# it 8 | fun = 3.89995e+00 | step = 3.11e-05 | crit = 2.52e-02 (accepted ✅)
# it 9 | fun = 3.89930e+00 | step = 3.73e-05 | crit = 2.59e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 41 : P = 3.89930 W | L = 1.000e+00 mH | lam = -5.394e-02
# ---- Start gradient descent
# it 0 | fun = 3.89930e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 42 : P = 3.89930 W | L = 1.000e+00 mH | lam = -5.350e-02
# ---- Start gradient descent
# it 0 | fun = 3.89930e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 43 : P = 3.89930 W | L = 1.000e+00 mH | lam = -5.302e-02
# ---- Start gradient descent
# it 0 | fun = 3.89930e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 44 : P = 3.89930 W | L = 1.000e+00 mH | lam = -5.250e-02
# ---- Start gradient descent
# it 0 | fun = 3.89930e+00 | step = 1.00e-04
# it 9 | fun = 3.89929e+00 | step = 4.69e-07 | crit = 3.18e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 45 : P = 3.89929 W | L = 1.000e+00 mH | lam = -5.241e-02
# ---- Start gradient descent
# it 0 | fun = 3.89929e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 46 : P = 3.89929 W | L = 1.000e+00 mH | lam = -5.231e-02
# ---- Start gradient descent
# it 0 | fun = 3.89929e+00 | step = 1.00e-04
# it 10 | fun = 3.89925e+00 | step = 2.34e-07 | crit = 2.22e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 47 : P = 3.89925 W | L = 9.999e-01 mH | lam = -5.296e-02
# ---- Start gradient descent
# it 0 | fun = 3.89925e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 48 : P = 3.89925 W | L = 9.999e-01 mH | lam = -5.369e-02
# ---- Start gradient descent
# it 0 | fun = 3.89925e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 49 : P = 3.89925 W | L = 9.999e-01 mH | lam = -5.448e-02
# ---- Start gradient descent
# it 0 | fun = 3.89925e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.

# %%
ax1 = plt.plot(P_list, color = 'b')   
plt.ylabel('Losses', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.plot(L_list, color = 'r')
plt.ylabel("Inductance", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene
