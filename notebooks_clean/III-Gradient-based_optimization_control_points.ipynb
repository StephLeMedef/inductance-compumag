# %% [markdown]
# # III - Gradient-based design optimization with control points
#
# - **Parametric optimization** is not incompatible with gradient optimization.
# - The derivatives can be evaluated using **finite differences**, but this requires at least as many additional function evaluations as the number of parameters $N$. With many parameters (say $N>10$), using finite difference becomes **really costly**, especially when evaluating the function requires solving finite element problems.
# - Thanks to mathematical tools such as shape derivative and adjoint method, the derivatives can be evaluated efficiently with only $1$ additional resolution of a linear finite element problem per function to derivate (so-called adjoint).

# %%
from shapeOptInductor import gen_meshN, Id
import ngsolve as ngs
from ngsolve.webgui import Draw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First, we set up the number of control points (with adjoint method, computation time is almost independant of the number of parameters).

# %%
##############################################
NControlPoints = 30 # can be changed
##############################################
print(f"{NControlPoints = }")
# Out:
# NControlPoints = 30

# %% [markdown]
# ___________________________
# ## 1 - Geometry and meshing
#
# Then, we define the inductor geometry and generate the mesh.

# %%
# Geometric parameters
lz = 1e-2               # z-thickness of the inductor  
s = 4                   # symmetry factor (model 1/4th of the total space)

# Mesh generation
airgap = 4.11e-3 * np.ones(NControlPoints)              # Array of y-coordinates of control points along the airgap
maxh = 2e-3                                             # Maximum size of mesh element
mesh, p1, p2 = gen_meshN(airgap, maxh)                  # Generate the mesh and return the coordinates of control points on the first and second leg
xAirgaps = [p[0] for p in p1] + [p[0] for p in p2]      # Extract the x-coordinates of the control points

# Define the characteristics functions
XiAir = mesh.MaterialCF({"air": 1})
XiCore = mesh.MaterialCF({"core": 1})
XiCoil = mesh.MaterialCF({"coil": 1})
materials_regions = 1 * XiAir + 2 * XiCoil + 3 * XiCore

# Draw the geometry and mesh
Draw(materials_regions, mesh, radius=0.02)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 2 - State problem (time-harmonic magnetics)
#
# ### 2.a - Parameters definition
#
# We describe the magnetic permeabilities and the source currents.

# %%
# Electric current (assumed sinusoidal)
f = 5e4                                                         # Working frequency (Hz)
omega = 2 * np.pi * f                                           # rad/s
nb_turn = 200                                                   # Number of turn in the coil (no unit)
I = 2                                                           # Amplitude of the source current (A)
j = nb_turn / 2 * I / (ngs.Integrate(XiCoil, mesh)) * XiCoil    # Amplitude of the source current density  (A/m²)

# Magnetic permeabilities
mu0 = 4e-7 * np.pi                                              # Void permeability (H/m)
mur = 1000                                                      # Relative permeability of iron (no unit)
mu_iron = mur * mu0                                             # Iron permeability (H/m)
delta = 0.1                                                     # Loss angle associated with the coil (rad)
mu_coil = np.exp(-1j * delta) * mu0                             # Complex permeability of the coil

# %% [markdown]
# ### 2.b - Definition of the time-harmonic magnetics problem
#
# Then we can write the weak formulation and solve the following problem :
# $$\text{Find } \underline{a_h} \in H := \{\underline{a} \in H^1(\Omega) |\, \underline{a} = 0 \text{ on } \Gamma_D\} \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H, \int_\Omega \underline{\nu_h} (\nabla \underline{a_h}) \cdot (\nabla \underline{v})^* \,\mathrm{d}x = \int_{\Omega_{c, h}} j \underline{v}^* \, \mathrm{d}x. $$

# %%
def magWeakFormComplex(ah : ngs.FESpace.TrialFunction, 
                       v  : ngs.FESpace.TestFunction
                       ) -> tuple[ngs.BilinearForm, ngs.LinearForm]:
    """Return the sybolic weak form of the magnetic problem, 
    i.e, bilinear and linear forms (not assembled yet)."""

    # Bilinear form (transmission)
    bf =  1 / mu_iron * ngs.grad(ah) * ngs.grad(v) * ngs.dx("core")
    bf += 1 / mu_coil * ngs.grad(ah) * ngs.grad(v) * ngs.dx("coil")
    bf += 1 / mu0 * ngs.grad(ah) * ngs.grad(v) * ngs.dx("air")

    # Linear form (source)
    lf = j * v * ngs.dx("coil")

    return bf, lf


def solveStateComplex(mesh : ngs.Mesh
                      ) -> tuple[ngs.GridFunction, ngs.la.BaseMatrix]:
    """ Solve the time-harmonic magnetics problem """

    # Definition of function space
    fes = ngs.H1(mesh, order=1, dirichlet="arc|domainVert", complex=True)
    a, v = fes.TnT()

    # Definition of weak form
    bf, f = magWeakFormComplex(a, v)

    # Assembly
    K = ngs.BilinearForm(bf).Assemble()
    F = ngs.LinearForm(f).Assemble()

    # Solving
    gf = ngs.GridFunction(fes)
    Kinv = K.mat.Inverse(freedofs=fes.FreeDofs())
    gf.vec.data = Kinv * F.vec

    return gf, Kinv  # returning Kinv speed up adjoint calculation

# Example :
state, Kinv = solveStateComplex(mesh)
Draw(state.real, mesh, radius=0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 2.c - Definition of the post-processed quantities
#
# We define the losses and inductance
# $$
# \begin{array}{lcl}
# P(\underline{a}) &=& \displaystyle  s l_z  \pi f \int_{\Omega_c} \text{Im} \left( \frac{1}{\underline{\mu_c}} \right ) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# L(\underline{a}) &=& \displaystyle \frac{s l_z}{I^2} \int_\Omega \text{Re} \left( \underline{\nu} \right) |\nabla \underline{a}|^2 \;\mathrm{d}x,\\
# \end{array}$$
#
# with their directional derivatives.

# %%
def L(state : ngs.GridFunction, 
      mesh : ngs.Mesh
      ) -> float:
    """ Compute inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return s * lz / (I**2) * ngs.Integrate(nu.real * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddL(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of the inductance from the time-harmonic solution """
    nu = XiAir / mu0 + XiCoil / mu_coil + XiCore / mu_iron
    return 2 * s * lz / (I**2) * ngs.InnerProduct(nu.real * ngs.grad(state), ngs.grad(v)) * ngs.dx


def P(state : ngs.GridFunction,
      mesh : ngs.Mesh
      ) -> float:
    """ Compute AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return s * np.pi * f * lz * ngs.Integrate(nu.imag * ngs.Norm(ngs.grad(state)) ** 2, mesh)


def ddP(state : ngs.GridFunction, 
        v : ngs.FESpace.TestFunction
        ) -> ngs.comp.SumOfIntegrals:
    """ Compute directional derivative of AC losses in the conductor from the time-harmonic solution """
    nu = XiCoil / mu_coil
    return 2 * s * np.pi * f * lz * ngs.InnerProduct(nu.imag * ngs.grad(state), ngs.grad(v)) * ngs.dx

# Example :
print(f"Inductance : {L(state, mesh) *1000:.3} mH")
print(f"Losses : {P(state, mesh):.3} W")
# Out:
# Inductance : 1.0 mH
# Losses : 13.2 W

# %% [markdown]
# ___________________________
# ## 3 - Adjoint problem
#
# The adjoint method is an efficient way to compute derivatives of PDE-constrained problem; it requires solving one linear auxiliary problem per function $f$ to derivate that reads
#
# $$ \text{Find } \underline{p}_f \in H \quad \text{ s.t. } \quad
#     \forall \underline{v} \in H,  \quad \int_\Omega \nabla \underline{p}_f \cdot \left( \frac{\chi_c}{\underline{\mu_f}} + \frac{\chi_f}{\underline{\mu_f}} +\frac{\chi_a}{\underline{\mu_0}}\right)^* \nabla \underline{v} \; \mathrm{d}x = f'(\underline{a})(\underline{v}), $$
#
# with $f'$ the directional derivative of $f$, such that $F(\underline{a}) = \int_\Omega f(\underline{a}) \; \mathrm{d}x$.

# %%
def solveAdjoint(state : ngs.GridFunction,      
                 df : ngs.comp.SumOfIntegrals,
                 Kinv : ngs.la.BaseMatrix
                 ) -> ngs.GridFunction:
    """Solve the adjoint equation for a given directional derivative (right-hand side)"""

    fes = state.space
    v = fes.TestFunction()

    # Assemble the right-hand side
    f = ngs.LinearForm(-1. * df(state, v)).Assemble()
    
    # Solve using the adjoint (transconjugate) of provided FEM matrix
    gf = ngs.GridFunction(fes)
    gf.vec.data = Kinv.H * f.vec

    return gf

# Example :
adjoint_P = solveAdjoint(state, ddP, Kinv)
Draw(adjoint_P.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})

adjoint_L = solveAdjoint(state, ddL, Kinv)
Draw(adjoint_L.real, mesh, radius = 0.02, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ___________________________
# ## 4 - Continuous and discretized shape derivatives
#
# ### 4.a - Continuous expressions
#
# The shape derivative of the losses is a linear form obtained by Céa's method that reads
# $$\mathrm{d} P(\Omega)(\phi) = \text{Re}\left( s l_z \pi f \int_{\Omega_c} \text{Im}\left(\frac{1}{\underline{\mu_c}}\right) A_\phi \nabla \underline a \cdot (\nabla \underline a)^* \; \mathrm{d} x + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_P^* \mathrm{d} x - \int_{\Omega_c} j\, \text{div} \phi\, \underline p_P^*  \mathrm{d} x \right)  $$
#
# with $\phi\in H^1(\Omega)^2$ and $A_\phi = \text{div} \phi \, I_2 - \nabla \phi - \nabla \phi^\top$.

# %%
def sdP(state : ngs.GridFunction,
        adjoint_P : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) of the AC losses inside the coil """

    # Finite element spaces
    mesh = state.space.mesh
    FESReal = ngs.VectorH1(mesh)
    FEScomplex = ngs.VectorH1(mesh, complex=True)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_losses = s * np.pi * f * lz * (1 / mu_coil).imag
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_losses * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx("coil")
    shape_derivative_cplx += -j * XiCoil * ngs.div(phi) * adjoint_P * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_P)) * ngs.dx
    shape_derivative_cplx.Assemble()

    # Take the real part
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# Similarly, computing the shape derivative of the inductance leads to
#
# $$
#  \mathrm{d}  L(\Omega)(\phi) =  \text{Re}\left( \frac{s l_z}{I^2} \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot (\nabla \underline a)^* \; \mathrm{d} x  + \int_\Omega \underline{\nu} A_\phi \nabla \underline{a} \cdot \nabla \underline p_L^* \mathrm{d} x - \int_{\Omega_c} j\,\text{div} \phi\, \underline p_L^*  \mathrm{d} x \right)
# $$

# %%
def sdL(state : ngs.GridFunction,
        adjoint_L : ngs.GridFunction
        ) -> ngs.LinearForm :
    """ Compute the shape derivative (linear form) for the inductance"""

    # Finite element spaces
    mesh = state.space.mesh
    FEScomplex = ngs.H1(mesh, complex = True)**2 #ngs.VectorH1(mesh, complex=True)
    FESReal = ngs.H1(mesh)**2 # ngs.VectorH1(mesh)
    phi = FEScomplex.TestFunction()

    # Shorthands
    nu = (1 / mu0) * XiAir + (1 / mu_coil) * XiCoil + (1 / mu_iron) * XiCore
    coeff_induc = s * lz / (I**2) * nu.real
    dA = ngs.div(phi) * Id - ngs.grad(phi) - ngs.grad(phi).trans

    # Shape derivative 
    shape_derivative_cplx = ngs.LinearForm(FEScomplex)
    shape_derivative_cplx += coeff_induc * ngs.InnerProduct(dA * ngs.grad(state), ngs.grad(state)) * ngs.dx
    shape_derivative_cplx += -j * ngs.div(phi) * adjoint_L * ngs.dx
    shape_derivative_cplx += ngs.InnerProduct(nu * dA * ngs.grad(state), ngs.grad(adjoint_L)) * ngs.dx
    shape_derivative_cplx.Assemble()
    shape_derivative = ngs.LinearForm(FESReal)
    shape_derivative.vec.FV().NumPy()[:] = np.real(shape_derivative_cplx.vec.FV().NumPy()[:])

    return shape_derivative

# %% [markdown]
# ### 4.b - Discrete shape derivatives
# - The shape derivative is a **linear form**, from which we can extract a **descent direction**.
# - At the discrete level, one possibility is to extract directly the **nodal coefficients** from the assembled linear form, which is a vector.
#     - It represents the derivative of the losses with respect to the **coordinates of the mesh nodes**. In a sense, it represents the **shape gradient** of the discretized model.
#     - It takes the form of a nodal vector field, indicating in which direction one should move every node of the mesh to increase $f$ maximally.
# - We can therefore plot it, as below. It is almost 0 everywhere (should be exactly 0 up to the discretization errors), except on the **edges** of the geometry.
#     - Indeed, displacing a node at an interface modify the material distribution, which impacts the value of the scalar function, while moving a point from the inside doesn't change the geometry.
# - The **correctness** of the point-wise values of the discretized shape derivative can therefore be checked by **finite difference**, which is the purpose of the last section.

# %%
# Nodal identification of the shape derivative of the losses:
sdP_linear_form = sdP(state, adjoint_P)
discrete_shape_gradient_P = ngs.GridFunction(sdP_linear_form.space)
discrete_shape_gradient_P.vec.data = sdP_linear_form.vec
Draw(discrete_shape_gradient_P, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %%
# Nodal identification of the shape derivative of the inductance:
sdL_linear_form = sdL(state, adjoint_L)
discrete_shape_gradient_L = ngs.GridFunction(sdL_linear_form.space)
discrete_shape_gradient_L.vec.data = sdL_linear_form.vec
Draw(discrete_shape_gradient_L, mesh, radius = 0.02, vectors={"grid_size":100}, settings = {"Objects" : { "Wireframe" : False }})
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'Objects': {'Wireframe': Fal…
# BaseWebGuiScene

# %% [markdown]
# ### 4.c - Sensitivities with respect to the control points
#
# The sensitivities with respect to the $y$-coordinate of the control points (i.e., the first order derivatives of the quantity of interest) are simply obtained by taking the scalar product of the discretized shape derivative with a displacement field induced by the displacement of the control points.
#
# To obtain the true derivative, the displacement of the control point should be unitary. In the literature, this displacement can also be called a "velocity" because it can be used as a descent direction, transporting the geometry through a pseudo-time that are iterations of the algorithm. It is also possible (rather recommended) to use other descent direction using a regularization.

# %%
from shapeOptInductor import referenceVelocity

def sensitivities_y_control_points(state : ngs.GridFunction,
               adjoint : ngs.GridFunction,
               shape_derivative : callable,
               x_airgap : list[float]) -> list[float]:
    """ Compute the sensitivities of a function with respect to the y-value of the control points """

    velocityFields = referenceVelocity(state.space.mesh, x_airgap)
    sd_linearform = shape_derivative(state, adjoint)
    sd_discretized = ngs.GridFunction(ngs.VectorH1(state.space.mesh))
    sd_discretized.vec.FV().NumPy()[:] = np.real(sd_linearform.vec.FV().NumPy()[:])
    sensitivities = [ ngs.InnerProduct(sd_discretized.vec, refVelocity.vec) for refVelocity in velocityFields]
    return sensitivities

# Example:
sensitivities_P = sensitivities_y_control_points(state, adjoint_P, sdP, xAirgaps)
sensitivities_L = sensitivities_y_control_points(state, adjoint_L, sdL, xAirgaps)

print("dL/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_P) + " ]")
print("dP/dy = [ " + ', '.join(f"{k:.3e}" for k in sensitivities_L) + " ]")
# Out:
# dL/dy = [ 4.567e+01, 9.131e+01, 9.119e+01, 9.096e+01, 9.052e+01, 8.974e+01, 8.838e+01, 8.595e+01, 8.174e+01, 7.411e+01, 5.939e+01, 2.962e+01, -4.272e+01, -4.868e+02, -2.064e+03, -1.117e+03, -3.902e+02, -1.386e+02, -9.400e+01, -7.562e+01, -6.665e+01, -6.192e+01, -5.952e+01, -5.852e+01, -5.859e+01, -5.985e+01, -6.302e+01, -7.075e+01, -1.059e+02, -1.440e+02 ]
# dP/dy = [ -7.634e-03, -1.527e-02, -1.527e-02, -1.528e-02, -1.530e-02, -1.532e-02, -1.537e-02, -1.545e-02, -1.559e-02, -1.584e-02, -1.632e-02, -1.725e-02, -1.936e-02, -2.903e-02, -3.780e-02, -1.611e-02, -1.246e-02, -8.256e-03, -7.344e-03, -6.953e-03, -6.764e-03, -6.674e-03, -6.648e-03, -6.675e-03, -6.767e-03, -6.961e-03, -7.360e-03, -8.282e-03, -1.241e-02, -1.689e-02 ]

# %%
np.dot([1,2,3],[3,2,1.])
# Out:
# np.float64(10.0)

# %% [markdown]
# ________
# ## 5 - Gradient-based optimization
#
# ### 5.a - Optimization algorithm
# We use an augmented Lagrangian algorithm to solve the constrained optimization problem. That is to say, we maximize with respect to a Lagrange multiplier $\lambda$ a sequence of inner minimization problem with respect to the optimization variables $y_{airgap}$ :
#
# $$ \mathcal L(y_{airgap},\lambda) = P(y_{airgap}) + \lambda (L(y_{airgap}) - L_0) + \frac{\beta}{2} (L(y_{airgap}) - L_0)^2 $$

# %%
# Wrappers
regularize_symmetry_axis = True # flag to ensure dy/dx = 0 at the symmetry axis; otherwise problems happen...
L0 = 1e-3                       # target inductance
scale = 1/L0                    # constraint scaling factor

# container
current = {"x" : None, 
           "x_airgap" : None,
           "state" : None, 
           "mesh" : None, 
           "Kinv" : None, 
           "FEM_counter" : 0}

def update(x):
    current["x"] = x
    if regularize_symmetry_axis : y_airgap = [x[0]] + list(x)
    else : y_airgap = list(x)
    current["mesh"], p1, p2 = gen_meshN(y_airgap, maxh)    # Generate the mesh and return the coordinates of control points on the first and second leg
    current["x_airgap"] = [p[0] for p in p1] + [p[0] for p in p2]     # Extract the x-coordinates of the control points
    current["state"], current["Kinv"] = solveStateComplex(current["mesh"])
    current["FEM_counter"] += 1

def obj(x):
    if x is not current["x"]: update(x)
    return P(current["state"], current["mesh"])

def dObj(x):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddP, current["Kinv"])
    dobj = sensitivities_y_control_points(current["state"], adjoint, sdP, current["x_airgap"])
    if regularize_symmetry_axis : return np.array(dobj[1:])
    else : return np.array(dobj)


def cons(x, L0 = L0, scale = scale):
    if x is not current["x"]: update(x)
    return scale * (L(current["state"], current["mesh"]) - L0)

def dCons(x, scale = scale):
    if x is not current["x"]: update(x)
    adjoint = solveAdjoint(current["state"], ddL, current["Kinv"])
    dcons = sensitivities_y_control_points(current["state"], adjoint, sdL, current["x_airgap"])
    if regularize_symmetry_axis : return scale * np.array(dcons[1:])
    else : return scale * np.array(dcons)

# lagrangian

def lagrangian(x, lam, beta, fun, cons):
    objFunction = fun(x)
    constraint = cons(x)
    return objFunction + lam * constraint + beta / 2 * constraint **2

def dx_lagrangian(x, lam, beta, dfun, dcons, cons):
    dx_objFunction = dfun(x)
    dx_constraint = dcons(x)
    constraint = cons(x)
    return dx_objFunction + lam * dx_constraint + beta * constraint * dx_constraint

# %% [markdown]
# ### 5-b. Unconstrained optimization (gradient descent)

# %%
from shapeOptInductor import gradient_descent

# Example (unconstrained)
lam = 0
beta = 100
lbound = 0.5e-4
ubound = 1.395e-2
if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

lagr = lambda x: lagrangian(x, lam = lam,  beta = beta, fun = obj, cons = cons)
dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
res = gradient_descent(lagr, dlagr, x, step = 1e-3, iter_max = 50,
                       xlb = lbound, xub = ubound, precond = True, verbosity = 2)
# Out:
# ---- Start gradient descent
# it 0 | fun = 1.31689e+01 | step = 1.00e-03
# it 1 | fun = 1.20389e+01 | step = 1.20e-03 | crit = 1.72e+00 (accepted ✅)
# it 2 | fun = 1.07420e+01 | step = 1.44e-03 | crit = 1.78e+00 (accepted ✅)
# it 3 | fun = 9.32434e+00 | step = 1.73e-03 | crit = 1.84e+00 (accepted ✅)
# it 4 | fun = 7.79670e+00 | step = 2.07e-03 | crit = 1.98e+00 (accepted ✅)
# it 5 | fun = 6.77384e+00 | step = 2.49e-03 | crit = 1.91e+00 (accepted ✅)
# it 6 | fun = 2.18590e+01 | step = 1.24e-03 | crit = 1.91e+00 (rejected ❌)
# it 7 | fun = 6.88421e+00 | step = 6.22e-04 | crit = 1.91e+00 (rejected ❌)
# it 8 | fun = 6.31748e+00 | step = 7.46e-04 | crit = 1.17e+00 (accepted ✅)
# it 9 | fun = 5.93944e+00 | step = 8.96e-04 | crit = 9.16e-01 (accepted ✅)
# it 10 | fun = 5.79050e+00 | step = 1.07e-03 | crit = 9.90e-01 (accepted ✅)
# it 11 | fun = 5.81613e+00 | step = 5.37e-04 | crit = 9.90e-01 (rejected ❌)
# it 12 | fun = 5.52012e+00 | step = 6.45e-04 | crit = 1.18e+00 (accepted ✅)
# it 13 | fun = 5.84303e+00 | step = 3.22e-04 | crit = 1.18e+00 (rejected ❌)
# it 14 | fun = 5.48068e+00 | step = 3.87e-04 | crit = 5.75e-01 (accepted ✅)
# it 15 | fun = 5.42793e+00 | step = 1.93e-04 | crit = 5.75e-01 (rejected ❌)
# it 16 | fun = 5.39360e+00 | step = 2.32e-04 | crit = 5.61e-01 (accepted ✅)
# it 17 | fun = 5.30255e+00 | step = 2.79e-04 | crit = 4.28e-01 (accepted ✅)
# it 18 | fun = 5.19742e+00 | step = 3.34e-04 | crit = 4.59e-01 (accepted ✅)
# it 19 | fun = 5.09049e+00 | step = 4.01e-04 | crit = 4.95e-01 (accepted ✅)
# it 20 | fun = 5.16690e+00 | step = 2.01e-04 | crit = 4.95e-01 (rejected ❌)
# it 21 | fun = 5.07279e+00 | step = 2.41e-04 | crit = 4.12e-01 (accepted ✅)
# it 22 | fun = 5.03491e+00 | step = 2.89e-04 | crit = 4.68e-01 (accepted ✅)
# it 23 | fun = 5.04237e+00 | step = 1.44e-04 | crit = 4.68e-01 (rejected ❌)
# it 24 | fun = 5.00726e+00 | step = 1.73e-04 | crit = 3.47e-01 (accepted ✅)
# it 25 | fun = 4.98514e+00 | step = 2.08e-04 | crit = 3.46e-01 (accepted ✅)
# it 26 | fun = 4.96439e+00 | step = 2.50e-04 | crit = 4.28e-01 (accepted ✅)
# it 27 | fun = 4.95991e+00 | step = 1.25e-04 | crit = 4.28e-01 (rejected ❌)
# it 28 | fun = 4.93670e+00 | step = 1.50e-04 | crit = 3.09e-01 (accepted ✅)
# it 29 | fun = 4.89921e+00 | step = 1.80e-04 | crit = 3.30e-01 (accepted ✅)
# it 30 | fun = 4.88152e+00 | step = 2.16e-04 | crit = 3.51e-01 (accepted ✅)
# it 31 | fun = 4.87600e+00 | step = 1.08e-04 | crit = 3.51e-01 (rejected ❌)
# it 32 | fun = 4.86062e+00 | step = 1.29e-04 | crit = 2.99e-01 (accepted ✅)
# it 33 | fun = 4.82398e+00 | step = 1.55e-04 | crit = 2.94e-01 (accepted ✅)
# it 34 | fun = 4.81583e+00 | step = 7.76e-05 | crit = 2.94e-01 (rejected ❌)
# it 35 | fun = 4.81051e+00 | step = 9.32e-05 | crit = 2.28e-01 (accepted ✅)
# it 36 | fun = 4.79072e+00 | step = 1.12e-04 | crit = 2.50e-01 (accepted ✅)
# it 37 | fun = 4.77618e+00 | step = 1.34e-04 | crit = 2.72e-01 (accepted ✅)
# it 38 | fun = 4.75984e+00 | step = 1.61e-04 | crit = 2.79e-01 (accepted ✅)
# it 39 | fun = 4.75836e+00 | step = 8.05e-05 | crit = 2.79e-01 (rejected ❌)
# it 40 | fun = 4.74761e+00 | step = 9.66e-05 | crit = 2.35e-01 (accepted ✅)
# it 41 | fun = 4.72532e+00 | step = 1.16e-04 | crit = 2.46e-01 (accepted ✅)
# it 42 | fun = 4.71705e+00 | step = 1.39e-04 | crit = 2.67e-01 (accepted ✅)
# it 43 | fun = 4.70311e+00 | step = 1.67e-04 | crit = 2.88e-01 (accepted ✅)
# it 44 | fun = 4.70202e+00 | step = 8.35e-05 | crit = 2.88e-01 (rejected ❌)
# it 45 | fun = 4.69272e+00 | step = 1.00e-04 | crit = 2.32e-01 (accepted ✅)
# it 46 | fun = 4.67832e+00 | step = 1.20e-04 | crit = 2.42e-01 (accepted ✅)
# it 47 | fun = 4.66116e+00 | step = 1.44e-04 | crit = 2.80e-01 (accepted ✅)
# it 48 | fun = 4.66326e+00 | step = 7.21e-05 | crit = 2.80e-01 (rejected ❌)
# it 49 | fun = 4.65241e+00 | step = 8.65e-05 | crit = 1.93e-01 (accepted ✅)
# it 50 | fun = 4.63469e+00 | step = 1.04e-04 | crit = 2.22e-01 (accepted ✅)
# ---- Stopped after 50 because maximum number of iterations reached.

# %% [markdown]
# We plot the convergence and optimized design:

# %%
print(f"final airgap control point values : {res["x"][-1]}")
# Out:
# final airgap control point values : [0.00147704 0.00147527 0.00152052 0.00174541 0.00240954 0.00354216
#  0.00501676 0.00667959 0.00827225 0.00968429 0.01094175 0.01206161
#  0.013157   0.01376351 0.01395    0.01347307 0.01245921 0.01146821
#  0.01043171 0.00939339 0.00838407 0.00743675 0.00658312 0.00584781
#  0.00525439 0.00482381 0.00456807 0.00456431 0.00470923]

# %%
ax1 = plt.plot(res["fun"], color = 'b')   
plt.ylabel('Objective function', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.semilogy(res["stop_criterion"], color = 'r')
plt.ylabel("Stop criterion", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5-c. Constrained optimization with augmented Lagrangian

# %%
# Example (constrained optimization)

beta = 0.1
lam = 0
max_outer = 50
max_inner = 10
step = 1e-4

if regularize_symmetry_axis : x = airgap[1:]
else : x = airgap

lam = 0
x_list= [x]
P_list = [obj(x)]
L_list = [cons(x)/scale + L0]

for i in range(max_outer):
    print(f"it {i} : P = {P_list[-1]:.5f} W | L = {L_list[-1] :.3e} mH | lam = {lam:.3e}")
    lagr = lambda x: lagrangian(x, lam = lam, beta = beta, fun = obj, cons = cons)
    dlagr = lambda x: dx_lagrangian(x, lam = lam, beta = beta, dfun = dObj, dcons = dCons, cons = cons)
    res = gradient_descent(lagr, dlagr, x, step = step, xlb = lbound, xub = ubound, 
                           iter_max = max_inner, precond = True, verbosity = 1)
    x = res["x"][-1]
    x_list.append(x)
    L_list.append(cons(x)/scale + L0)
    P_list.append(obj(x))
    lam += beta * cons(x)
    beta *= 1.1
    
print(f"Final design : P = {P_list[-1]:.5f} W | L = {L_list[-1] :.3e} mH")
# Out:
# it 0 : P = 13.16888 W | L = 1.000e-03 mH | lam = 0.000e+00
# ---- Start gradient descent
# it 0 | fun = 1.31689e+01 | step = 1.00e-04
# it 1 | fun = 1.30222e+01 | step = 1.20e-04 | crit = 5.42e-01 (accepted ✅)
# it 2 | fun = 1.28430e+01 | step = 1.44e-04 | crit = 5.82e-01 (accepted ✅)
# it 3 | fun = 1.26574e+01 | step = 1.73e-04 | crit = 6.33e-01 (accepted ✅)
# it 4 | fun = 1.24390e+01 | step = 2.07e-04 | crit = 6.81e-01 (accepted ✅)
# it 5 | fun = 1.21824e+01 | step = 2.49e-04 | crit = 7.32e-01 (accepted ✅)
# it 6 | fun = 1.18765e+01 | step = 2.99e-04 | crit = 7.95e-01 (accepted ✅)
# it 7 | fun = 1.15410e+01 | step = 3.58e-04 | crit = 8.56e-01 (accepted ✅)
# it 8 | fun = 1.11292e+01 | step = 4.30e-04 | crit = 9.28e-01 (accepted ✅)
# it 9 | fun = 1.06621e+01 | step = 5.16e-04 | crit = 9.98e-01 (accepted ✅)
# it 10 | fun = 1.01119e+01 | step = 6.19e-04 | crit = 1.08e+00 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 1 : P = 10.11180 W | L = 9.484e-04 mH | lam = -5.161e-03
# ---- Start gradient descent
# it 0 | fun = 1.01122e+01 | step = 1.00e-04
# it 1 | fun = 1.00018e+01 | step = 1.20e-04 | crit = 4.67e-01 (accepted ✅)
# it 2 | fun = 9.87759e+00 | step = 1.44e-04 | crit = 5.09e-01 (accepted ✅)
# it 3 | fun = 9.73093e+00 | step = 1.73e-04 | crit = 5.53e-01 (accepted ✅)
# it 4 | fun = 9.54993e+00 | step = 2.07e-04 | crit = 6.03e-01 (accepted ✅)
# it 5 | fun = 9.33876e+00 | step = 2.49e-04 | crit = 6.54e-01 (accepted ✅)
# it 6 | fun = 9.09362e+00 | step = 2.99e-04 | crit = 7.12e-01 (accepted ✅)
# it 7 | fun = 8.81105e+00 | step = 3.58e-04 | crit = 7.72e-01 (accepted ✅)
# it 8 | fun = 8.47224e+00 | step = 4.30e-04 | crit = 8.33e-01 (accepted ✅)
# it 9 | fun = 8.08371e+00 | step = 5.16e-04 | crit = 9.02e-01 (accepted ✅)
# it 10 | fun = 7.63161e+00 | step = 6.19e-04 | crit = 9.73e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 2 : P = 7.63092 W | L = 9.260e-04 mH | lam = -1.330e-02
# ---- Start gradient descent
# it 0 | fun = 7.63224e+00 | step = 1.00e-04
# it 1 | fun = 7.55062e+00 | step = 1.20e-04 | crit = 4.15e-01 (accepted ✅)
# it 2 | fun = 7.44588e+00 | step = 1.44e-04 | crit = 4.53e-01 (accepted ✅)
# it 3 | fun = 7.32916e+00 | step = 1.73e-04 | crit = 4.89e-01 (accepted ✅)
# it 4 | fun = 7.18899e+00 | step = 2.07e-04 | crit = 5.30e-01 (accepted ✅)
# it 5 | fun = 7.02897e+00 | step = 2.49e-04 | crit = 5.72e-01 (accepted ✅)
# it 6 | fun = 6.84980e+00 | step = 2.99e-04 | crit = 6.08e-01 (accepted ✅)
# it 7 | fun = 6.63280e+00 | step = 3.58e-04 | crit = 6.52e-01 (accepted ✅)
# it 8 | fun = 6.41081e+00 | step = 4.30e-04 | crit = 6.92e-01 (accepted ✅)
# it 9 | fun = 6.15800e+00 | step = 5.16e-04 | crit = 7.22e-01 (accepted ✅)
# it 10 | fun = 5.89735e+00 | step = 6.19e-04 | crit = 7.47e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 3 : P = 5.89688 W | L = 9.689e-04 mH | lam = -1.706e-02
# ---- Start gradient descent
# it 0 | fun = 5.89747e+00 | step = 1.00e-04
# it 1 | fun = 5.84853e+00 | step = 1.20e-04 | crit = 3.10e-01 (accepted ✅)
# it 2 | fun = 5.79365e+00 | step = 1.44e-04 | crit = 3.37e-01 (accepted ✅)
# it 3 | fun = 5.72741e+00 | step = 1.73e-04 | crit = 3.64e-01 (accepted ✅)
# it 4 | fun = 5.64778e+00 | step = 2.07e-04 | crit = 3.95e-01 (accepted ✅)
# it 5 | fun = 5.56694e+00 | step = 2.49e-04 | crit = 4.26e-01 (accepted ✅)
# it 6 | fun = 5.45678e+00 | step = 2.99e-04 | crit = 4.60e-01 (accepted ✅)
# it 7 | fun = 5.34358e+00 | step = 3.58e-04 | crit = 4.94e-01 (accepted ✅)
# it 8 | fun = 5.20451e+00 | step = 4.30e-04 | crit = 5.30e-01 (accepted ✅)
# it 9 | fun = 5.05340e+00 | step = 5.16e-04 | crit = 5.68e-01 (accepted ✅)
# it 10 | fun = 4.88260e+00 | step = 6.19e-04 | crit = 6.04e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 4 : P = 4.88121 W | L = 9.352e-04 mH | lam = -2.569e-02
# ---- Start gradient descent
# it 0 | fun = 4.88319e+00 | step = 1.00e-04
# it 1 | fun = 4.85011e+00 | step = 1.20e-04 | crit = 2.55e-01 (accepted ✅)
# it 2 | fun = 4.81071e+00 | step = 1.44e-04 | crit = 2.78e-01 (accepted ✅)
# it 3 | fun = 4.76872e+00 | step = 1.73e-04 | crit = 3.01e-01 (accepted ✅)
# it 4 | fun = 4.71617e+00 | step = 2.07e-04 | crit = 3.26e-01 (accepted ✅)
# it 5 | fun = 4.65333e+00 | step = 2.49e-04 | crit = 3.52e-01 (accepted ✅)
# it 6 | fun = 4.58269e+00 | step = 2.99e-04 | crit = 3.79e-01 (accepted ✅)
# it 7 | fun = 4.50878e+00 | step = 3.58e-04 | crit = 3.97e-01 (accepted ✅)
# it 8 | fun = 4.43099e+00 | step = 4.30e-04 | crit = 4.11e-01 (accepted ✅)
# it 9 | fun = 4.34339e+00 | step = 5.16e-04 | crit = 4.22e-01 (accepted ✅)
# it 10 | fun = 4.25968e+00 | step = 6.19e-04 | crit = 4.28e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 5 : P = 4.25487 W | L = 8.647e-04 mH | lam = -4.550e-02
# ---- Start gradient descent
# it 0 | fun = 4.26250e+00 | step = 1.00e-04
# it 1 | fun = 4.24721e+00 | step = 1.20e-04 | crit = 1.75e-01 (accepted ✅)
# it 2 | fun = 4.22770e+00 | step = 1.44e-04 | crit = 1.89e-01 (accepted ✅)
# it 3 | fun = 4.20853e+00 | step = 1.73e-04 | crit = 2.03e-01 (accepted ✅)
# it 4 | fun = 4.18496e+00 | step = 2.07e-04 | crit = 2.18e-01 (accepted ✅)
# it 5 | fun = 4.15789e+00 | step = 2.49e-04 | crit = 2.33e-01 (accepted ✅)
# it 6 | fun = 4.12685e+00 | step = 2.99e-04 | crit = 2.48e-01 (accepted ✅)
# it 7 | fun = 4.09371e+00 | step = 3.58e-04 | crit = 2.63e-01 (accepted ✅)
# it 8 | fun = 4.06107e+00 | step = 4.30e-04 | crit = 2.82e-01 (accepted ✅)
# it 10 | fun = 4.05124e+00 | step = 2.58e-04 | crit = 1.79e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 6 : P = 4.04139 W | L = 8.329e-04 mH | lam = -7.240e-02
# ---- Start gradient descent
# it 0 | fun = 4.05596e+00 | step = 1.00e-04
# it 1 | fun = 4.04938e+00 | step = 1.20e-04 | crit = 1.32e-01 (accepted ✅)
# it 2 | fun = 4.03921e+00 | step = 1.44e-04 | crit = 1.51e-01 (accepted ✅)
# it 3 | fun = 4.03366e+00 | step = 1.73e-04 | crit = 1.51e-01 (accepted ✅)
# it 4 | fun = 4.02616e+00 | step = 2.07e-04 | crit = 1.50e-01 (accepted ✅)
# it 5 | fun = 4.02187e+00 | step = 2.49e-04 | crit = 1.68e-01 (accepted ✅)
# it 6 | fun = 4.01458e+00 | step = 2.99e-04 | crit = 1.77e-01 (accepted ✅)
# it 8 | fun = 4.00853e+00 | step = 1.79e-04 | crit = 1.40e-01 (accepted ✅)
# it 9 | fun = 3.99552e+00 | step = 2.15e-04 | crit = 1.70e-01 (accepted ✅)
# it 10 | fun = 3.98958e+00 | step = 2.58e-04 | crit = 1.70e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 7 : P = 3.97123 W | L = 7.970e-04 mH | lam = -1.084e-01
# ---- Start gradient descent
# it 0 | fun = 3.99724e+00 | step = 1.00e-04
# it 1 | fun = 3.99246e+00 | step = 1.20e-04 | crit = 1.04e-01 (accepted ✅)
# it 2 | fun = 3.98288e+00 | step = 1.44e-04 | crit = 1.36e-01 (accepted ✅)
# it 3 | fun = 3.97257e+00 | step = 1.73e-04 | crit = 1.47e-01 (accepted ✅)
# it 4 | fun = 3.96428e+00 | step = 2.07e-04 | crit = 1.60e-01 (accepted ✅)
# it 6 | fun = 3.96012e+00 | step = 1.24e-04 | crit = 1.00e-01 (accepted ✅)
# it 7 | fun = 3.95659e+00 | step = 1.49e-04 | crit = 1.20e-01 (accepted ✅)
# it 8 | fun = 3.95254e+00 | step = 1.79e-04 | crit = 1.19e-01 (accepted ✅)
# it 10 | fun = 3.95076e+00 | step = 1.07e-04 | crit = 9.37e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 8 : P = 3.92397 W | L = 7.917e-04 mH | lam = -1.489e-01
# ---- Start gradient descent
# it 0 | fun = 3.95963e+00 | step = 1.00e-04
# it 1 | fun = 3.95672e+00 | step = 1.20e-04 | crit = 9.60e-02 (accepted ✅)
# it 2 | fun = 3.95427e+00 | step = 1.44e-04 | crit = 1.08e-01 (accepted ✅)
# it 3 | fun = 3.95015e+00 | step = 1.73e-04 | crit = 1.13e-01 (accepted ✅)
# it 4 | fun = 3.94601e+00 | step = 2.07e-04 | crit = 1.27e-01 (accepted ✅)
# it 5 | fun = 3.94313e+00 | step = 2.49e-04 | crit = 1.43e-01 (accepted ✅)
# it 7 | fun = 3.93946e+00 | step = 1.49e-04 | crit = 1.16e-01 (accepted ✅)
# it 8 | fun = 3.93715e+00 | step = 1.79e-04 | crit = 1.20e-01 (accepted ✅)
# it 9 | fun = 3.93348e+00 | step = 2.15e-04 | crit = 1.48e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 9 : P = 3.89634 W | L = 7.841e-04 mH | lam = -1.952e-01
# ---- Start gradient descent
# it 0 | fun = 3.94397e+00 | step = 1.00e-04
# it 1 | fun = 3.94084e+00 | step = 1.20e-04 | crit = 9.29e-02 (accepted ✅)
# it 2 | fun = 3.93810e+00 | step = 1.44e-04 | crit = 1.24e-01 (accepted ✅)
# it 3 | fun = 3.93565e+00 | step = 1.73e-04 | crit = 1.11e-01 (accepted ✅)
# it 5 | fun = 3.93362e+00 | step = 1.04e-04 | crit = 8.73e-02 (accepted ✅)
# it 6 | fun = 3.93134e+00 | step = 1.24e-04 | crit = 9.32e-02 (accepted ✅)
# it 7 | fun = 3.92981e+00 | step = 1.49e-04 | crit = 1.07e-01 (accepted ✅)
# it 9 | fun = 3.92774e+00 | step = 8.96e-05 | crit = 7.53e-02 (accepted ✅)
# it 10 | fun = 3.92396e+00 | step = 1.07e-04 | crit = 1.04e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 10 : P = 3.87690 W | L = 7.865e-04 mH | lam = -2.456e-01
# ---- Start gradient descent
# it 0 | fun = 3.93525e+00 | step = 1.00e-04
# it 1 | fun = 3.93266e+00 | step = 1.20e-04 | crit = 9.06e-02 (accepted ✅)
# it 2 | fun = 3.92868e+00 | step = 1.44e-04 | crit = 1.13e-01 (accepted ✅)
# it 3 | fun = 3.92388e+00 | step = 1.73e-04 | crit = 1.22e-01 (accepted ✅)
# it 5 | fun = 3.92254e+00 | step = 1.04e-04 | crit = 8.56e-02 (accepted ✅)
# it 6 | fun = 3.92038e+00 | step = 1.24e-04 | crit = 8.94e-02 (accepted ✅)
# it 8 | fun = 3.91910e+00 | step = 7.46e-05 | crit = 7.07e-02 (accepted ✅)
# it 9 | fun = 3.91780e+00 | step = 8.96e-05 | crit = 7.25e-02 (accepted ✅)
# it 10 | fun = 3.91689e+00 | step = 1.07e-04 | crit = 8.47e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 11 : P = 3.86109 W | L = 7.950e-04 mH | lam = -2.987e-01
# ---- Start gradient descent
# it 0 | fun = 3.92833e+00 | step = 1.00e-04
# it 1 | fun = 3.92566e+00 | step = 1.20e-04 | crit = 8.82e-02 (accepted ✅)
# it 3 | fun = 3.92487e+00 | step = 7.20e-05 | crit = 7.18e-02 (accepted ✅)
# it 4 | fun = 3.92329e+00 | step = 8.64e-05 | crit = 7.02e-02 (accepted ✅)
# it 5 | fun = 3.92252e+00 | step = 1.04e-04 | crit = 8.54e-02 (accepted ✅)
# it 6 | fun = 3.92057e+00 | step = 1.24e-04 | crit = 8.99e-02 (accepted ✅)
# it 8 | fun = 3.91937e+00 | step = 7.46e-05 | crit = 7.30e-02 (accepted ✅)
# it 9 | fun = 3.91778e+00 | step = 8.96e-05 | crit = 7.18e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 12 : P = 3.85955 W | L = 8.205e-04 mH | lam = -3.500e-01
# ---- Start gradient descent
# it 0 | fun = 3.92743e+00 | step = 1.00e-04
# it 3 | fun = 3.92648e+00 | step = 3.00e-05 | crit = 4.82e-02 (accepted ✅)
# it 4 | fun = 3.92562e+00 | step = 3.60e-05 | crit = 4.55e-02 (accepted ✅)
# it 6 | fun = 3.92478e+00 | step = 2.16e-05 | crit = 3.53e-02 (accepted ✅)
# it 8 | fun = 3.92435e+00 | step = 1.30e-05 | crit = 2.77e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 13 : P = 3.85594 W | L = 8.192e-04 mH | lam = -4.067e-01
# ---- Start gradient descent
# it 0 | fun = 3.93512e+00 | step = 1.00e-04
# it 7 | fun = 3.93491e+00 | step = 1.88e-06 | crit = 1.11e-02 (accepted ✅)
# it 8 | fun = 3.93475e+00 | step = 2.25e-06 | crit = 1.21e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 14 : P = 3.85574 W | L = 8.196e-04 mH | lam = -4.690e-01
# ---- Start gradient descent
# it 0 | fun = 3.94655e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 15 : P = 3.85574 W | L = 8.196e-04 mH | lam = -5.375e-01
# ---- Start gradient descent
# it 0 | fun = 3.95953e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 16 : P = 3.85574 W | L = 8.196e-04 mH | lam = -6.129e-01
# ---- Start gradient descent
# it 0 | fun = 3.97381e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 17 : P = 3.85574 W | L = 8.196e-04 mH | lam = -6.958e-01
# ---- Start gradient descent
# it 0 | fun = 3.98952e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 18 : P = 3.85574 W | L = 8.196e-04 mH | lam = -7.870e-01
# ---- Start gradient descent
# it 0 | fun = 4.00680e+00 | step = 1.00e-04
# it 1 | fun = 4.00420e+00 | step = 1.20e-04 | crit = 1.19e-01 (accepted ✅)
# it 2 | fun = 3.99939e+00 | step = 1.44e-04 | crit = 1.02e-01 (accepted ✅)
# it 3 | fun = 3.99206e+00 | step = 1.73e-04 | crit = 1.15e-01 (accepted ✅)
# it 4 | fun = 3.98669e+00 | step = 2.07e-04 | crit = 1.33e-01 (accepted ✅)
# it 6 | fun = 3.98170e+00 | step = 1.24e-04 | crit = 1.23e-01 (accepted ✅)
# it 7 | fun = 3.97868e+00 | step = 1.49e-04 | crit = 1.40e-01 (accepted ✅)
# it 8 | fun = 3.97459e+00 | step = 1.79e-04 | crit = 1.54e-01 (accepted ✅)
# it 10 | fun = 3.96792e+00 | step = 1.07e-04 | crit = 1.50e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 19 : P = 3.86811 W | L = 8.784e-04 mH | lam = -8.546e-01
# ---- Start gradient descent
# it 0 | fun = 3.97656e+00 | step = 1.00e-04
# it 1 | fun = 3.97065e+00 | step = 1.20e-04 | crit = 1.32e-01 (accepted ✅)
# it 2 | fun = 3.96680e+00 | step = 1.44e-04 | crit = 1.54e-01 (accepted ✅)
# it 3 | fun = 3.96198e+00 | step = 1.73e-04 | crit = 1.64e-01 (accepted ✅)
# it 5 | fun = 3.95535e+00 | step = 1.04e-04 | crit = 1.63e-01 (accepted ✅)
# it 6 | fun = 3.94813e+00 | step = 1.24e-04 | crit = 1.24e-01 (accepted ✅)
# it 7 | fun = 3.94223e+00 | step = 1.49e-04 | crit = 1.48e-01 (accepted ✅)
# it 9 | fun = 3.93556e+00 | step = 8.96e-05 | crit = 1.24e-01 (accepted ✅)
# it 10 | fun = 3.92995e+00 | step = 1.07e-04 | crit = 1.14e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 20 : P = 3.87378 W | L = 9.358e-04 mH | lam = -8.939e-01
# ---- Start gradient descent
# it 0 | fun = 3.93260e+00 | step = 1.00e-04
# it 1 | fun = 3.92629e+00 | step = 1.20e-04 | crit = 1.34e-01 (accepted ✅)
# it 2 | fun = 3.92020e+00 | step = 1.44e-04 | crit = 1.59e-01 (accepted ✅)
# it 4 | fun = 3.91311e+00 | step = 8.64e-05 | crit = 1.32e-01 (accepted ✅)
# it 5 | fun = 3.90600e+00 | step = 1.04e-04 | crit = 1.18e-01 (accepted ✅)
# it 6 | fun = 3.89780e+00 | step = 1.24e-04 | crit = 1.32e-01 (accepted ✅)
# it 7 | fun = 3.88930e+00 | step = 1.49e-04 | crit = 1.53e-01 (accepted ✅)
# it 9 | fun = 3.88213e+00 | step = 8.96e-05 | crit = 1.43e-01 (accepted ✅)
# it 10 | fun = 3.87628e+00 | step = 1.07e-04 | crit = 1.57e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 21 : P = 3.87256 W | L = 9.958e-04 mH | lam = -8.967e-01
# ---- Start gradient descent
# it 0 | fun = 3.87630e+00 | step = 1.00e-04
# it 1 | fun = 3.87099e+00 | step = 1.20e-04 | crit = 1.69e-01 (accepted ✅)
# it 3 | fun = 3.86246e+00 | step = 7.20e-05 | crit = 1.65e-01 (accepted ✅)
# it 4 | fun = 3.85540e+00 | step = 8.64e-05 | crit = 1.21e-01 (accepted ✅)
# it 5 | fun = 3.84713e+00 | step = 1.04e-04 | crit = 1.30e-01 (accepted ✅)
# it 6 | fun = 3.83959e+00 | step = 1.24e-04 | crit = 1.59e-01 (accepted ✅)
# it 8 | fun = 3.83213e+00 | step = 7.46e-05 | crit = 1.66e-01 (accepted ✅)
# it 9 | fun = 3.82376e+00 | step = 8.96e-05 | crit = 1.51e-01 (accepted ✅)
# it 10 | fun = 3.81936e+00 | step = 1.07e-04 | crit = 1.90e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 22 : P = 3.86873 W | L = 1.056e-03 mH | lam = -8.550e-01
# ---- Start gradient descent
# it 0 | fun = 3.82183e+00 | step = 1.00e-04
# it 2 | fun = 3.81301e+00 | step = 6.00e-05 | crit = 1.31e-01 (accepted ✅)
# it 3 | fun = 3.80784e+00 | step = 7.20e-05 | crit = 1.10e-01 (accepted ✅)
# it 4 | fun = 3.79922e+00 | step = 8.64e-05 | crit = 1.21e-01 (accepted ✅)
# it 5 | fun = 3.78986e+00 | step = 1.04e-04 | crit = 1.34e-01 (accepted ✅)
# it 6 | fun = 3.77761e+00 | step = 1.24e-04 | crit = 1.50e-01 (accepted ✅)
# it 7 | fun = 3.76287e+00 | step = 1.49e-04 | crit = 1.70e-01 (accepted ✅)
# it 8 | fun = 3.75280e+00 | step = 1.79e-04 | crit = 1.99e-01 (accepted ✅)
# it 10 | fun = 3.74573e+00 | step = 1.07e-04 | crit = 2.01e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 23 : P = 3.90505 W | L = 1.207e-03 mH | lam = -6.868e-01
# ---- Start gradient descent
# it 0 | fun = 3.78224e+00 | step = 1.00e-04
# it 1 | fun = 3.77413e+00 | step = 1.20e-04 | crit = 2.69e-01 (accepted ✅)
# it 3 | fun = 3.76373e+00 | step = 7.20e-05 | crit = 1.57e-01 (accepted ✅)
# it 4 | fun = 3.75737e+00 | step = 8.64e-05 | crit = 1.25e-01 (accepted ✅)
# it 6 | fun = 3.75366e+00 | step = 5.18e-05 | crit = 1.20e-01 (accepted ✅)
# it 7 | fun = 3.75078e+00 | step = 6.22e-05 | crit = 1.53e-01 (accepted ✅)
# it 8 | fun = 3.74565e+00 | step = 7.46e-05 | crit = 1.52e-01 (accepted ✅)
# it 10 | fun = 3.74106e+00 | step = 4.48e-05 | crit = 1.41e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 24 : P = 3.86546 W | L = 1.210e-03 mH | lam = -4.989e-01
# ---- Start gradient descent
# it 0 | fun = 3.78246e+00 | step = 1.00e-04
# it 1 | fun = 3.77884e+00 | step = 1.20e-04 | crit = 1.24e-01 (accepted ✅)
# it 4 | fun = 3.77378e+00 | step = 3.60e-05 | crit = 9.87e-02 (accepted ✅)
# it 5 | fun = 3.77181e+00 | step = 4.32e-05 | crit = 7.32e-02 (accepted ✅)
# it 6 | fun = 3.76987e+00 | step = 5.18e-05 | crit = 8.42e-02 (accepted ✅)
# it 8 | fun = 3.76788e+00 | step = 3.11e-05 | crit = 7.57e-02 (accepted ✅)
# it 9 | fun = 3.76648e+00 | step = 3.73e-05 | crit = 8.60e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 25 : P = 3.85922 W | L = 1.245e-03 mH | lam = -2.573e-01
# ---- Start gradient descent
# it 0 | fun = 3.82871e+00 | step = 1.00e-04
# it 5 | fun = 3.82829e+00 | step = 7.50e-06 | crit = 2.52e-02 (accepted ✅)
# it 8 | fun = 3.82814e+00 | step = 2.25e-06 | crit = 1.30e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 26 : P = 3.85868 W | L = 1.240e-03 mH | lam = 3.154e-03
# ---- Start gradient descent
# it 0 | fun = 3.89386e+00 | step = 1.00e-04
# it 2 | fun = 3.89180e+00 | step = 6.00e-05 | crit = 1.21e-01 (accepted ✅)
# it 4 | fun = 3.88933e+00 | step = 3.60e-05 | crit = 9.46e-02 (accepted ✅)
# it 5 | fun = 3.88800e+00 | step = 4.32e-05 | crit = 7.99e-02 (accepted ✅)
# it 7 | fun = 3.88588e+00 | step = 2.59e-05 | crit = 7.55e-02 (accepted ✅)
# it 8 | fun = 3.88472e+00 | step = 3.11e-05 | crit = 5.76e-02 (accepted ✅)
# it 9 | fun = 3.88334e+00 | step = 3.73e-05 | crit = 6.52e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 27 : P = 3.85962 W | L = 1.197e-03 mH | lam = 2.378e-01
# ---- Start gradient descent
# it 0 | fun = 3.93183e+00 | step = 1.00e-04
# it 2 | fun = 3.92533e+00 | step = 6.00e-05 | crit = 1.37e-01 (accepted ✅)
# it 3 | fun = 3.92100e+00 | step = 7.20e-05 | crit = 1.09e-01 (accepted ✅)
# it 4 | fun = 3.91468e+00 | step = 8.64e-05 | crit = 1.24e-01 (accepted ✅)
# it 5 | fun = 3.91202e+00 | step = 1.04e-04 | crit = 1.43e-01 (accepted ✅)
# it 7 | fun = 3.90633e+00 | step = 6.22e-05 | crit = 1.27e-01 (accepted ✅)
# it 8 | fun = 3.90220e+00 | step = 7.46e-05 | crit = 1.02e-01 (accepted ✅)
# it 10 | fun = 3.89993e+00 | step = 4.48e-05 | crit = 9.16e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 28 : P = 3.86813 W | L = 1.104e-03 mH | lam = 3.741e-01
# ---- Start gradient descent
# it 0 | fun = 3.91481e+00 | step = 1.00e-04
# it 1 | fun = 3.90533e+00 | step = 1.20e-04 | crit = 1.32e-01 (accepted ✅)
# it 2 | fun = 3.89730e+00 | step = 1.44e-04 | crit = 1.38e-01 (accepted ✅)
# it 3 | fun = 3.88735e+00 | step = 1.73e-04 | crit = 1.47e-01 (accepted ✅)
# it 5 | fun = 3.88388e+00 | step = 1.04e-04 | crit = 1.39e-01 (accepted ✅)
# it 6 | fun = 3.88030e+00 | step = 1.24e-04 | crit = 1.80e-01 (accepted ✅)
# it 7 | fun = 3.87434e+00 | step = 1.49e-04 | crit = 1.98e-01 (accepted ✅)
# it 9 | fun = 3.86867e+00 | step = 8.96e-05 | crit = 1.47e-01 (accepted ✅)
# it 10 | fun = 3.86697e+00 | step = 1.07e-04 | crit = 1.27e-01 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 29 : P = 3.86947 W | L = 9.932e-04 mH | lam = 3.643e-01
# ---- Start gradient descent
# it 0 | fun = 3.86704e+00 | step = 1.00e-04
# it 1 | fun = 3.86383e+00 | step = 1.20e-04 | crit = 1.62e-01 (accepted ✅)
# it 2 | fun = 3.86091e+00 | step = 1.44e-04 | crit = 1.71e-01 (accepted ✅)
# it 4 | fun = 3.85543e+00 | step = 8.64e-05 | crit = 1.35e-01 (accepted ✅)
# it 5 | fun = 3.85382e+00 | step = 1.04e-04 | crit = 1.15e-01 (accepted ✅)
# it 7 | fun = 3.84926e+00 | step = 6.22e-05 | crit = 1.09e-01 (accepted ✅)
# it 8 | fun = 3.84679e+00 | step = 7.46e-05 | crit = 7.60e-02 (accepted ✅)
# it 9 | fun = 3.84292e+00 | step = 8.96e-05 | crit = 8.15e-02 (accepted ✅)
# it 10 | fun = 3.84061e+00 | step = 1.07e-04 | crit = 8.86e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 30 : P = 3.85457 W | L = 9.578e-04 mH | lam = 2.974e-01
# ---- Start gradient descent
# it 0 | fun = 3.84357e+00 | step = 1.00e-04
# it 2 | fun = 3.84199e+00 | step = 6.00e-05 | crit = 6.82e-02 (accepted ✅)
# it 4 | fun = 3.84088e+00 | step = 3.60e-05 | crit = 5.64e-02 (accepted ✅)
# it 5 | fun = 3.83988e+00 | step = 4.32e-05 | crit = 5.48e-02 (accepted ✅)
# it 6 | fun = 3.83824e+00 | step = 5.18e-05 | crit = 6.04e-02 (accepted ✅)
# it 7 | fun = 3.83693e+00 | step = 6.22e-05 | crit = 6.73e-02 (accepted ✅)
# it 8 | fun = 3.83559e+00 | step = 7.46e-05 | crit = 7.87e-02 (accepted ✅)
# it 10 | fun = 3.83376e+00 | step = 4.48e-05 | crit = 7.13e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 31 : P = 3.84857 W | L = 9.394e-04 mH | lam = 1.917e-01
# ---- Start gradient descent
# it 0 | fun = 3.84048e+00 | step = 1.00e-04
# it 3 | fun = 3.84006e+00 | step = 3.00e-05 | crit = 4.62e-02 (accepted ✅)
# it 4 | fun = 3.83929e+00 | step = 3.60e-05 | crit = 4.67e-02 (accepted ✅)
# it 6 | fun = 3.83867e+00 | step = 2.16e-05 | crit = 4.01e-02 (accepted ✅)
# it 7 | fun = 3.83805e+00 | step = 2.59e-05 | crit = 3.98e-02 (accepted ✅)
# it 8 | fun = 3.83731e+00 | step = 3.11e-05 | crit = 4.18e-02 (accepted ✅)
# it 9 | fun = 3.83674e+00 | step = 3.73e-05 | crit = 4.82e-02 (accepted ✅)
# it 10 | fun = 3.83609e+00 | step = 4.48e-05 | crit = 5.63e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 32 : P = 3.84443 W | L = 9.360e-04 mH | lam = 6.883e-02
# ---- Start gradient descent
# it 0 | fun = 3.84434e+00 | step = 1.00e-04
# it 1 | fun = 3.84035e+00 | step = 1.20e-04 | crit = 8.93e-02 (accepted ✅)
# it 4 | fun = 3.84002e+00 | step = 3.60e-05 | crit = 4.87e-02 (accepted ✅)
# it 5 | fun = 3.83923e+00 | step = 4.32e-05 | crit = 5.26e-02 (accepted ✅)
# it 7 | fun = 3.83898e+00 | step = 2.59e-05 | crit = 3.54e-02 (accepted ✅)
# it 9 | fun = 3.83890e+00 | step = 1.56e-05 | crit = 2.72e-02 (accepted ✅)
# it 10 | fun = 3.83815e+00 | step = 1.87e-05 | crit = 3.46e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 33 : P = 3.83807 W | L = 9.337e-04 mH | lam = -7.118e-02
# ---- Start gradient descent
# it 0 | fun = 3.84790e+00 | step = 1.00e-04
# it 3 | fun = 3.84722e+00 | step = 3.00e-05 | crit = 4.39e-02 (accepted ✅)
# it 4 | fun = 3.84641e+00 | step = 3.60e-05 | crit = 4.30e-02 (accepted ✅)
# it 6 | fun = 3.84610e+00 | step = 2.16e-05 | crit = 3.45e-02 (accepted ✅)
# it 7 | fun = 3.84562e+00 | step = 2.59e-05 | crit = 3.61e-02 (accepted ✅)
# it 8 | fun = 3.84515e+00 | step = 3.11e-05 | crit = 4.26e-02 (accepted ✅)
# it 9 | fun = 3.84483e+00 | step = 3.73e-05 | crit = 5.05e-02 (accepted ✅)
# it 10 | fun = 3.84085e+00 | step = 4.48e-05 | crit = 5.24e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 34 : P = 3.83529 W | L = 9.550e-04 mH | lam = -1.757e-01
# ---- Start gradient descent
# it 0 | fun = 3.84579e+00 | step = 1.00e-04
# it 1 | fun = 3.84348e+00 | step = 1.20e-04 | crit = 7.75e-02 (accepted ✅)
# it 4 | fun = 3.84272e+00 | step = 3.60e-05 | crit = 5.15e-02 (accepted ✅)
# it 5 | fun = 3.84201e+00 | step = 4.32e-05 | crit = 5.21e-02 (accepted ✅)
# it 6 | fun = 3.84161e+00 | step = 5.18e-05 | crit = 6.00e-02 (accepted ✅)
# it 8 | fun = 3.84032e+00 | step = 3.11e-05 | crit = 5.72e-02 (accepted ✅)
# it 9 | fun = 3.83925e+00 | step = 3.73e-05 | crit = 4.44e-02 (accepted ✅)
# it 10 | fun = 3.83864e+00 | step = 4.48e-05 | crit = 4.99e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 35 : P = 3.83247 W | L = 9.710e-04 mH | lam = -2.498e-01
# ---- Start gradient descent
# it 0 | fun = 3.84090e+00 | step = 1.00e-04
# it 2 | fun = 3.84010e+00 | step = 6.00e-05 | crit = 7.29e-02 (accepted ✅)
# it 4 | fun = 3.83899e+00 | step = 3.60e-05 | crit = 6.53e-02 (accepted ✅)
# it 5 | fun = 3.83805e+00 | step = 4.32e-05 | crit = 5.43e-02 (accepted ✅)
# it 7 | fun = 3.83728e+00 | step = 2.59e-05 | crit = 4.92e-02 (accepted ✅)
# it 8 | fun = 3.83619e+00 | step = 3.11e-05 | crit = 4.36e-02 (accepted ✅)
# it 9 | fun = 3.83548e+00 | step = 3.73e-05 | crit = 4.63e-02 (accepted ✅)
# it 10 | fun = 3.83493e+00 | step = 4.48e-05 | crit = 5.85e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 36 : P = 3.83624 W | L = 1.005e-03 mH | lam = -2.346e-01
# ---- Start gradient descent
# it 0 | fun = 3.83502e+00 | step = 1.00e-04
# it 3 | fun = 3.83338e+00 | step = 3.00e-05 | crit = 6.05e-02 (accepted ✅)
# it 4 | fun = 3.83261e+00 | step = 3.60e-05 | crit = 4.41e-02 (accepted ✅)
# it 7 | fun = 3.83215e+00 | step = 1.08e-05 | crit = 2.73e-02 (accepted ✅)
# it 8 | fun = 3.83191e+00 | step = 1.30e-05 | crit = 2.50e-02 (accepted ✅)
# it 10 | fun = 3.83174e+00 | step = 7.78e-06 | crit = 1.93e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 37 : P = 3.83227 W | L = 1.002e-03 mH | lam = -2.275e-01
# ---- Start gradient descent
# it 0 | fun = 3.83176e+00 | step = 1.00e-04
# it 1 | fun = 3.82948e+00 | step = 1.20e-04 | crit = 7.53e-02 (accepted ✅)
# it 4 | fun = 3.82869e+00 | step = 3.60e-05 | crit = 4.52e-02 (accepted ✅)
# it 6 | fun = 3.82814e+00 | step = 2.16e-05 | crit = 4.35e-02 (accepted ✅)
# it 7 | fun = 3.82790e+00 | step = 2.59e-05 | crit = 4.09e-02 (accepted ✅)
# it 8 | fun = 3.82761e+00 | step = 3.11e-05 | crit = 5.22e-02 (accepted ✅)
# it 10 | fun = 3.82705e+00 | step = 1.87e-05 | crit = 3.53e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 38 : P = 3.83085 W | L = 1.020e-03 mH | lam = -1.608e-01
# ---- Start gradient descent
# it 0 | fun = 3.82842e+00 | step = 1.00e-04
# it 5 | fun = 3.82810e+00 | step = 7.50e-06 | crit = 2.14e-02 (accepted ✅)
# it 6 | fun = 3.82802e+00 | step = 9.00e-06 | crit = 2.27e-02 (accepted ✅)
# it 7 | fun = 3.82793e+00 | step = 1.08e-05 | crit = 2.41e-02 (accepted ✅)
# it 8 | fun = 3.82745e+00 | step = 1.30e-05 | crit = 2.76e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 39 : P = 3.82950 W | L = 1.016e-03 mH | lam = -1.026e-01
# ---- Start gradient descent
# it 0 | fun = 3.82841e+00 | step = 1.00e-04
# it 3 | fun = 3.82792e+00 | step = 3.00e-05 | crit = 4.33e-02 (accepted ✅)
# it 5 | fun = 3.82771e+00 | step = 1.80e-05 | crit = 3.35e-02 (accepted ✅)
# it 6 | fun = 3.82734e+00 | step = 2.16e-05 | crit = 3.29e-02 (accepted ✅)
# it 7 | fun = 3.82713e+00 | step = 2.59e-05 | crit = 4.20e-02 (accepted ✅)
# it 9 | fun = 3.82689e+00 | step = 1.56e-05 | crit = 2.60e-02 (accepted ✅)
# it 10 | fun = 3.82678e+00 | step = 1.87e-05 | crit = 2.93e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 40 : P = 3.82777 W | L = 1.013e-03 mH | lam = -4.901e-02
# ---- Start gradient descent
# it 0 | fun = 3.82752e+00 | step = 1.00e-04
# it 4 | fun = 3.82733e+00 | step = 1.50e-05 | crit = 2.86e-02 (accepted ✅)
# it 6 | fun = 3.82722e+00 | step = 9.00e-06 | crit = 2.09e-02 (accepted ✅)
# it 7 | fun = 3.82682e+00 | step = 1.08e-05 | crit = 2.78e-02 (accepted ✅)
# it 9 | fun = 3.82674e+00 | step = 6.48e-06 | crit = 1.77e-02 (accepted ✅)
# it 10 | fun = 3.82639e+00 | step = 7.78e-06 | crit = 2.25e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 41 : P = 3.82666 W | L = 1.012e-03 mH | lam = 3.126e-03
# ---- Start gradient descent
# it 0 | fun = 3.82702e+00 | step = 1.00e-04
# it 4 | fun = 3.82691e+00 | step = 1.50e-05 | crit = 2.76e-02 (accepted ✅)
# it 5 | fun = 3.82670e+00 | step = 1.80e-05 | crit = 3.24e-02 (accepted ✅)
# it 6 | fun = 3.82630e+00 | step = 2.16e-05 | crit = 3.40e-02 (accepted ✅)
# it 8 | fun = 3.82622e+00 | step = 1.30e-05 | crit = 2.65e-02 (accepted ✅)
# it 9 | fun = 3.82588e+00 | step = 1.56e-05 | crit = 2.98e-02 (accepted ✅)
# it 10 | fun = 3.82550e+00 | step = 1.87e-05 | crit = 3.21e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 42 : P = 3.82533 W | L = 1.008e-03 mH | lam = 4.179e-02
# ---- Start gradient descent
# it 0 | fun = 3.82582e+00 | step = 1.00e-04
# it 4 | fun = 3.82554e+00 | step = 1.50e-05 | crit = 2.99e-02 (accepted ✅)
# it 5 | fun = 3.82511e+00 | step = 1.80e-05 | crit = 2.91e-02 (accepted ✅)
# it 6 | fun = 3.82467e+00 | step = 2.16e-05 | crit = 3.23e-02 (accepted ✅)
# it 7 | fun = 3.82433e+00 | step = 2.59e-05 | crit = 3.57e-02 (accepted ✅)
# it 9 | fun = 3.82388e+00 | step = 1.56e-05 | crit = 3.20e-02 (accepted ✅)
# it 10 | fun = 3.82368e+00 | step = 1.87e-05 | crit = 3.15e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 43 : P = 3.82372 W | L = 9.989e-04 mH | lam = 3.585e-02
# ---- Start gradient descent
# it 0 | fun = 3.82368e+00 | step = 1.00e-04
# it 5 | fun = 3.82356e+00 | step = 7.50e-06 | crit = 1.86e-02 (accepted ✅)
# it 6 | fun = 3.82317e+00 | step = 9.00e-06 | crit = 2.36e-02 (accepted ✅)
# it 7 | fun = 3.82291e+00 | step = 1.08e-05 | crit = 2.69e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 44 : P = 3.82301 W | L = 9.945e-04 mH | lam = 2.797e-03
# ---- Start gradient descent
# it 0 | fun = 3.82310e+00 | step = 1.00e-04
# it 6 | fun = 3.82292e+00 | step = 3.75e-06 | crit = 1.30e-02 (accepted ✅)
# it 9 | fun = 3.82266e+00 | step = 1.13e-06 | crit = 7.41e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 45 : P = 3.82260 W | L = 9.952e-04 mH | lam = -2.895e-02
# ---- Start gradient descent
# it 0 | fun = 3.82282e+00 | step = 1.00e-04
# it 10 | fun = 3.82280e+00 | step = 2.34e-07 | crit = 3.15e-03 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 46 : P = 3.82258 W | L = 9.954e-04 mH | lam = -6.284e-02
# ---- Start gradient descent
# it 0 | fun = 3.82296e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 47 : P = 3.82258 W | L = 9.954e-04 mH | lam = -1.001e-01
# ---- Start gradient descent
# it 0 | fun = 3.82314e+00 | step = 1.00e-04
# it 4 | fun = 3.82293e+00 | step = 1.50e-05 | crit = 3.08e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# it 48 : P = 3.82298 W | L = 1.000e-03 mH | lam = -9.590e-02
# ---- Start gradient descent
# it 0 | fun = 3.82293e+00 | step = 1.00e-04
# ---- Stopped after 10 because maximum number of iterations reached.
# it 49 : P = 3.82298 W | L = 1.000e-03 mH | lam = -9.126e-02
# ---- Start gradient descent
# it 0 | fun = 3.82294e+00 | step = 1.00e-04
# it 7 | fun = 3.82280e+00 | step = 1.88e-06 | crit = 1.02e-02 (accepted ✅)
# ---- Stopped after 10 because maximum number of iterations reached.
# Final design : P = 3.82283 W | L = 1.000e-03 mH

# %% [markdown]
# We plot the convergence and optimized design:

# %%
ax1 = plt.plot(P_list, color = 'b')   
plt.ylabel('AC losses (W)', color = 'b')
plt.xlabel('Iteration')
ax2 = plt.gca().twinx()
ax2.plot(np.array(L_list)*1000, color = 'r')
plt.ylabel("Inductance (mH)", color = 'r')
plt.show()

# %%
Draw(materials_regions, current["mesh"])
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %% [markdown]
# ### 5.d - Scipy version

# %% [markdown]
# #TODO
